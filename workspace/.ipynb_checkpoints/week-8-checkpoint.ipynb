# %% [markdown]
# <h1> Week 8 Practicum</h1>

# %% [markdown]
# Didi Chang-Park

# %%
# import some things
import os
import pandas as pd
from textblob import TextBlob
pd.set_option("display.max_rows", 20)
import nltk

# Set text folder and metadata path
text_folder = '../corpora/peregrine'
path_to_metadata='../corpora/peregrine/peregrine.csv'

# %% [markdown]
# <h3>Set up dataframe </h3>
# <i>Load your metadata file as a pandas dataframe<br>
# Show the metadata dataframe <br>
# Make an empty "results" list <br>
# Loop over your filename column, <br>
# Get the full path to the text <br>
# Open the text file <br>
# Count the number of words in the text <br>
# Make an empty "result_dict" dictionary <br>
# Add the number of words to that dictionary <br>
# Add the filename to that dictionary <br>
# Load that results list into a dataframe <br>
# Merge that dataframe with your metadata <br>
# Show the merged dataframe </i>

# %%
# Get the metadata for this corpus
df_meta = pd.read_csv(path_to_metadata).set_index('fn')
df_meta
# Out:
#                               book                    subtitle  season  \
# fn
# apr-2.txt            the peregrine                         NaN  spring
# apr-3.txt            the peregrine                         NaN  spring
# apr-4.txt            the peregrine                         NaN  spring
# dec-1.txt            the peregrine                         NaN  winter
# dec-10.txt           the peregrine                         NaN  winter
# dec-12.txt           the peregrine                         NaN  winter
# dec-15.txt           the peregrine                         NaN  winter
# dec-17.txt           the peregrine                         NaN  winter
# dec-18.txt           the peregrine                         NaN  winter
# dec-2.txt            the peregrine                         NaN  winter
# ...                            ...                         ...     ...
# hill-jun-2.txt  the hill of summer  june: the sea and the moor  summer
# hill-jun-3.txt  the hill of summer             june: midsummer  summer
# hill-may-1.txt  the hill of summer                may: a storm  spring
# hill-may-2.txt  the hill of summer          may: the pine wood  spring
# hill-may-3.txt  the hill of summer              may: a journey  spring
# hill-may-4.txt  the hill of summer               may: downland  spring
# hill-sep.txt    the hill of summer         september: the hill    fall
# hill-may.txt    the hill of summer                         NaN  spring
# hill-jun.txt    the hill of summer                         NaN  summer
# hill-jul.txt    the hill of summer                         NaN  summer
#
#                       unit
# fn
# apr-2.txt              day
# apr-3.txt              day
# apr-4.txt              day
# dec-1.txt              day
# dec-10.txt             day
# dec-12.txt             day
# dec-15.txt             day
# dec-17.txt             day
# dec-18.txt             day
# dec-2.txt              day
# ...                    ...
# hill-jun-2.txt  month part
# hill-jun-3.txt  month part
# hill-may-1.txt  month part
# hill-may-2.txt  month part
# hill-may-3.txt  month part
# hill-may-4.txt  month part
# hill-sep.txt         month
# hill-may.txt         month
# hill-jun.txt         month
# hill-jul.txt         month
#
# [113 rows x 4 columns]

# %%
def make_dtm0(text_folder,n_top_words=5000,normalize=False):
    # get stopwords
    from nltk.corpus import stopwords
    stopwords=set(stopwords.words('english'))

    # make an empty results list
    all_results = []

    # make a count for all words
    from collections import Counter
    all_counts = Counter()

    # for each filename
    filenames=sorted(os.listdir(text_folder))
    for i,fn in enumerate(filenames):
        if not i%10: print('>> looping through #',i,'of',len(filenames),'files:',fn)
        # make sure is a text file
        if not fn.endswith('.txt'): continue
        
        # full path
        full_path = os.path.join(text_folder,fn)

        # open the file
        with open(full_path) as file:
            txt=file.read()

        # make a blob
        blob = TextBlob(txt.lower())

        # make a result dictionary
        text_result = {}

        # set the filename
        text_result['fn']=fn

        # loop over the word counts
        num_words = len(blob.words)
        text_result['num words'] = num_words
        # add results
        all_results.append(text_result)

    # Get columns
    columns=[]
    columns.append('fn')
    columns.append('num words')
    
    # Make dataframe
    df = pd.DataFrame(all_results, columns=columns).set_index('fn').fillna(0)
    
    # return dataframe
    return df

# %%
# Make the document term matrix
dtm0 = make_dtm0(text_folder,normalize=True)
# Out:
# >> looping through # 0 of 115 files: apr-2.txt
# >> looping through # 10 of 115 files: dec-2.txt
# >> looping through # 20 of 115 files: dec-8.txt
# >> looping through # 30 of 115 files: hill-jul-1.txt
# >> looping through # 40 of 115 files: hill-may-4.txt
# >> looping through # 50 of 115 files: mar-10.txt
# >> looping through # 60 of 115 files: mar-21.txt
# >> looping through # 70 of 115 files: mar-6.txt
# >> looping through # 80 of 115 files: nov-16.txt
# >> looping through # 90 of 115 files: nov-6.txt
# >> looping through # 100 of 115 files: oct-23.txt
# >> looping through # 110 of 115 files: oct-9.txt

# %%
# Add the metadata
dtm_meta0=df_meta.merge(dtm0,on='fn')
dtm_meta0
# Out:
#                               book                    subtitle  season  \
# fn
# apr-2.txt            the peregrine                         NaN  spring
# apr-3.txt            the peregrine                         NaN  spring
# apr-4.txt            the peregrine                         NaN  spring
# dec-1.txt            the peregrine                         NaN  winter
# dec-10.txt           the peregrine                         NaN  winter
# dec-12.txt           the peregrine                         NaN  winter
# dec-15.txt           the peregrine                         NaN  winter
# dec-17.txt           the peregrine                         NaN  winter
# dec-18.txt           the peregrine                         NaN  winter
# dec-2.txt            the peregrine                         NaN  winter
# ...                            ...                         ...     ...
# hill-jun-2.txt  the hill of summer  june: the sea and the moor  summer
# hill-jun-3.txt  the hill of summer             june: midsummer  summer
# hill-may-1.txt  the hill of summer                may: a storm  spring
# hill-may-2.txt  the hill of summer          may: the pine wood  spring
# hill-may-3.txt  the hill of summer              may: a journey  spring
# hill-may-4.txt  the hill of summer               may: downland  spring
# hill-sep.txt    the hill of summer         september: the hill    fall
# hill-may.txt    the hill of summer                         NaN  spring
# hill-jun.txt    the hill of summer                         NaN  summer
# hill-jul.txt    the hill of summer                         NaN  summer
#
#                       unit  num words
# fn
# apr-2.txt              day        442
# apr-3.txt              day        807
# apr-4.txt              day        886
# dec-1.txt              day        781
# dec-10.txt             day        554
# dec-12.txt             day       1331
# dec-15.txt             day        923
# dec-17.txt             day        799
# dec-18.txt             day        286
# dec-2.txt              day        132
# ...                    ...        ...
# hill-jun-2.txt  month part       2098
# hill-jun-3.txt  month part       3912
# hill-may-1.txt  month part       1930
# hill-may-2.txt  month part       2666
# hill-may-3.txt  month part       3367
# hill-may-4.txt  month part       2946
# hill-sep.txt         month       5362
# hill-may.txt         month      10909
# hill-jun.txt         month       9382
# hill-jul.txt         month       8915
#
# [113 rows x 5 columns]

# %% [markdown]
# <h2> Practice Most Distinctive Words </h2>
#
# <i>Replicate the "difference of means" or "tf-idf" sections of the MDW notebook on your own corpus.
# To do this, you'll need to make use of a column in your metadata that allows you to make comparisons between vocabulary usage: like a column for "political party", which allows us to ask for which words most distinguish Republican and Democrat presidents. If you don't yet have such a column, please work to create one before uploading your corpus.
# Write a brief note, before you begin your analysis, about which words you would expect to distinguish your two groups. At the close of the notebook, please write a follow-up note describing how the data aligned or departed from your expectations. </i>

# %% [markdown]
# <h3> Hypotheses </h3>
# I expect there to be more mentions of snow and ice in winter, and more mentions of tree, grass, and other kind of vegetation in the spring and fall. The seasons should also distinguish migratory birds. As J.A. Baker writes in the "Peregrines" section of the book,
#
# > More woodpigeons were killed during the winter I have described in this book, because of their extraordinary abundance in the cold weather, and because of the absence of other inland species at that time. The relative figures for this particular winter are as follows:
# Woodpigeon – 54%  <br>
# Black-headed gull – 9% <br>
# Lapwing – 7% <br>
# Wigeon – 3% <br>
# Partridge – 3% <br>
# Fieldfare – 2% <br>
# Moorhen – 2% <br>
# Curlew – 2% <br>
# Rook – 2% <br>
# Mallard – 2% <br>
#
# Baker also mentions black-headed gulls as another popular winter prey. So we might expect to see both animals mentioned more frequently in the winter texts.
#
#
# J.A. Baker also tells us that
# > In early autumn, and in spring, when days are longer and the air warmer, the peregrine soars higher and hunts over a wider area. In March, when conditions are often ideal for soaring, his range increases, and by long stoops from a great height he is able to kill larger and heavier prey. Cloudy weather means shorter flights at lower levels. Rain curtails the hunting range still further. Fog reduces it to a single field. The shorter the day the more active the hawk, for there is less time available for hunting. All its activities contract or expand with the shortening or lengthening of days on either side of the winter solstice.
#
# Therefore we can expect to see words like "soaring" and "circling," and other words related to high flight, in the fall and spring entries, and especially in March.

# %% [markdown]
# <h3> Difference of means </h3>

# %%
# Loop over each of the filenames

def make_dtm(text_folder,n_top_words=5000,normalize=False):
    # get stopwords
    from nltk.corpus import stopwords
    stopwords=set(stopwords.words('english'))

    # make an empty results list
    all_results = []

    # make a count for all words
    from collections import Counter
    all_counts = Counter()

    # for each filename
    filenames=sorted(os.listdir(text_folder))
    for i,fn in enumerate(filenames):
        if not i%10: print('>> looping through #',i,'of',len(filenames),'files:',fn)
        # make sure is a text file
        if not fn.endswith('.txt'): continue
        
        # full path
        full_path = os.path.join(text_folder,fn)

        # open the file
        with open(full_path) as file:
            txt=file.read()

        # make a blob
        blob = TextBlob(txt.lower())

        # make a result dictionary
        text_result = {}

        # set the filename
        text_result['fn']=fn

        # loop over the word counts
        num_words = len(blob.words)

        # for each word,count pair in the blob.word_counts dictionary...
        for word,count in blob.word_counts.items():
            # is the word in the stopwords?
            if word in stopwords: continue  

            # is the word a punctuation?
            if not word[0].isalpha(): continue
            
            # set the normalized version
            if normalize:
                # get the term frequency (count divided by number of words)
                tf = count / num_words

                # set the term frequency result to the key 'word' in the text_result dictionary
                text_result[word] = tf
            else:
                # set the count as a result
                text_result[word] = count

            # add the count to the dictionary of counts for all words
            all_counts[word]+=count

        # add results
        all_results.append(text_result)
    
    # Get the most frequent words
    most_common_words_plus_counts = all_counts.most_common(n_top_words)
    
    # Get only the words
    word_columns = []
    for word,count in most_common_words_plus_counts:
        word_columns.append(word)
    
    # Get columns
    columns=[]
    columns.append('fn')
    columns.extend(word_columns)
    
    # Make dataframe
    df = pd.DataFrame(all_results, columns=columns).set_index('fn').fillna(0)
    
    # return dataframe
    return df

# %%
# Make the document term matrix
dtm = make_dtm(text_folder,normalize=True)
# Out:
# >> looping through # 0 of 115 files: apr-2.txt
# >> looping through # 10 of 115 files: dec-2.txt
# >> looping through # 20 of 115 files: dec-8.txt
# >> looping through # 30 of 115 files: hill-jul-1.txt
# >> looping through # 40 of 115 files: hill-may-4.txt
# >> looping through # 50 of 115 files: mar-10.txt
# >> looping through # 60 of 115 files: mar-21.txt
# >> looping through # 70 of 115 files: mar-6.txt
# >> looping through # 80 of 115 files: nov-16.txt
# >> looping through # 90 of 115 files: nov-6.txt
# >> looping through # 100 of 115 files: oct-23.txt
# >> looping through # 110 of 115 files: oct-9.txt

# %%
# Add the metadata
dtm_meta=df_meta.merge(dtm,on='fn')
dtm_meta
# Out:
#                               book                    subtitle season_x  \
# fn
# apr-2.txt            the peregrine                         NaN   spring
# apr-3.txt            the peregrine                         NaN   spring
# apr-4.txt            the peregrine                         NaN   spring
# dec-1.txt            the peregrine                         NaN   winter
# dec-10.txt           the peregrine                         NaN   winter
# dec-12.txt           the peregrine                         NaN   winter
# dec-15.txt           the peregrine                         NaN   winter
# dec-17.txt           the peregrine                         NaN   winter
# dec-18.txt           the peregrine                         NaN   winter
# dec-2.txt            the peregrine                         NaN   winter
# ...                            ...                         ...      ...
# hill-jun-2.txt  the hill of summer  june: the sea and the moor   summer
# hill-jun-3.txt  the hill of summer             june: midsummer   summer
# hill-may-1.txt  the hill of summer                may: a storm   spring
# hill-may-2.txt  the hill of summer          may: the pine wood   spring
# hill-may-3.txt  the hill of summer              may: a journey   spring
# hill-may-4.txt  the hill of summer               may: downland   spring
# hill-sep.txt    the hill of summer         september: the hill     fall
# hill-may.txt    the hill of summer                         NaN   spring
# hill-jun.txt    the hill of summer                         NaN   summer
# hill-jul.txt    the hill of summer                         NaN   summer
#
#                       unit      like     wings       sky      hawk      flew  \
# fn
# apr-2.txt              day  0.006787  0.004525  0.000000  0.000000  0.000000
# apr-3.txt              day  0.007435  0.002478  0.002478  0.001239  0.007435
# apr-4.txt              day  0.002257  0.003386  0.005643  0.006772  0.003386
# dec-1.txt              day  0.006402  0.006402  0.006402  0.002561  0.008963
# dec-10.txt             day  0.016245  0.000000  0.003610  0.005415  0.007220
# dec-12.txt             day  0.006011  0.007513  0.001503  0.007513  0.009016
# dec-15.txt             day  0.009751  0.008667  0.005417  0.007584  0.006501
# dec-17.txt             day  0.006258  0.007509  0.006258  0.005006  0.005006
# dec-18.txt             day  0.013986  0.010490  0.013986  0.000000  0.000000
# dec-17.txt        0.000000     0.000000   0.000000  0.000000   0.000000
# dec-18.txt        0.000000     0.000000   0.000000  0.000000   0.000000
# dec-2.txt         0.000000     0.000000   0.000000  0.000000   0.000000
# ...                    ...          ...        ...       ...        ...
# hill-jun-2.txt    0.000000     0.000000   0.000000  0.000000   0.000000
# hill-jun-3.txt    0.000000     0.000000   0.000000  0.000000   0.000000
# hill-may-1.txt    0.000000     0.000000   0.000000  0.000000   0.000000
# hill-may-2.txt    0.000000     0.000000   0.000000  0.000000   0.000000
# hill-may-3.txt    0.000000     0.000000   0.000000  0.000000   0.000000
# hill-may-4.txt    0.000000     0.000000   0.000000  0.000000   0.000000
# hill-sep.txt      0.000000     0.000000   0.000000  0.000000   0.000000
# hill-may.txt      0.000000     0.000000   0.000000  0.000000   0.000000
# hill-jun.txt      0.000000     0.000000   0.000000  0.000000   0.000000
# hill-jul.txt      0.000112     0.000112   0.000112  0.000112   0.000112
#
#                    whang
# fn
# apr-2.txt       0.000000
# apr-3.txt       0.000000
# apr-4.txt       0.000000
# dec-1.txt       0.000000
# dec-10.txt      0.000000
# dec-12.txt      0.000000
# dec-15.txt      0.000000
# dec-17.txt      0.000000
# dec-18.txt      0.000000
# dec-2.txt       0.000000
# ...                  ...
# hill-jun-2.txt  0.000000
# hill-jun-3.txt  0.000000
# hill-may-1.txt  0.000000
# hill-may-2.txt  0.000000
# hill-may-3.txt  0.000000
# hill-may-4.txt  0.000000
# hill-sep.txt    0.000000
# hill-may.txt    0.000000
# hill-jun.txt    0.000000
# hill-jul.txt    0.000112
#
# [113 rows x 5004 columns]

# %%
dtm_meta.groupby('season_x').mean()
# Out:
#               like     wings       sky      hawk      flew       air  \
# season_x
# all       0.007324  0.004616  0.003662  0.004616  0.004959  0.002251
# fall      0.007189  0.004426  0.003823  0.004455  0.005862  0.001913
# spring    0.006976  0.003577  0.002895  0.003698  0.004047  0.002419
# summer    0.008472  0.003825  0.002896  0.001554  0.000858  0.004272
# winter    0.008822  0.005036  0.003576  0.004752  0.004368  0.002114
#
#              white      away       sun      dark  ...  spatters   healed  \
# season_x                                          ...
# all       0.002518  0.002918  0.002727  0.002003  ...   0.00000  0.00000
# fall      0.002884  0.002598  0.002455  0.002486  ...   0.00000  0.00000
# spring    0.002208  0.003099  0.002548  0.001942  ...   0.00000  0.00000
# summer    0.003566  0.002961  0.003467  0.003335  ...   0.00004  0.00004
# winter    0.003145  0.002468  0.004037  0.001513  ...   0.00000  0.00000
#
#            flecks    swans  impression  loosestrife  smoulders   martin  \
# season_x
# all       0.00000  0.00000     0.00000      0.00000    0.00000  0.00000
# fall      0.00000  0.00000     0.00000      0.00000    0.00000  0.00000
# spring    0.00000  0.00000     0.00000      0.00000    0.00000  0.00000
# summer    0.00004  0.00004     0.00004      0.00004    0.00004  0.00004
# winter    0.00000  0.00000     0.00000      0.00000    0.00000  0.00000
#
#           backwater    whang
# season_x
# all         0.00000  0.00000
# fall        0.00000  0.00000
# spring      0.00000  0.00000
# summer      0.00004  0.00004
# winter      0.00000  0.00000
#
# [5 rows x 5000 columns]

# %%
round(dtm_meta.groupby('season_x').mean().T * 1000,2)
# Out:
# season_x      all  fall  spring  summer  winter
# like         7.32  7.19    6.98    8.47    8.82
# wings        4.62  4.43    3.58    3.82    5.04
# sky          3.66  3.82    2.89    2.90    3.58
# hawk         4.62  4.46    3.70    1.55    4.75
# flew         4.96  5.86    4.05    0.86    4.37
# air          2.25  1.91    2.42    4.27    2.11
# white        2.52  2.88    2.21    3.57    3.14
# away         2.92  2.60    3.10    2.96    2.47
# sun          2.73  2.45    2.55    3.47    4.04
# dark         2.00  2.49    1.94    3.34    1.51
# ...           ...   ...     ...     ...     ...
# spatters     0.00  0.00    0.00    0.04    0.00
# healed       0.00  0.00    0.00    0.04    0.00
# flecks       0.00  0.00    0.00    0.04    0.00
# swans        0.00  0.00    0.00    0.04    0.00
# impression   0.00  0.00    0.00    0.04    0.00
# loosestrife  0.00  0.00    0.00    0.04    0.00
# smoulders    0.00  0.00    0.00    0.04    0.00
# martin       0.00  0.00    0.00    0.04    0.00
# backwater    0.00  0.00    0.00    0.04    0.00
# whang        0.00  0.00    0.00    0.04    0.00
#
# [5000 rows x 5 columns]

# %%
dtm_meta_T = dtm_meta.groupby('season_x').mean().T * 1000
dtm_meta_T
# Out:
# season_x          all      fall    spring    summer    winter
# like         7.324191  7.188664  6.976223  8.472211  8.821706
# wings        4.615766  4.426305  3.577372  3.824522  5.035997
# sky          3.662095  3.823459  2.894756  2.896274  3.576209
# hawk         4.615766  4.455283  3.698171  1.553938  4.751567
# flew         4.959088  5.861501  4.046674  0.858043  4.367672
# air          2.250663  1.912870  2.419166  4.271784  2.114389
# white        2.517691  2.884165  2.208087  3.566136  3.144515
# away         2.918232  2.597541  3.099334  2.960513  2.468433
# sun          2.727498  2.454693  2.547535  3.467153  4.036779
# dark         2.002708  2.486233  1.942220  3.335463  1.512601
# ...               ...       ...       ...       ...       ...
# spatters     0.000000  0.000000  0.000000  0.040194  0.000000
# healed       0.000000  0.000000  0.000000  0.040194  0.000000
# flecks       0.000000  0.000000  0.000000  0.040194  0.000000
# swans        0.000000  0.000000  0.000000  0.040194  0.000000
# impression   0.000000  0.000000  0.000000  0.040194  0.000000
# loosestrife  0.000000  0.000000  0.000000  0.040194  0.000000
# smoulders    0.000000  0.000000  0.000000  0.040194  0.000000
# martin       0.000000  0.000000  0.000000  0.040194  0.000000
# backwater    0.000000  0.000000  0.000000  0.040194  0.000000
# whang        0.000000  0.000000  0.000000  0.040194  0.000000
#
# [5000 rows x 5 columns]

# %%
dtm_meta_T['S-W']=dtm_meta_T['spring'] - dtm_meta_T['winter']
dtm_meta_T['S-F']=dtm_meta_T['spring'] - dtm_meta_T['fall']
dtm_meta_T['F-W']=dtm_meta_T['fall'] - dtm_meta_T['winter']
dtm_meta_T['F-Su']=dtm_meta_T['fall'] - dtm_meta_T['summer']
dtm_meta_T['W-Su']=dtm_meta_T['winter'] - dtm_meta_T['summer']
dtm_meta_T['S-Su']=dtm_meta_T['spring'] - dtm_meta_T['summer']

round(dtm_meta_T,2)
# Out:
# season_x      all  fall  spring  summer  winter   S-W   S-F   F-W  F-Su  W-Su  \
# like         7.32  7.19    6.98    8.47    8.82 -1.85 -0.21 -1.63 -1.28  0.35
# wings        4.62  4.43    3.58    3.82    5.04 -1.46 -0.85 -0.61  0.60  1.21
# sky          3.66  3.82    2.89    2.90    3.58 -0.68 -0.93  0.25  0.93  0.68
# hawk         4.62  4.46    3.70    1.55    4.75 -1.05 -0.76 -0.30  2.90  3.20
# flew         4.96  5.86    4.05    0.86    4.37 -0.32 -1.81  1.49  5.00  3.51
# air          2.25  1.91    2.42    4.27    2.11  0.30  0.51 -0.20 -2.36 -2.16
# white        2.52  2.88    2.21    3.57    3.14 -0.94 -0.68 -0.26 -0.68 -0.42
# away         2.92  2.60    3.10    2.96    2.47  0.63  0.50  0.13 -0.36 -0.49
# sun          2.73  2.45    2.55    3.47    4.04 -1.49  0.09 -1.58 -1.01  0.57
# dark         2.00  2.49    1.94    3.34    1.51  0.43 -0.54  0.97 -0.85 -1.82
# ...           ...   ...     ...     ...     ...   ...   ...   ...   ...   ...
# spatters     0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# healed       0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# flecks       0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# swans        0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# impression   0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# loosestrife  0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# smoulders    0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# martin       0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# backwater    0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
# whang        0.00  0.00    0.00    0.04    0.00  0.00  0.00  0.00 -0.04 -0.04
#
# season_x     S-Su
# like        -1.50
# wings       -0.25
# sky         -0.00
# hawk         2.14
# flew         3.19
# air         -1.85
# white       -1.36
# away         0.14
# sun         -0.92
# dark        -1.39
# ...           ...
# spatters    -0.04
# healed      -0.04
# flecks      -0.04
# swans       -0.04
# impression  -0.04
# loosestrife -0.04
# smoulders   -0.04
# martin      -0.04
# backwater   -0.04
# whang       -0.04
#
# [5000 rows x 11 columns]

# %% [markdown]
# <h4>Comment</h4>
#
# We can see here that the words "air," "dark," "grass," "green," "upon," "heat," and "leaves" appear more often in the summer texts, while "snow," "peregrine," "flew," "hawk," "ice," "woodpigeons," "fields," brook," "three," and "mud," etc. appear more often in the winter chapters.
#
# Some of this might be attributed to the fact that <i>The Hill of Summer</i> is not predominantly focused on peregrines and other birds of prey. The other seasonal references to vegetation or heat vs. cold are to be expected. That leaves "three" and "upon" as a bit unexpected... I can't really explain why these differences are the case when I look at the texts.

# %%
round(dtm_meta_T.sort_values('W-Su'),2)
# Out:
# season_x      all  fall  spring  summer  winter   S-W   S-F   F-W  F-Su  W-Su  \
# air          2.25  1.91    2.42    4.27    2.11  0.30  0.51 -0.20 -2.36 -2.16
# dark         2.00  2.49    1.94    3.34    1.51  0.43 -0.54  0.97 -0.85 -1.82
# grass        1.37  1.09    2.48    2.10    0.38  2.10  1.39  0.71 -1.01 -1.72
# green        1.34  1.48    2.08    3.03    1.32  0.76  0.60  0.16 -1.55 -1.71
# upon         0.61  0.63    0.80    1.94    0.47  0.33  0.17  0.16 -1.31 -1.47
# heat         0.06  0.15    0.06    1.45    0.04  0.02 -0.09  0.11 -1.30 -1.41
# leaves       0.48  0.96    0.41    2.00    0.61 -0.19 -0.55  0.36 -1.04 -1.40
# seems        0.15  0.08    0.44    1.42    0.13  0.31  0.36 -0.05 -1.34 -1.29
# sound        0.69  0.69    1.16    1.74    0.49  0.67  0.47  0.20 -1.05 -1.26
# dry          0.48  0.61    0.59    1.46    0.29  0.30 -0.02  0.32 -0.85 -1.18
# ...           ...   ...     ...     ...     ...   ...   ...   ...   ...   ...
# mud          0.72  0.78    0.50    0.48    1.91 -1.41 -0.28 -1.13  0.30  1.44
# three        1.16  1.01    1.05    0.38    1.84 -0.80  0.03 -0.83  0.63  1.46
# brook        1.35  0.96    0.76    0.00    1.85 -1.10 -0.20 -0.89  0.96  1.85
# fields       2.21  2.22    1.76    1.05    3.02 -1.26 -0.46 -0.80  1.17  1.97
# woodpigeons  0.92  0.66    0.51    0.19    2.19 -1.68 -0.16 -1.52  0.48  2.00
# ice          0.48  0.19    0.00    0.04    2.05 -2.05 -0.19 -1.86  0.15  2.01
# hawk         4.62  4.46    3.70    1.55    4.75 -1.05 -0.76 -0.30  2.90  3.20
# flew         4.96  5.86    4.05    0.86    4.37 -0.32 -1.81  1.49  5.00  3.51
# peregrine    3.78  4.47    3.02    0.00    4.57 -1.54 -1.45 -0.09  4.47  4.57
# snow         1.28  0.13    0.35    0.00    5.62 -5.26  0.23 -5.49  0.13  5.62
#
# season_x     S-Su
# air         -1.85
# dark        -1.39
# grass        0.38
# green       -0.95
# upon        -1.14
# heat        -1.39
# leaves      -1.59
# seems       -0.98
# sound       -0.58
# dry         -0.88
# ...           ...
# mud          0.03
# three        0.66
# brook        0.76
# fields       0.71
# woodpigeons  0.32
# ice         -0.04
# hawk         2.14
# flew         3.19
# peregrine    3.02
# snow         0.35
#
# [5000 rows x 11 columns]

# %% [markdown]
# <h4>Comment</h4>
# The seasonal differences are present here with "snow," "ice," "woodpigeons," and "frozen" predominating in winter and not in fall, but there are less obvious differences as well: why more "brook" in winter and more "river" in fall? Why is there more "sun" in winter? And why does "across" distinguish fall most from winter? Though the uses of "across" vary widely within the fall chapters, it seems to conceptually embody the liminality of the season... the flow of the "river" conveys something similar, while the smaller, perhaps largely frozen brook conjures something more precise and narrow, given to the hardness and crispness of ice or snow. The sun is easy to understand; the whiteness of winter secenery reflects the brilliance of the sun more readily than any other season. Not to mention the more dramatic sunsets and sunrises of the darker months.

# %%
round(dtm_meta_T.sort_values('F-W'),2)
# Out:
# season_x      all  fall  spring  summer  winter   S-W   S-F   F-W  F-Su  W-Su  \
# snow         1.28  0.13    0.35    0.00    5.62 -5.26  0.23 -5.49  0.13  5.62
# ice          0.48  0.19    0.00    0.04    2.05 -2.05 -0.19 -1.86  0.15  2.01
# like         7.32  7.19    6.98    8.47    8.82 -1.85 -0.21 -1.63 -1.28  0.35
# sun          2.73  2.45    2.55    3.47    4.04 -1.49  0.09 -1.58 -1.01  0.57
# woodpigeons  0.92  0.66    0.51    0.19    2.19 -1.68 -0.16 -1.52  0.48  2.00
# frozen       0.38  0.11    0.00    0.08    1.28 -1.28 -0.11 -1.17  0.03  1.20
# mud          0.72  0.78    0.50    0.48    1.91 -1.41 -0.28 -1.13  0.30  1.44
# eye          0.65  0.28    0.90    0.46    1.20 -0.30  0.62 -0.92 -0.18  0.74
# hundred      1.07  0.80    0.58    0.34    1.71 -1.13 -0.22 -0.91  0.46  1.37
# brook        1.35  0.96    0.76    0.00    1.85 -1.10 -0.20 -0.89  0.96  1.85
# ...           ...   ...     ...     ...     ...   ...   ...   ...   ...   ...
# inland       0.61  1.26    0.41    0.56    0.17  0.25 -0.85  1.09  0.70 -0.40
# brown        1.53  1.99    1.16    1.09    0.89  0.27 -0.83  1.10  0.89 -0.20
# came         1.30  1.93    0.96    1.14    0.76  0.20 -0.97  1.17  0.79 -0.38
# starlings    0.67  1.51    0.11    0.40    0.11  0.00 -1.40  1.40  1.11 -0.30
# waders       0.69  1.72    0.50    0.31    0.31  0.19 -1.23  1.42  1.41 -0.01
# long         2.78  3.12    3.40    2.14    1.64  1.76  0.28  1.49  0.98 -0.50
# flew         4.96  5.86    4.05    0.86    4.37 -0.32 -1.81  1.49  5.00  3.51
# river        2.02  3.12    1.39    1.31    1.55 -0.16 -1.73  1.57  1.81  0.25
# plover       1.07  1.84    0.60    0.42    0.22  0.38 -1.24  1.62  1.43 -0.19
# across       2.35  2.82    2.56    1.87    1.16  1.39 -0.26  1.66  0.95 -0.70
#
# season_x     S-Su
# snow         0.35
# ice         -0.04
# like        -1.50
# sun         -0.92
# woodpigeons  0.32
# frozen      -0.08
# mud          0.03
# eye          0.44
# hundred      0.24
# brook        0.76
# ...           ...
# inland      -0.15
# brown        0.07
# came        -0.18
# starlings   -0.30
# waders       0.18
# long         1.26
# flew         3.19
# river        0.08
# plover       0.19
# across       0.69
#
# [5000 rows x 11 columns]

# %%
dtm_meta.boxplot('sun',by='season_x',figsize=(8,5))

# %%
dtm_meta.boxplot('flew',by='season_x',figsize=(8,5))

# %%
dtm_meta.boxplot('river',by='season_x',figsize=(8,5))

# %%
dtm_meta.boxplot('brook',by='season_x',figsize=(8,5))

# %%
dtm_meta.boxplot('across',by='season_x',figsize=(8,5))

# %% [markdown]
# The boxplots conform with some of the observations in the comments above.
# Interestingly enough "across" appears quite frequently in spring as well, and less in both the summer and winter months. The migratory motions, and other kinds of transitional moments, are no doubt more common in the spring and fall seasons.

# %% [markdown]
# <h3> TF-IDF </h3>

# %%
# set a given word?
given_word='across'

# %%
# We already have that calculated here:
tf_series = dtm[given_word]
tf_series.sort_values(ascending=False)
# Out:
# fn
# nov-9.txt     0.010471
# apr-2.txt     0.009050
# mar-31.txt    0.008078
# mar-22.txt    0.007732
# oct-8.txt     0.007538
# nov-2.txt     0.006780
# mar-10.txt    0.005747
# nov-6.txt     0.005626
# mar-9.txt     0.005102
# dec-27.txt    0.005013
#                 ...
# nov-13.txt    0.000000
# oct-23.txt    0.000000
# oct-24.txt    0.000000
# dec-29.txt    0.000000
# dec-3.txt     0.000000
# dec-5.txt     0.000000
# dec-8.txt     0.000000
# jan-18.txt    0.000000
# feb-17.txt    0.000000
# jan-5.txt     0.000000
# Name: across, Length: 114, dtype: float64

# %%
# Get the number of documents
num_docs = len(dtm)
num_docs
# Out:
# 114

# %%
# Get the number of documents a given word appears
dtm[dtm[given_word]>0][given_word]
# Out:
# fn
# apr-2.txt               0.009050
# apr-3.txt               0.003717
# apr-4.txt               0.002257
# apr.txt                 0.004215
# dec-1.txt               0.001280
# dec-10.txt              0.001805
# dec-12.txt              0.000751
# dec-15.txt              0.001083
# dec-21.txt              0.001513
# dec-22.txt              0.004197
#                           ...
# oct-28.txt              0.002558
# oct-29.txt              0.002398
# oct-3.txt               0.003185
# oct-30.txt              0.002591
# oct-7.txt               0.002967
# oct-8.txt               0.007538
# oct-9.txt               0.002703
# oct-nov.txt             0.002826
# oct.txt                 0.002267
# the-hunting-life.txt    0.002346
# Name: across, Length: 89, dtype: float64

# %%
num_docs_with_word=len(dtm[dtm[given_word]>0])

# %%
import numpy as np
idf = np.log(num_docs/num_docs_with_word)
idf
# Out:
# 0.24756207866235563

# %%
tfidf_series = tf_series * idf
tfidf_series.sort_values(ascending=False)
# Out:
# fn
# nov-9.txt     0.002592
# apr-2.txt     0.002240
# mar-31.txt    0.002000
# mar-22.txt    0.001914
# oct-8.txt     0.001866
# nov-2.txt     0.001678
# mar-10.txt    0.001423
# nov-6.txt     0.001393
# mar-9.txt     0.001263
# dec-27.txt    0.001241
#                 ...
# nov-13.txt    0.000000
# oct-23.txt    0.000000
# oct-24.txt    0.000000
# dec-29.txt    0.000000
# dec-3.txt     0.000000
# dec-5.txt     0.000000
# dec-8.txt     0.000000
# jan-18.txt    0.000000
# feb-17.txt    0.000000
# jan-5.txt     0.000000
# Name: across, Length: 114, dtype: float64

# %%
pd.DataFrame({'tfidf':tfidf_series, 'tf':tf_series}).plot(x='tf',y='tfidf',kind='scatter')

# %%
# make
def to_tfidf(dtm):
    # list of dictionaries
    dtm_tfidf = pd.DataFrame()
    
    for word in dtm.columns:
        # tf
        tf_series = dtm[word]
        
        # idf
        num_docs = len(dtm)
        num_docs_with_word=len(dtm[dtm[word]>0])
        idf=np.log(num_docs/num_docs_with_word)
        
        # tfidf
        tfidf_series = tf_series * idf
        dtm_tfidf[word]=tfidf_series
    
    return dtm_tfidf

# %%
dtm_tfidf=to_tfidf(dtm)
dtm_tfidf
# Out:
#                           like     wings       sky      hawk      flew  \
# fn
# apr-2.txt             0.000558  0.000731  0.000000  0.000000  0.000000
# apr-3.txt             0.000611  0.000400  0.000558  0.000279  0.001201
# apr-4.txt             0.000186  0.000547  0.001272  0.001526  0.000547
# apr.txt               0.000424  0.000529  0.000739  0.000739  0.000681
# mar-9.txt     0.001263
# dec-27.txt    0.001241
# Name: across, dtype: float64

# %%
pd.DataFrame({'tf':dtm[word], 'tfidf':dtm_tfidf[word]}).plot(x='tf',y='tfidf')

# %%
fn='nov-9.txt'
dtm_tfidf.loc[fn].nlargest(10)
# Out:
# fear          0.016891
# taken         0.012242
# surprise      0.010914
# magpie        0.008162
# gull          0.007944
# dunlin        0.006075
# helmet        0.005457
# careful       0.005457
# zigzagging    0.005457
# flocks        0.005296
# Name: nov-9.txt, dtype: float64

# %%
dtm.loc[fn].nlargest(10)
# Out:
# fear         0.013962
# across       0.010471
# hawk         0.008726
# like         0.006981
# sky          0.006981
# flew         0.006981
# wings        0.005236
# white        0.005236
# peregrine    0.005236
# gull         0.005236
# Name: nov-9.txt, dtype: float64

# %% [markdown]
# The results are quite different between the difference of means and TF-IDF methods.
# I'd say that the words given by TF-IDF are indeed more distinctive to the november 9th text.

# %%
fn='hill.txt'
dtm_tfidf.loc[fn].nlargest(10)
# Out:
# wood        0.002284
# seems       0.002107
# leaves      0.002029
# song        0.001843
# bracken     0.001803
# heat        0.001771
# green       0.001750
# sound       0.001734
# darkness    0.001728
# shrike      0.001682
# Name: hill.txt, dtype: float64

# %% [markdown]
# <i>The Hill of Summer</i> has a more woody, leafy, lush, atmosphere, with less motion perhaps.

# %%
fn='the-hunting-life.txt'
dtm_tfidf.loc[fn].nlargest(10)
# Out:
# snow        0.001749
# march       0.001490
# orchard     0.001484
# december    0.001214
# october     0.001214
# falcon      0.001207
# brook       0.001200
# river       0.001199
# gulls       0.001169
# tiercel     0.001166
# Name: the-hunting-life.txt, dtype: float64

# %% [markdown]
# <i>The Hunting Life</i> is dominated by the winter atmosphere, the presence of the river/brook, and the various hunting birds and their prey.

# %%
n_words = 10
for index in reversed(dtm_tfidf.index):
    # get row for this index
    row=dtm_tfidf.loc[index]
    
    # get the lagest words
    top_words_series=row.nlargest(n_words)
    top_words_list=list(top_words_series.index)
    top_words_str=', '.join(top_words_list)
    
    # print
    print('##',index.upper())
    print(top_words_str)
    print()
# Out:
# ## THE-HUNTING-LIFE.TXT
# snow, march, orchard, december, october, falcon, brook, river, gulls, tiercel
#
# ## OCT.TXT
# waders, crows, starlings, inland, plough, river, gulls, dunlin, airk, field
#
# ## OCT-NOV.TXT
# waders, starlings, river, gulls, plover, crows, inland, falcon, stubble, lapwings
#
# ## OCT-9.TXT
# fog, learnt, jays, mobbed, eight, acorn, meat, breeding, flamed, acrid
#
# ## OCT-8.TXT
# airk, waders, inland, turnstones, dunlin, walked, rained, long-billed, frieze, flapping
#
# ## OCT-7.TXT
# length, tern, cars, peregrines, teeth, gave, eating, twice, falcon, hands
#
# ## OCT-5.TXT
# kestrel, orchard, stubble, partridges, deepening, spiral, strike, brook, curlew, gale
#
# ## OCT-30.TXT
# loneliness, desolation, stubbled, lanes, elms, lived, explosive, leaves, greasy, swan
#
# ## OCT-3.TXT
# beach, waders, sanderling, beaches, sea, faced, inland, flashing, tide, breeze
#
# ## OCT-29.TXT
# crows, plough, starlings, river-bank, spend, arrowed, black-brown, grin, spoor, mounted
#
# ## OCT-28.TXT
# inland, woodcock, smell, fox, stoops, burned, owls, stream, trying, bird-calling
#
# ## OCT-26.TXT
# stooped, shoulders, gull, corner, crows, hit, starlings, tried, climbed, attack
#
# ## OCT-24.TXT
# chimney, tried, roost, gull, luminous, coastal, serious, furiously, stiff-winged, emptiness
#
# ## OCT-23.TXT
# starling, plough, lapwings, gulls, month, mimicry, swarm, migrants, launched, gracefully
#
# ## OCT-20.TXT
# horseshoe, shoulders, revolving, crow, wider, stooped, starlings, golden, chest, strong
#
# ## OCT-18.TXT
# keerk, rain, crow, fine, crows, field, minutes, wire, sat, food
#
# ## OCT-16.TXT
# spray, waders, wall, waves, smoke, gale, slept, turnstone, recognition, beast
#
# ## OCT-15.TXT
# peregrines, wingbeats, falcon, ford, blackish, plumage, flickered, catapulting, gather, crows
#
# ## OCT-14.TXT
# godwit, godwits, turn, seldom, pecking, corkscrewing, shore, turnstone, boats, revolve
#
# ## OCT-12.TXT
# crows, dunlin, regain, prruk, crow, plough, dry, furrows, haze, twisted
#
# ## OCT-1.TXT
# acorn, follow, jays, tractors, jay, alder, cirrus, drifting, plough, autumn
#
# ## NOV.TXT
# gall, river, post, plover, falcon, woodcock, gulls, beagles, starlings, water
#
# ## NOV-9.TXT
# fear, taken, surprise, magpie, gull, dunlin, helmet, careful, zigzagging, flocks
#
# ## NOV-6.TXT
# clay, flock, post, pursuit, fence, pigeons, rain, cleared, starlings, ahead
#
# ## NOV-4.TXT
# gale, hovered, hovering, ran, scoured, neatly, thirty, cleaned, sank, plucked
#
# ## NOV-30.TXT
# men, crouching, kingfisher, weighed, meat, glimmers, hunts, insanity, gait, blood-red
#
# ## NOV-29.TXT
# grebe, spot, u, palate, weighed, cleaned, taste, unpleasant, steamed, weighing
#
# ## NOV-28.TXT
# jay, shoulders, chaffinches, scolding, stones, poor, hawthorns, cleaned, bathe, drank
#
# ## NOV-26.TXT
# merganser, rain, grey, red-breasted, careful, scoured, palate, shore, rooks, waders
#
# ## NOV-24.TXT
# hovers, crouch, orchard, squelching, extinguished, cupped, nearest, sixteen, stubble, lane
#
# ## NOV-21.TXT
# call, stubble, stands, hedge, cluster, stubbles, spiky, saffron, calmly, limes
#
# ## NOV-2.TXT
# fires, autumn, heading, gull, yellow, gravel, half-past, warrior, flocked, bloomed
#
# ## NOV-18.TXT
# waders, island, sand, estuary, beyond, ran, cleaves, heading, u, curve
#
# ## NOV-16.TXT
# beagles, hare, falcon, kink, huntsmen, followers, earth, starlings, gulls, intricate
#
# ## NOV-15.TXT
# gall, bracken, woodcock, hammering, birches, tapping, pasture, jays, chestnuts, lesser
#
# ## NOV-13.TXT
# ride, face, owl, rook, wood, woodcock, gathered, pine, free, helmet
#
# ## NOV-12.TXT
# teal, duck, pond, marsh, post, came, red-breasted, bills, black-tailed, orange-red
#
# ## NOV-11.TXT
# kicked, partridge, post, surprise, spend, oblivious, fences, sparrows, serious, warily
#
# ## MAR.TXT
# orchard, owl, tiercel, grass, falcon, estuary, hovered, tree, elm, wind
#
# ## MAR-APR.TXT
# orchard, grass, tiercel, owl, tree, falcon, drumming, elm, spring, estuary
#
# ## MAR-9.TXT
# waders, planes, humped, rocking, sea-wall, gathering, leap, pouring, width, tide
#
# ## MAR-8.TXT
# lark, wall, lost, merlin, singing, saltings, death, save, striving, jabbing
#
# ## MAR-7.TXT
# million, prisms, wasted, hollow, piped, barns, distorted, lee, rain, arrow
#
# ## MAR-6.TXT
# shared, places, warm, quarry, longing, sun-glittered, sack, horror, flocks, cage
#
# ## MAR-5.TXT
# gate, orchard, snow, streams, eroded, aisles, flocks, past, swaying, chain
#
# ## MAR-31.TXT
# drumming, produced, spotted, lesser, owl, darkness, woodpecker, willow, rattle, loudest
#
# ## MAR-30.TXT
# rain, drenched, carried, sparrows, deceived, swelled, elm, flapped, gust, stoat
#
# ## MAR-29.TXT
# snipe, drumming, molehill, bud, march, bleating, peregrines, twist, elm, twig
#
# ## MAR-28.TXT
# orchard, wing-hold, images, speck, leave, hedge, ploughland, sunlit, circle, islands
#
# ## MAR-27.TXT
# godwit, black-backed, killers, falcon, blinked, carcass, stoat, funny, heron, gull
#
# ## MAR-25.TXT
# gull, shelduck, cook-a-doo, falcon, seal, waves, shark, impact, shingle, redshank
#
# ## MAR-23.TXT
# kestrels, orchard, mouse, apple, grass, stoat, dread, brook, carrying, resist
#
# ## MAR-22.TXT
# orchard, pound, partridge, hunt, grip, red-legged, weighs, wing-strokes, crows, jackdaws
#
# ## MAR-21.TXT
# footpath, figure, using, speck, pigeon, part, either, aside, binoculars, lighter
#
# ## MAR-20.TXT
# orchard, reddish, ignored, mantle, perch, barred, mice, worms, ate, stayed
#
# ## MAR-2.TXT
# orchard, december, saw, south-east, beyond, soar, shrilling, rage, shoulder, scolded
#
# ## MAR-17.TXT
# lapwing, owl, swooped, solitary, marsh, barn, stayed, rowing, exactly, diffusion
#
# ## MAR-16.TXT
# wigeon, mask, owl, barn, night, silence, lay, headless, shriek, gate-post
#
# ## MAR-15.TXT
# gale, throat, orchard, sockets, hovered, partridge, creamy, brown, tiercel, hazel
#
# ## MAR-14.TXT
# creek, mottled, short-eared, mud, chest, diamond-shaped, striving, shore, breeze, suspicious
#
# ## MAR-13.TXT
# worm, worms, rattle, gull, replaced, bites, red, bedraggled, curiosity, shaggy
#
# ## MAR-12.TXT
# swift, marshes, green, strong, quarry, hills, view, glorious, farmland, march
#
# ## MAR-11.TXT
# hills, spirals, brightening, valleys, estuary, desperate, villages, cries, lurking, shadows
#
# ## MAR-10.TXT
# falcon, splendid, invisible, eroded, tarnished, save, aloud, weirs, curl, pursue
#
# ## JAN.TXT
# snow, ice, frozen, blood, barn, dying, roof, outlived, corpses, moorhen
#
# ## JAN-9.TXT
# outlived, snow, woodcock, frozen, clearest, coldest, knee-deep, unruffled, sarcophagus, gibbering
#
# ## JAN-5.TXT
# ice, kingfisher, snow, frozen, guns, others, sparkled, patrolled, brussels, sprouts
#
# ## JAN-30.TXT
# snow, road, barn, window-pane, breasts, scowling, brows, snow-flecked, stacks, disintegrating
#
# ## JAN-25.TXT
# snow, blood, ice, wooden, pike, roof, barn, frozen, trudged, foot-deep
#
# ## JAN-18.TXT
# snow, sandpiper, cracked, whanged, sealed, rigidity, antics, enfeebled, weakened, pitting
#
# ## HILL.TXT
# wood, seems, leaves, song, bracken, heat, green, sound, darkness, shrike
#
# ## HILL-SEP.TXT
# fog, hill, spruce, thistles, seems, hedges, rises, summer, leaves, owl
#
# ## HILL-MAY.TXT
# rain, wood, song, pines, sings, pine, nightjar, darkness, seems, smell
#
# ## HILL-MAY-4.TXT
# wood, keer, kee, bracken, lark, kee-u, plantation, lets, larches, seemed
#
# ## HILL-MAY-3.TXT
# rain, barn, horse, blossom, smells, grove, cycle, swallows, seems, firs
#
# ## HILL-MAY-2.TXT
# nightjar, pines, song, seems, chirrup, clapping, bracken, night, darkness, croak
#
# ## HILL-MAY-1.TXT
# thunder, pine, sings, bluebells, rain, sparrowhawks, needles, wood, garden, warbler
#
# ## HILL-JUN.TXT
# beech, hay, woodpecker, bales, beeches, moor, wood, leaves, seemed, bole
#
# ## HILL-JUN-3.TXT
# hay, bales, bracken, hayfield, heat, darkness, wood, moon, night, seemed
#
# ## HILL-JUN-2.TXT
# moor, merlin, buzzard, sea, sail, seems, male, shines, rock, hurling
#
# ## HILL-JUN-1.TXT
# beech, woodpecker, beeches, bole, squirrel, leaves, jay, squirrels, clearing, moved
#
# ## HILL-JUL.TXT
# shrike, heath, hobby, heat, boat, gorse, swifts, swallows, pines, insects
#
# ## HILL-JUL-2.TXT
# shrike, heath, gorse, heather, male, pines, young, bush, insects, hobby
#
# ## HILL-JUL-1.TXT
# boat, heat, hobby, bank, river, seems, tern, water, rises, surface
#
# ## HILL-AUG.TXT
# bay, dyke, waders, seems, tide, shore, sea-wall, mud, rises, inland
#
# ## HILL-APR.TXT
# ants, bracken, wood, larch, gorse, pine, redstart, blossom, leaves, insects
#
# ## FEB.TXT
# snow, footprints, agony, marks, rolled, hundred, fox, angle, woodpigeons, fall
#
# ## FEB-27.TXT
# snow, lances, thrive, twenty-six, under-weight, obtain, amount, bronze-brown, stretch, pear
#
# ## FEB-22.TXT
# snow, footprints, marks, fox, returning, thaw, heap, manoeuvred, pleasure, dogs
#
# ## FEB-17.TXT
# snow, tits, footprints, mallard, inches, channels, halved, survived, thirteen, scored
#
# ## FEB-10.TXT
# agony, angle, fall, snow, beak, became, sheltered, feet, rage, beginning
#
# ## DEC.TXT
# frost, brook, wood, snow, tree, sparrowhawk, mud, frozen, pigeons, snipe
#
# ## DEC-JAN-FEB.TXT
# snow, ice, frozen, brook, frost, wood, woodpigeons, sparrowhawk, gulls, blood
#
# ## DEC-8.TXT
# keerk, wigeon, raised, barbarous, tenseness, ply, inextricably, turmoil, stealthy, diffusing
#
# ## DEC-5.TXT
# rime, drip, haystack, brushing, fourteen, unfrozen, reeds, stirring, boomed, sullen
#
# ## DEC-3.TXT
# mud, land, oozing, glutinous, sprout, octopus, squelched, slippery, treacherous, evil
#
# ## DEC-29.TXT
# snow, chak, outer, guns, may, powerless, smack, snow-drifted, predictability, trusting
#
# ## DEC-27.TXT
# sparrowhawk, snow, safe, muffling, mysteries, cat-thin, speeded-up, recording, whimpering, dusts
#
# ## DEC-24.TXT
# frost, sparrowhawk, frozen, hornbeam, sticks, clarity, hazel, rather, gaping, feel
#
# ## DEC-23.TXT
# jack, climbs, snap, shrew, thinking, ice, tree, bill, stop, wood
#
# ## DEC-22.TXT
# cotswold, cliffs, remember, chalk, sea, peregrines, winter, sterile, thames, oxford
#
# ## DEC-21.TXT
# bulge, begin, circle, rhythm, deadly, clearer, unnatural, huddled-up, fleeces, mercurial
#
# ## DEC-20.TXT
# mallard, birch, lake, relax, cock, wood, frost, pedalling, trap-door, loft
#
# ## DEC-2.TXT
# deflated, lagoons, smarted, gasping, lanced, hook, curlew, breast, veins, strands
#
# ## DEC-18.TXT
# drakes, duck, reservoir, goosander, troughs, bomb-shaped, imperial, goldeneyes, ung-ick, noses
#
# ## DEC-17.TXT
# frost, alternately, falcon, swished, arcs, movements, round, gliding, direction, polar
#
# ## DEC-15.TXT
# gale, warning, pigeons, love, wild, fell, flinging, brook, heaved, breakwater
#
# ## DEC-12.TXT
# tractors, pond, lapwing, copse, gaped, sewage, pollard, ford, roadside, tractor
#
# ## DEC-10.TXT
# snipe, sandpiper, fieldfares, scattering, meadow, stooped, keeping, brutal, thickening, sleet
#
# ## DEC-1.TXT
# pigeons, falcon, searched, would, tension, untroubled, temptation, challenge, scrutinised, eludes
#
# ## APR.TXT
# quee, spring, drumming, comes, wall, song, inland, closer, woodpecker, ended
#
# ## APR-4.TXT
# wall, inland, breathe, look, bunting, spring, comes, sea-wall, hoping, wire
#
# ## APR-3.TXT
# quee, drumming, woodpecker, wood, beech, song, knew, spotted, october, fuzzy
#
# ## APR-2.TXT
# spring, ploughland, chemicals, wheatears, fanatic, evenings, hoop, red-hot, sears, meeting

# %% [markdown]
# I like the fact that TF-IDF gives a pretty even mix of truly distinctive words which I may not have highlighted on my own and more predictable words pertaining to weather and seasonality. Depending on the resolution of the text (size) one can find more obscure entities in each date entry or terms of more general interest such as "across" or "river." It's interesting to track how certain words persist in larger text sizes while others fade out. "Cotswold" in dec-22.txt shows up five times in that text, but nowhere else, so it is naturally not part of the dec.txt most-distinctive-words.

# %% [markdown]
# <h3> Going forward... </h3>
# <i>Write a paragraph about your research plans for the remainder of the course.
# What are you hoping to accomplish in your final project?
# Which research question(s) are guiding you?
# Now that we have a better sense of what's possible, what findings and visualizations are you hoping to produce?
# What do you hope to accomplish next week as we work on our projects in class?
# (Answering these questions will help us be maximally productive next week.)</i>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#     Clearly I've changed my corpus once again, but I think this has been a good decision. I feel like each date entry from <i>The Hunting Life</i> (first published in 1967 in <i>The Peregrine</i>) forms a discrete unit of analysis which holds on its own and can be linked in interesting ways to others. Having <i>The Hill of Summer</i> (1969) to compare it to allows me to see differences not only between the warmer and cooler seasons, but the differences between a text preoccupied with the peregrine falcon and another more generally interested in the natural landscape. I'm broadly hoping that observing the texts using computational methods will give me ways of easily identifying general patterns and preoccupations of the texts while also allowing me to see how the most distinctive and specific instances of poetic language interact with those broader themes. One way I hope to do this is by making networks around specific key words, such as the various bird species, or distinctive terms like "across." Making networks for two terms might serve as a kind of lexical venn diagram or visual thesaurus (example below).

# %%
from IPython.display import Image
Image("./download.png", width=500)

# %% [markdown]
# More fundamentally however, I want to understand how similes play out in the text, and am working on network visualizations which use "like" or "as" as edges. The underlying question being, **what makes the similes in Baker's writing so powerful?** Metaphor is generally considered to be the more powerful trope in literary texts, yet somehow the similes here have their own charisma. I observe from the concordance below that the similes tend to involve more unusual terms and phrases, "he glowed purple and grey like broccoli, in the white field" being one striking example. The use of hyphenated words is also significant and interesting; perhaps those compound words are in fact doing another level of metaphorical work, as in the "cat-thin skirling, like a speeded-up recording of the song of a nightjar." These are pretty dense and lengthy similes, which give me a good motivation for putting them into networks. The question of how to do this will be of scale (i.e. how to visualize a smaller text vs a larger amalgamation of texts), of how to slice out the noise and choose the right data to visualize. Once I can find some really interesting networks, I need to translate them into other scales and domains and see how well the networks I make can be summarized quantitatively by certain graph metrics. Ideally, I will be able to make good networks for individual texts but also for larger ones, and will find numerical formulae for speaking concisely about how these networks change between scales and between texts.

# %%
def concordance(text_folder,filename,word,width=100,lines=1000):
    # Get the path
    text_path = os.path.join(text_folder, filename)
    print(text_path)

    # Open the file
    with open(text_path) as file:
        text_txt=file.read()

    # make nltk version of the text (useful for concordance)
    import nltk
    text_words = nltk.word_tokenize(text_txt)
    text_nltk = nltk.text.Text(text_words)

    # get concordance
    text_nltk.concordance(word,width=width,lines=lines)

# %%
concordance(text_folder,'dec.txt',"like")
# Out:
# ../corpora/peregrine/dec.txt
# Displaying 93 of 93 matches:
# winked madly in the sun . Coot huddled together like winkles on a plate . Drake smew , their phantom
#  curled about with thin black veins , sank deep like ice-floes or dazzled up the sky like flying sno
#  sank deep like ice-floes or dazzled up the sky like flying snow . I did not see a peregrine , thoug
# f flesh . What was left smelt fresh and sweet , like a mash of raw beef and pineapple . It was an ap
# ungry . The day hardened in the easterly gale , like a flawless crystal . Columns of sunlight floate
# h its bill if you reach down to it as it floats like a log in the tide . A poisoned crow , gaping an
# f death . We carry it with us . It sticks to us like frost . We can not tear it away . At midday the
# is bill gaping open . He glowed purple and grey like broccoli , in the white field . I went down int
#  of dusk flickered across the barred sunlight , like the shadow of something higher . Thirty yards a
# ugh the colour of the memory will slowly fade , like the plumage of a stuffed bird in a glass case .
# nsanity of searing yellow , raging and seething like sulphurous craters . They seemed to shine in th
# s craters . They seemed to shine in the dimness like jellies of yellow blood . The glaring madness d
