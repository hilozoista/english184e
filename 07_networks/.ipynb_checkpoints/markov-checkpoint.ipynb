# %%
import os
import markovify
import numpy
import natsort
import matplotlib.pyplot as plt
text_folder = '../corpora/peregrine/'

with open(text_folder+"/hidden/the-hunting-life.txt") as f:
    text = f.read()
    whole_model = markovify.Text(text, state_size=2)
    
with open(text_folder+"/hidden/first-lines.txt") as f:
    text = f.read()
    firstline_model = markovify.Text(text, state_size=2)
    
def markovify(fn):
    import markovify
    with open(text_folder+fn) as f:
        txt = f.read()
        txt_model = markovify.Text(txt, state_size=2)
    full_model = markovify.combine([whole_model, txt_model], [1,5])
    first_model = markovify.combine([firstline_model,txt_model],[5,1])
    new_text=""
    sd = sent_data(fn)
    num_sents = sd[1][4]
    max_len = sd[1][0]
    wc = sd[1][5]
    curlen = 0
    new = first_model.make_sentence(tries=400)
    if(new!=None):
            new_text+=(new+" ")
            curlen+=(new.count(" ")+1)
    while curlen<wc+5:
        #new = text_model.make_short_sentence(max_len)
        new = full_model.make_sentence(tries=500)
        if(new!=None):
            new_text+=(new+" ")
            curlen+=(new.count(" ")+1)
    m = open(text_folder+"_"+fn, "w+")
    m.write(new_text)
    m.close()

# %%
def sent_data(filename):
    sent_len = []
    with open(text_folder+filename) as f:
        text = f.read().strip("\n").split(".")
        text[0]+=" "
        for sent in text:
            if(sent!=""):
                sentlen = sent.count(" ")
                sent_len.append(sentlen)
        #max sent length, min sent length, mean sent length, standard deviation on sent length, number of sents, number of words
        data = [max(sent_len), min(sent_len),sum(sent_len)/len(sent_len), np.std(sent_len),len(sent_len), sum(sent_len)]
    return([sent_len,data])

# %%
def plot_sents(fn):
    max_x = sent_data(fn)[1][4]
    data = sent_data(fn)[0]
    plt.bar(range(1,max_x+1),data)

# %%
test_date = "35_dec-2.txt"
markovify(test_date)
print(sent_data(test_date)[1])
print(sent_data("_"+test_date)[1])
plot_sents(test_date)
plot_sents("_"+test_date)
# Out:
# [33, 4, 14.333333333333334, 8.04155872120988, 9, 129]
# [34, 1, 13.6, 8.867919710958146, 10, 136]

# %%
for fn in os.listdir(text_folder):
    if(fn[0]!="_" and fn[-3:]=="txt"):
        markovify(fn)

# %%
#creates the CSV metadata
seasons = {
    "oct" : "fall",
    "nov" : "fall",
    "dec" : "winter",
    "jan" : "winter",
    "feb" : "winter",
    "mar" : "spring",
    "apr" : "spring"
}
dr=os.listdir(text_folder)
nr = natsort.natsorted(dr)
with open(text_folder+"peregrine.csv", "w+") as file:
    file.write("fn,season,author\n")
    for fn in nr:
        author="baker"
        month=fn[3:6]
        if(fn[-3:]=="txt"):
            if(fn[0]=="_"):
                author="markov"
                month = fn[4:7]
            elif(fn[0]=="-"):
                author="gpt-2"
                month = fn[4:7]
            file.write(fn+","+seasons[month]+","+author+"\n")
    file.close()
path_to_metadata='../corpora/peregrine/peregrine.csv'

# %%
# Get the metadata for this corpus
import pandas as pd
from textblob import TextBlob
pd.set_option("display.max_rows", 20)
import nltk

# %%
df_meta = pd.read_csv(path_to_metadata).set_index('fn')

# %%
def make_dtm(text_folder,normalize=False):

    # make an empty results list
    all_results = []
    
    columns=[]
    attrbs = ['max_sent_len','min_sent_len','mean_sent_len',
             'sd_sent_len','num_sents','num_words']
    columns.append('fn')
    for att in attrbs:
        columns.append(att)
    
    # for each filename
    filenames=sorted(os.listdir(text_folder))
    for fn in filenames:
        if(fn[-3:]=="txt"):
            text_result = {}
            text_result["fn"]=fn
            #max sent length, min sent length, mean sent length, standard deviation on sent length, number of sents, number of words
            text_result['max_sent_len']=sent_data(fn)[1][0]
            text_result['min_sent_len']=sent_data(fn)[1][1]
            text_result['mean_sent_len']=sent_data(fn)[1][2]
            text_result['sd_sent_len']=sent_data(fn)[1][3]
            text_result['num_sents']=sent_data(fn)[1][4]
            text_result['num_words']=sent_data(fn)[1][5]
        all_results.append(text_result)
            

    
    # Make dataframe
    df = pd.DataFrame(all_results, columns=columns).set_index('fn').fillna(0)
    
    # return dataframe
    return df

# %%
dtm = make_dtm(text_folder,normalize=True)

# %%
dtm
# Out:
#                 max_sent_len  min_sent_len  mean_sent_len  sd_sent_len  \
# fn
# -51_jan-5.txt             27             5      14.184211     5.041174
# -51_jan-5.txt             27             5      14.184211     5.041174
# 00_oct-1.txt              28             2      13.213115     6.606293
# 01_oct-3.txt              20             2      10.000000     4.918694
# 02_oct-5.txt              38             3      14.309524     7.651605
# 03_oct-7.txt              44             2      15.488372     8.439586
# 04_oct-8.txt              18             2      10.888889     4.550811
# 05_oct-9.txt              26             2      13.000000     5.843189
# 06_oct-12.txt             26             4      14.035714     5.133797
# 07_oct-14.txt             26             4      10.000000     6.291757
# ...                      ...           ...            ...          ...
# _79_mar-27.txt            50             1      15.757143     8.504513
# _80_mar-28.txt            64             1      16.089888    10.177791
# _81_mar-29.txt            48             1      16.745763    10.529367
# _82_mar-30.txt            32             1      14.529412     7.754450
# _83_mar-31.txt            64             1      16.289474    10.605133
# _84_apr-2.txt             35             1      13.968750     7.028888
# _85_apr-3.txt             33             1      15.823529     6.978134
# _86_apr-4.txt             48             1      13.984127     8.321882
# _86_apr-4.txt             48             1      13.984127     8.321882
# _86_apr-4.txt             48             1      13.984127     8.321882
#
#                 num_sents  num_words
# fn
# -51_jan-5.txt          38        539
# -51_jan-5.txt          38        539
# 00_oct-1.txt           61        806
# 01_oct-3.txt           31        310
# 02_oct-5.txt           42        601
# 03_oct-7.txt           43        666
# 04_oct-8.txt           36        392
# 05_oct-9.txt           28        364
# 06_oct-12.txt          56        786
# 07_oct-14.txt          29        290
# ...                   ...        ...
# _79_mar-27.txt         70       1103
# _80_mar-28.txt         89       1432
# _81_mar-29.txt         59        988
# _82_mar-30.txt         17        247
# _83_mar-31.txt         38        619
# _84_apr-2.txt          32        447
# _85_apr-3.txt          51        807
# _86_apr-4.txt          63        881
# _86_apr-4.txt          63        881
# _86_apr-4.txt          63        881
#
# [178 rows x 6 columns]

# %%
dtm_meta=df_meta.merge(dtm,on='fn')
dtm_meta = dtm_meta[dtm_meta.author !="gpt-2"]
dtm_meta
# Out:
#                 season  author  max_sent_len  min_sent_len  mean_sent_len  \
# fn
# 00_oct-1.txt      fall   baker            28             2      13.213115
# 01_oct-3.txt      fall   baker            20             2      10.000000
# 02_oct-5.txt      fall   baker            38             3      14.309524
# 03_oct-7.txt      fall   baker            44             2      15.488372
# 04_oct-8.txt      fall   baker            18             2      10.888889
# 05_oct-9.txt      fall   baker            26             2      13.000000
# 06_oct-12.txt     fall   baker            26             4      14.035714
# 07_oct-14.txt     fall   baker            26             4      10.000000
# 08_oct-15.txt     fall   baker            37             3      17.185185
# 09_oct-16.txt     fall   baker            36             7      16.840000
# ...                ...     ...           ...           ...            ...
# _79_mar-27.txt  spring  markov            50             1      15.757143
# _80_mar-28.txt  spring  markov            64             1      16.089888
# _81_mar-29.txt  spring  markov            48             1      16.745763
# _82_mar-30.txt  spring  markov            32             1      14.529412
# _83_mar-31.txt  spring  markov            64             1      16.289474
# _84_apr-2.txt   spring  markov            35             1      13.968750
# _85_apr-3.txt   spring  markov            33             1      15.823529
# _86_apr-4.txt   spring  markov            48             1      13.984127
# _86_apr-4.txt   spring  markov            48             1      13.984127
# _86_apr-4.txt   spring  markov            48             1      13.984127
#
#                 sd_sent_len  num_sents  num_words
# fn
# 00_oct-1.txt       6.606293         61        806
# 01_oct-3.txt       4.918694         31        310
# 02_oct-5.txt       7.651605         42        601
# 03_oct-7.txt       8.439586         43        666
# 04_oct-8.txt       4.550811         36        392
# 05_oct-9.txt       5.843189         28        364
# 06_oct-12.txt      5.133797         56        786
# 07_oct-14.txt      6.291757         29        290
# 08_oct-15.txt      8.515942         27        464
# 09_oct-16.txt      6.466405         25        421
# ...                     ...        ...        ...
# _79_mar-27.txt     8.504513         70       1103
# _80_mar-28.txt    10.177791         89       1432
# _81_mar-29.txt    10.529367         59        988
# _82_mar-30.txt     7.754450         17        247
# _83_mar-31.txt    10.605133         38        619
# _84_apr-2.txt      7.028888         32        447
# _85_apr-3.txt      6.978134         51        807
# _86_apr-4.txt      8.321882         63        881
# _86_apr-4.txt      8.321882         63        881
# _86_apr-4.txt      8.321882         63        881
#
# [176 rows x 8 columns]

# %%
dtm_meta.groupby('author').mean()

# %%
import matplotlib
matplotlib.style.use('ggplot')
dtm_meta.groupby('author').mean_sent_len.plot(kind='barh',figsize = (500px,800px))
