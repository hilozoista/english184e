# %% [markdown]
# <h1>Mimicking The Peregrine</h1>
# Didi Chang-Park

# %%
import json
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
text_folder = '../corpora/peregrine/'

# %%
#thanks to ryan for this method, which I've slightly modified
def draw_graph3(networkx_graph,notebook=True,output_filename='graph.html',show_buttons=False,only_physics_buttons=False):
    # import
    from pyvis import network as net
    
    # make a pyvis network
    pyvis_graph = net.Network(notebook=notebook, height="750px", width="100%")
    
    # for each node and its attributes in the networkx graph
    for node,node_attrs in networkx_graph.nodes(data=True):
        pyvis_graph.add_node(node,**node_attrs)
        
    # for each edge and its attributes in the networkx graph
    for source,target,edge_attrs in networkx_graph.edges(data=True):
        # if value/width not specified directly, and weight is specified, set 'value' to 'weight'
        if not 'value' in edge_attrs and not 'width' in edge_attrs and 'weight' in edge_attrs:
            # place at key 'value' the weight of the edge
            edge_attrs['value']=edge_attrs['weight']
        # add the edge
        pyvis_graph.add_edge(source,target,**edge_attrs)

    pyvis_graph.set_edge_smooth('dynamic')
    # return and also save
    return pyvis_graph.show(output_filename)

# %%
import nltk
from nltk.corpus import stopwords
import re
import pyvis
from pyvis.network import Network
lemma = nltk.wordnet.WordNetLemmatizer()

stop_words = stopwords.words('english')
stop_words.append('is')
stop_words.remove('as')
stop_words.append('a')
parts = ['N','V','A']
colordict = {}
colordict['N'] = ['green',15]
colordict['V'] = ['red',15]
colordict['A'] = ['pink',15]
colordict['D'] = ['#c0c1c4',15]
colordict['P'] = ['yellow',15]
birds = ('falcon',"peregrine","tiercel","lapwing","woodcock","curlew","heron","sandpiper",
        "snipe","wigeon","starling","skylark","gull","owl","mallard","woodpigeons","swan",
        "jackdaw","lark","plover","partridge","pigeon","duck","hawk","crow","teal","wildfowl",
        "blackbird","bunting","swallow","martin","kestrel","jay","plover","sanderling",
        "wader","pheasant","greenshank","grebe","pied","wagtail","moorhen","thrush","finch")
for bird in birds:
    colordict[bird] = ["blue",40]
    
#from colour import Color
#red = Color("red")
#colors = red.range_to(Color("green"),10)

# %%
#stopped=0 does nothing
#stopped=1 will take out stopwords from nltk's list.
#stopped=2 will exclude all words that are not Nouns, Verbs, or Adjectives.

def getsents(text,stopped):
    #with open(text_folder+fn) as file:
    #    filetext = file.read().lower()
    sents_unstripped = nltk.sent_tokenize(text.lower())
    sents_unstopped = []
    for s in sents_unstripped:
        sents_unstopped.append(re.sub(r'[^\w\-\s]', '',s).split())
    sents = []
    for s in sents_unstopped:
        st = []
        for w in s:
            if w not in stop_words:
                if(w=="smoothed"):
                    print("smoothed")
                if(w=="as"):
                    st.append("as")
                if(w=="was"):
                    st.append("was")
                else:
                    st.append(lemma.lemmatize(w))
        sents.append(st)
    return sents

def getsents_filter(text,words):
    sents_unstripped = nltk.sent_tokenize(text.lower())
    sents_unstopped = []

    for s in sents_unstripped:
        sents_unstopped.append(re.sub(r'[^\w\-\s]', '',s).split())
    sents = []
    
    for s in sents_unstopped:
        if(any(x in s for x in words) and "like" in s):
            st = []
            for w in s:
                if(w in ["his", "he", "him","tiercel","falcon"]):
                    st.append("peregrine")
                if w not in stop_words:
                    if(w=="as"):
                        st.append("as")
                    else:
                        st.append(lemma.lemmatize(w))
                sents.append(st)
    return sents

# %%
def getParts(sents):
    sent_holder = []    
    part_dict = {}
    for s in sents:
        tags = nltk.pos_tag(s)
        sholder = []
        for tag in tags:
            if(tag[1][:1] in parts):
                sholder.append(tag[0])
            part_dict[tag[0]] = tag[1]
        if(len(sholder)!=0):
            sent_holder.append(sholder)
    return part_dict

# %%
def makegraph(sents):
    G = nx.Graph()
    part_dict = getParts(sents)
    
    num_sents = len(sents)
    storelast = ""
    for s in sents:
        bigs = list(nltk.bigrams(s))
        if(len(bigs)>0):
            if sents.index(s)>0:
                G.add_edge(storelast, bigs[0][0])
            for pair in bigs:
                p0 = part_dict[pair[0]][:1]
                p1 = part_dict[pair[1]][:1]
                size0 = size=1/freqdist[pair[0]]*30+10
                size1 = size=1/freqdist[pair[1]]*30+10
                attribs=['#8c8c8c','#8c8c8c',7,7]
                if(p0 in colordict):
                    attribs[0]=colordict[p0][0]
                if(p1 in colordict):
                    attribs[1]=colordict[p1][0]
                if(pair[0] in birds):
                    attribs[0] = "blue"
                    size0 = 35
                if(pair[1] in birds):
                    attribs[1] = "blue"
                    size1 = 35                
                G.add_node(pair[0],color=attribs[0], size=size0)
                G.add_node(pair[1],color=attribs[1], size=size1)
                if("peregrine" in s):
                    edgec = "blue"
                else:
                    edgec = "red"
                G.add_edge(pair[0], pair[1],color=edgec)
            if sents.index(s)<num_sents-1:
                storelast = bigs[len(bigs)-1][1]
    return G

# %%
#Makes word frequency dictionary for entire corpus
with open(text_folder+"/hidden/the-hunting-life.txt") as file:
    filetext = file.read().lower().split()
with open(text_folder+"hidden/markov-life.txt","w") as file:
    for fn in os.listdir(text_folder):
        if(fn[0]=="_"):
            file.write(open(text_folder+fn).read()+"\n")
markovtext = open(text_folder+"hidden/markov-life.txt","r").read().lower().split()
new = filetext+markovtext
words = []
for word in new:
    if(word=="as"):
        words.append(word)
    if(word=="was"):
        words.append(word)
    else:
        words.append(lemma.lemmatize(re.sub(r'[^\w\-\s]', '', word)))
freqdist={}
for word in words:
    if word not in freqdist.keys():
        freqdist[word]=1
    else:
        freqdist[word]+=1

# %%
import os
path='../corpora/peregrine/'
filenames = os.listdir(path)
graph_dict = {}
for f in filenames:
    if(f[-3:] == "txt" and f[0]!="-"):
        filetext = open(path+f, "r").read()
        graph_dict[f[:-4]]=makegraph(getsents(filetext,1))

# %%
import os
import markovify
import numpy
import natsort
import matplotlib.pyplot as plt
text_folder = '../corpora/peregrine/'

seasons = {
    "oct" : "fall",
    "nov" : "fall",
    "dec" : "winter",
    "jan" : "winter",
    "feb" : "winter",
    "mar" : "spring",
    "apr" : "spring"
}

ss = 3

with open(text_folder+"/hidden/the-hunting-life.txt") as f:
    text = f.read()
    whole_model = markovify.Text(text, state_size=ss)

seasons_mark = {}
for season in seasons.values():
    with open(text_folder+"/hidden/seasons/"+season+".txt") as f:
        text = f.read()
        seasons_mark[season] = markovify.Text(text, state_size=ss)
    
with open(text_folder+"/hidden/first-lines.txt") as f:
    text = f.read()
    firstline_model = markovify.Text(text, state_size=ss)
    
def markovify(fn):
    import markovify
    with open(text_folder+fn) as f:
        txt = f.read()
        txt_model = markovify.Text(txt, state_size=ss)
    season_model = seasons_mark[seasons[fn[3:6]]]
    full_model = markovify.combine([whole_model, season_model,txt_model], [.2,.5,.3])
    first_model = markovify.combine([firstline_model,txt_model],[5,1])
    new_text=""
    sd = sent_data(fn)
    num_sents = sd[1][4]
    max_len = sd[1][0]
    wc = sd[1][5]
    curlen = 0
    new = first_model.make_sentence(tries=400)
    if(new!=None):
            new_text+=(new+" ")
            curlen+=(new.count(" ")+1)
    while curlen<wc+5:
        #new = text_model.make_short_sentence(max_len)
        new = full_model.make_sentence(tries=500)
        if(new!=None):
            new_text+=(new+" ")
            curlen+=(new.count(" ")+1)
    m = open(text_folder+"_"+fn, "w+")
    m.write(new_text)
    m.close()

# %%
def sent_data(filename):
    import numpy
    sent_len = []
    with open(text_folder+filename) as f:
        text = f.read().strip("\n").split(".")
        text[0]+=" "
        for sent in text:
            if(sent!=""):
                sentlen = sent.count(" ")
                sent_len.append(sentlen)
        #max sent length, min sent length, mean sent length, standard deviation on sent length, number of sents, number of words
        data = [max(sent_len), min(sent_len),sum(sent_len)/len(sent_len), numpy.std(sent_len),len(sent_len), sum(sent_len)]
    return([sent_len,data])

# %%
def plot_sents(fn):
    max_x = sent_data(fn)[1][4]
    data = sent_data(fn)[0]
    plt.bar(range(1,max_x+1),data)

# %%
test_date = "42_dec-17.txt"
markovify(test_date)
print(sent_data(test_date)[1])
print(sent_data("_"+test_date)[1])
plot_sents(test_date)
plot_sents("_"+test_date)
# Out:
# [38, 4, 15.192307692307692, 7.770849031769708, 52, 790]
# [35, 1, 17.97826086956522, 7.191447609108737, 46, 827]

# %%
for fn in os.listdir(text_folder):
    if(fn[0] not in ["_","-"] and fn[-3:]=="txt"):
        markovify(fn)

# %%
#creates the CSV metadata
dr=os.listdir(text_folder)
nr = natsort.natsorted(dr)
with open(text_folder+"peregrine.csv", "w+") as file:
    file.write("fn,season,author\n")
    for fn in nr:
        author="baker"
        month=fn[3:6]
        if(fn[-3:]=="txt"):
            if(fn[0]=="_"):
                author="markov"
                month = fn[4:7]
            elif(fn[0]=="-"):
                author="gpt-2"
                month = fn[4:7]
            file.write(fn+","+seasons[month]+","+author+"\n")
    file.close()
path_to_metadata='../corpora/peregrine/peregrine.csv'

# %%
# Get the metadata for this corpus
import pandas as pd
from textblob import TextBlob
pd.set_option("display.max_rows", 20)
import nltk

# %%
df_meta = pd.read_csv(path_to_metadata).set_index('fn')

# %%
def make_dtm(text_folder,normalize=False):

    # make an empty results list
    all_results = []
    
    columns=[]
    attrbs = ['max_sent_len','min_sent_len','mean_sent_len',
             'sd_sent_len','num_sents','num_words']
    columns.append('fn')
    for att in attrbs:
        columns.append(att)
    
    # for each filename
    filenames=sorted(os.listdir(text_folder))
    for fn in filenames:
        if(fn[-3:]=="txt"):
            text_result = {}
            text_result["fn"]=fn
            #max sent length, min sent length, mean sent length, standard deviation on sent length, number of sents, number of words
            text_result['max_sent_len']=sent_data(fn)[1][0]
            text_result['min_sent_len']=sent_data(fn)[1][1]
            text_result['mean_sent_len']=sent_data(fn)[1][2]
            text_result['sd_sent_len']=sent_data(fn)[1][3]
            text_result['num_sents']=sent_data(fn)[1][4]
            text_result['num_words']=sent_data(fn)[1][5]
        all_results.append(text_result)
            

    
    # Make dataframe
    df = pd.DataFrame(all_results, columns=columns).set_index('fn').fillna(0)
    
    # return dataframe
    return df

# %%
dtm = make_dtm(text_folder,normalize=True)
dtm_meta=df_meta.merge(dtm,on='fn')
dtm_meta = dtm_meta[dtm_meta.author !="gpt-2"]
dtm_meta
# Out:
#                 season  author  max_sent_len  min_sent_len  mean_sent_len  \
# fn
# 00_oct-1.txt      fall   baker            28             2      13.213115
# 01_oct-3.txt      fall   baker            20             2      10.000000
# 02_oct-5.txt      fall   baker            38             3      14.309524
# 03_oct-7.txt      fall   baker            44             2      15.488372
# 04_oct-8.txt      fall   baker            18             2      10.888889
# 05_oct-9.txt      fall   baker            26             2      13.000000
# 06_oct-12.txt     fall   baker            26             4      14.035714
# 07_oct-14.txt     fall   baker            26             4      10.000000
# 08_oct-15.txt     fall   baker            37             3      17.185185
# 09_oct-16.txt     fall   baker            36             7      16.840000
# ...                ...     ...           ...           ...            ...
# _81_mar-29.txt  spring  markov            32             1      16.898305
# _82_mar-30.txt  spring  markov            25             1      14.176471
# _83_mar-31.txt  spring  markov            38             1      15.769231
# _84_apr-2.txt   spring  markov            28             1      18.541667
# _85_apr-3.txt   spring  markov            32             1      16.729167
# _86_apr-4.txt   spring  markov            31             1      17.057692
# _86_apr-4.txt   spring  markov            31             1      17.057692
# _86_apr-4.txt   spring  markov            31             1      17.057692
# _86_apr-4.txt   spring  markov            31             1      17.057692
# _86_apr-4.txt   spring  markov            31             1      17.057692
#
#                 sd_sent_len  num_sents  num_words
# fn
# 00_oct-1.txt       6.606293         61        806
# 01_oct-3.txt       4.918694         31        310
# 02_oct-5.txt       7.651605         42        601
# 03_oct-7.txt       8.439586         43        666
# 04_oct-8.txt       4.550811         36        392
# 05_oct-9.txt       5.843189         28        364
# 06_oct-12.txt      5.133797         56        786
# 07_oct-14.txt      6.291757         29        290
# 08_oct-15.txt      8.515942         27        464
# 09_oct-16.txt      6.466405         25        421
# ...                     ...        ...        ...
# _81_mar-29.txt     6.759036         59        997
# _82_mar-30.txt     6.793035         17        241
# _83_mar-31.txt     7.701021         39        615
# _84_apr-2.txt      5.894766         24        445
# _85_apr-3.txt      6.057845         48        803
# _86_apr-4.txt      6.584987         52        887
# _86_apr-4.txt      6.584987         52        887
# _86_apr-4.txt      6.584987         52        887
# _86_apr-4.txt      6.584987         52        887
# _86_apr-4.txt      6.584987         52        887
#
# [178 rows x 8 columns]

# %%
def graph_data(fn,verbose=True):
    g = graph_dict[fn[:-4]]
    d = dict(nx.degree(g))
    max_degree = max(d.values())
    hubs = sorted(zip(d.values(),d.keys()), reverse=True)[:3]
    loss=_g.number_of_edges()+1-dtm_meta.at[fn,"num_words"]
    diameter = nx.diameter(g)
    center = nx.center(g)
    clustering = nx.average_clustering(g)
    #closeness = nx.closeness_centrality(g).values()
    dom_set = nx.dominating_set(g)
    max_ind = nx.maximal_independent_set(g)
    if(verbose):
        print(hubs)
        print("Loss:",loss)
        print("Diameter:",diameter)
        print("Center nodes:",center)
        print("Average clustering:", clustering)
        print("Dominating set:",dom_set)
        print("Dominating set length:",len(dom_set))
        print("Maximal independent set:",max_ind)
        print("Maximal independent set length:",len(max_ind))
    return([hubs, loss, diameter,center,dom_set,len(dom_set),max_ind,len(max_ind)])

# %%
checkfile="15_oct-28"
_g = graph_dict["_"+checkfile]
_gd = graph_data("_"+checkfile+".txt")
# Out:
# [(23, 'flew'), (15, 'wing'), (14, 'river')]
# Loss: -388
# Diameter: 15
# Center nodes: ['oclock', 'flew', 'slowly', 'three', 'relaxing', 'tension', 'ashore']
# Average clustering: 0.025679617313345903
# Dominating set: {'layered', 'seldom', 'swept', 'waddled', 'seven', 'perch', 'brown', 'tide', 'greenish-brown', 'as', 'lane', 'puff', 'match', 'roaring', 'spray', 'easily', 'shoulder', 'low', 'tower', 'uneasy', 'small', 'soon', 'brook', 'breast', 'warm', 'grip', 'turning', 'joint', 'rushed', 'water', 'valley', 'front', 'furiously', 'conventional', 'haste', 'higher', 'dunlin', 'curving', 'feel', 'glinted', 'saw', 'instantly', 'le', 'twitched', 'edge', 'looking', 'though', 'cumbersomely', 'circled', 'followed', 'walked', 'degree', 'marsh', 'ashore', 'dawn', 'safety', 'quick', 'twenty', 'left', 'gap', 'wet', 'gliding', 'sea-wall', 'heard', 'rush', 'east', 'sailed', 'suddenly', 'steeply', 'strength', 'curved', 'meadow', 'began', 'dim', 'clear', 'stone', 'smoked', 'side', 'narrowly', 'overhang', 'four', 'hill', 'slightly', 'forward', 'peregrine', 'hard', 'partridge', 'yet', 'gradually', 'turquoise', 'fly', 'sheer', 'roof', 'bone', 'air', 'behind', 'oak', 'pile', 'top', 'stained', 'upward', 'casting', 'hour', 'repeating', 'half', 'star', 'attack', 'branch', 'say', 'oxide', 'hundred', 'rust', 'glided', 'place', 'prey', 'woodland', 'slight', 'relaxing', 'sand', 'plain', 'cold', 'middle', 'darkening', 'melt', 'fast', 'crouching', 'dived', 'came', 'one', 'high', 'tawny', 'seem', 'sometimes', 'spread', 'speed', 'bent', 'looked', 'stomach', 'godwit'}
# Dominating set length: 139
# Maximal independent set: ['sky', 'struck', 'sound', 'branch', 'clay', 'air', 'merely', 'front', 'spray', 'sun', 'familiar', 'circled', 'crouching', 'twilight', 'speed', 'south', 'sunshine', 'foot', 'briefly', 'dropped', 'flying', 'sharply', 'haste', 'tree', 'though', 'gull', 'conventional', 'sudden', 'perch', 'seldom', 'glide', 'wader', 'fired', 'immediately', 'round', 'safety', 'stomach', 'wind', 'wet', 'tension', 'carpal', 'clown', 'glided', 'returned', 'sighted', 'heard', 'rust', 'half', 'floor', 'bark', 'oxide', 'crow', 'smoked', 'flicking', 'beneath', 'stone', 'kill', 'body', 'tide', 'hawk', 'beyond', 'forward', 'stopped', 'stream', 'flocked', 'flickered', 'soft', 'spread', 'fly', 'right', 'mallard', 'nothing', 'back', 'meadow', 'fell', 'tawny', 'circling', 'walked', 'turquoise', 'mimicked', 'darkened', 'degree', 'away', 'peace', 'perfectly', 'gesture', 'blind', 'greenish-brown', 'see', 'attack', 'active', 'ashore', 'top', 'minute', 'among', 'hill', 'casting', 'inland', 'edge', 'sea', 'sailed', 'winghold', 'alder', 'towards', 'steeply', 'jerking', 'brook', 'four', 'blue', 'roof', 'roaring', 'sneaking', 'whose', 'grip', 'seem', 'tiercel', 'bush', 'valley', 'curved', 'sea-wall', 'gap', 'shoulder', 'repeating', 'several', 'becoming', 'godwit', 'lane', 'puff', 'stayed', 'partridge', 'cumbersomely', 'falcon', 'plain', 'young', 'sometimes', 'hour', 'church', 'turn', 'killed', 'followed']
# Maximal independent set length: 140

# %%
g = graph_dict[checkfile]
gd = graph_data(checkfile+".txt")
# Out:
# [(10, 'like'), (10, 'hawk'), (9, 'field')]
# Loss: -371
# Diameter: 13
# Center nodes: ['inland', 'green', 'bird', 'called', 'snipe']
# Average clustering: 0.0028120087225518534
# Dominating set: {'nose', 'glare', 'splayed', 'sank', 'grass', 'hushing', 'brown', 'tide', 'rest', 'shook', 'summer', 'smelt', 'lane', 'as', 'puff', 'conveyed', 'easily', 'low', 'splashed', 'furrow', 'weaving', 'drift', 'indefinable', 'small', 'plucked', 'salting', 'warm', 'white-flecked', 'turning', 'joint', 'softly', 'hissing', 'fur', 'smouldering', 'enfolded', 'spat', 'higher', 'deepening', 'gold', 'elbow-like', 'deep', 'lowered', 'fire', 'edge', 'looking', 'though', 'could', 'leaf', 'circled', 'bird-calling', 'towards', 'elegant', 'dreary', 'smell', 'shining', 'roan-coloured', 'glitteringly', 'silent', 'left', 'wet', 'gliding', 'aroma', 'heard', 'shine', 'ducking', 'raced', 'wetness', 'thousand', 'roused', 'dropped', 'suddenly', 'brighter', 'stubble', 'across', 'called', 'crowded', 'waiting', 'midday', 'side', 'streaming', 'fierce', 'hill', 'four', 'last', 'head', 'evening', 'beer', 'pervasive', 'forward', 'sleep', 'splashing', 'near', 'hard', 'partridge', 'savagely', 'ground', 'barking', 'tiptoe', 'minute', 'dimmed', 'dart', 'sea-weed', 'blowing', 'top', 'fed', 'jewel', 'contract', 'casting', 'others', 'pure', 'limp', 'windless', 'baffled', 'menacing', 'hood', 'draught', 'hopelessly', 'swayed', 'autumn', 'drifting', 'muffled', 'among', 'sniffed', 'became', 'teal', 'yard', 'falling', 'skyline', 'outlined', 'soothed', 'roosting', 'flame', 'darkening', 'came', 'one', 'gave', 'shape', 'ebb-tide', 'heron'}
# Dominating set length: 139
# Maximal independent set: ['wader', 'huddled', 'together', 'surface', 'muffled', 'sunlit', 'sour-sweet', 'mud', 'feather', 'windless', 'last', 'trotted', 'far', 'tuft', 'wetness', 'walked', 'exhaled', 'curved', 'dreary', 'slanting', 'head', 'glitteringly', 'skyline', 'binoculars', 'heron', 'three', 'four', 'crouched', 'circled', 'soft', 'pungent', 'nutty', 'shine', 'small', 'wigeon', 'away', 'tiptoe', 'joint', 'gliding', 'aroma', 'ten', 'a', 'sea-wall', 'sniffed', 'hard', 'raced', 'waiting', 'trying', 'sharp', 'gorse', 'glare', 'flickered', 'flame', 'dim', 'within', 'estuary', 'red', 'wet', 'feed', 'higher', 'building', 'gathered', 'pervasive', 'bundled', 'cobra', 'left', 'drifted', 'became', 'beautiful', 'drifting', 'turning', 'fierce', 'grass', 'iris', 'covey', 'killed', 'day', 'beer', 'mingles', 'long', 'swished', 'splashed', 'first', 'thousand', 'alive', 'fast', 'summer', 'bird', 'hopelessly', 'snipe', 'draught', 'cutting', 'prey', 'sank', 'conveyed', 'midday', 'flew', 'rest', 'limp', 'see', 'outlined', 'warm', 'heard', 'dimmed', 'crashed', 'floated', 'bay', 'roosting', 'barbaric', 'sparrow', 'autumnal', 'briefly', 'ducking', 'loosen', 'bird-calling', 'contract', 'thrumming', 'others', 'sleek', 'still', 'amber', 'ghost', 'flake', 'near', 'white-flecked', 'human', 'leaping', 'upon', 'gave', 'deepening', 'incoming', 'warning', 'ear', 'ebb-tide', 'think', 'drier', 'wood', 'sleep', 'diminished', 'swayed', 'move', 'shook', 'brighter']
# Maximal independent set length: 143

# %%
def make_graph_dtm(text_folder,normalize=False):

    # make an empty results list
    all_results = []
    
    columns=[]

    attrbs = ['hubs','loss','diameter',
             'center','dom_set','len_dom_set','indep_set', 'len_indep_set']
    columns.append('fn')
    for att in attrbs:
        columns.append(att)
    
    # for each filename
    filenames=sorted(os.listdir(text_folder))
    for fn in filenames:
        if(fn[-3:]=="txt"):
            text_result = {}
            text_result["fn"]=fn
            gd = graph_data(fn)
            
            text_result['hubs']=gd[0]
            text_result['loss']=gd[1]
            text_result['diameter']=gd[2]
            text_result['center']=gd[3]
            text_result['dom_set']=gd[4]
            text_result['len_dom_set']=gd[5]
            text_result['indep_set']=gd[6]
            text_result['len_indep_set']=gd[7]
            all_results.append(text_result)
            
    
    # Make dataframe
    df = pd.DataFrame(all_results, columns=columns).set_index('fn').fillna(0)
    
    # return dataframe
    return df

# %%
gdtm = make_graph_dtm(text_folder,normalize=True)
gdtm_meta=df_meta.merge(gdtm,on='fn')
gdtm_meta = gdtm_meta[dtm_meta.author !="gpt-2"]
gdtm_meta
# Out:
# [(12, 'sky'), (12, 'jay'), (12, 'hawk')]
# Loss: -404
# Diameter: 14
# Center nodes: ['sky', 'alder', 'river', 'hawk', 'water', 'watching', 'blind', 'white', 'bill', 'away', 'air', 'follow', 'tractor', 'gull', 'flecked', 'know', 'drifting', 'till', 'plume', 'last', 'one', 'oclock', 'looking', 'acorn', 'wing', 'flashing', 'leaf', 'flew', 'heavily', 'flash', 'rump']
# Average clustering: 0.010928689883913763
# Dominating set: {'seldom', 'swept', 'perch', 'rest', 'mask', 'as', 'breaking', 'quickly', 'low', 'furrow', 'north', 'tree', 'life', 'lean', 'supple-winged', 'apart', 'haunted', 'small', 'moving', 'white-bannered', 'plucked', 'trip', 'swerving', 'killed', 'predatory', 'wide-open', 'turning', 'flash', 'hedge-hopped', 'drumming', 'water', 'scold', 'cool', 'bared', 'exaltation', 'flashing', 'feel', 'west', 'brilliant', 'something', 'magpie', 'oclock', 'clattering', 'deep', 'trail', 'lowered', 'seen', 'widens', 'lapwing', 'looking', 'mile', 'though', 'could', 'plume', 'cursing', 'towards', 'cirrus', 'swaying', 'flew', 'wet', 'tit', 'purring', 'heard', 'ploughing', 'bottle', 'cry', 'bright', 'across', 'meadow', 'began', 'dark', 'water-meadows', 'lopsidedly', 'spaniel', 'clear', 'bird', 'blackbird', 'southward', 'settled', 'screeching', 'pagan', 'leaving', 'lunch', 'boar', 'hill', 'four', 'misty', 'flesh', 'depth', 'harsh', 'gleaming', 'near', 'gravel', 'darkens', 'call', 'furtive', 'colour', 'sheer', 'air', 'behind', 'dazzled', 'spear', 'smelling', 'bury', 'carried', 'calling', 'hour', 'circle', 'vivid', 'rump', 'breast-bone', 'come', 'endless', 'go', 'bulging', 'ripple', 'spurted', 'stuffed', 'harvest', 'shaken', 'place', 'windfall', 'yard', 'soaring', 'jackdaw', 'crow', 'woodland', 'seemed', 'sand', 'vibrant', 'found', 'spiral', 'sink', 'hillside', 'plover', 'cold', 'mutter', 'gone', 'gluttonous', 'matt', 'purified', 'went', 'carrying', 'embedded', 'flecked', 'know', 'heron', 'watch', 'share', 'warmth', 'plough'}
# Dominating set length: 151
# Maximal independent set: ['flashing', 'wood', 'eye', 'east', 'arm', 'bright', 'tit', 'hour', 'scatter', 'follow', 'hedge-hopped', 'lunch', 'water-meadows', 'began', 'shadow', 'partridge', 'something', 'roosting', 'gone', 'behind', 'hundred', 'spine', 'mask', 'air', 'apart', 'burning', 'released', 'warmth', 'lemon', 'move', 'mouth', 'widens', 'hedge', 'bird', 'suddenly', 'field', 'thin', 'sharply', 'flesh', 'ate', 'blue', 'fit', 'ochre', 'stay', 'fovea', 'vinegary', 'wake', 'find', 'sleep', 'exaltation', 'spear', 'lurk', 'water', 'lapwing', 'swaying', 'elm', 'raw', 'high', 'kaleidoscope', 'go', 'twisting', 'hoping', 'pouring', 'mark', 'long', 'screeching', 'left', 'making', 'breast-bone', 'breaking', 'gravel', 'along', 'driver', 'human', 'splutter', 'river-bank', 'carried', 'bottle', 'found', 'shall', 'calling', 'a', 'fall', 'far', 'flash', 'steeply', 'watched', 'binoculars', 'looking', 'delicately', 'sunlight', 'glide', 'misty', 'manner', 'swallow', 'first', 'swept', 'purring', 'swathe', 'harsh', 'darkens', 'leaf', 'land', 'know', 'came', 'carrying', 'hoarding', 'one', 'distant', 'bulging', 'plume', 'harvest', 'bared', 'usual', 'jackdaw', 'fell', 'embedded', 'attack', 'north', 'rump', 'watch', 'spare', 'crescent', 'stain', 'west', 'autumn', 'back', 'hunting', 'gleaming', 'rising', 'slowly', 'threshing', 'slept', 'soaring', 'quickly', 'turning', 'leaving', 'matt', 'clear', 'spurted', 'face', 'see', 'killed', 'wide-open', 'moving', 'low', 'fascinated', 'blind']
# Maximal independent set length: 148
# [(12, 'wader'), (11, 'beach'), (10, 'sea')]
# Loss: 92
# Diameter: 14
# Center nodes: ['sun', 'sea', 'flashing', 'salting', 'wader', 'white', 'beach', 'haze', 'settled', 'shell', 'grey', 'plover', 'sanderling', 'would', 'black', 'leg', 'ran', 'swam', 'shadow', 'sank', 'shield', 'sky', 'circled', 'wing', 'billhook', 'splinter']
# Average clustering: 0.0
# Dominating set: {'slashed', 'sable', 'preening', 'cooling', 'could', 'leg', 'sea', 'sank', 'gritty', 'stick', 'redshank', 'tide', 'feed', 'a', 'swaying', 'marsh', 'shaking', 'south', 'firing', 'ran', 'skylark', 'knot', 'whistling', 'shining', 'five', 'grey', 'thick', 'aimlessly', 'way', 'apart', 'billhook', 'oystercatcher', 'small', 'sandpiper', 'salvo', 'column', 'sharp', 'salting', 'hot', 'haze', 'stolid', 'swam', 'stopped', 'behind', 'flared', 'eye', 'shield', 'rose', 'cawing', 'shooting', 'room', 'tiring', 'shell', 'called', 'watery', 'mud', 'dunlin', 'roan', 'torn', 'smaller', 'ringer', 'bird', 'bill', 'stagnant', 'rising', 'would', 'wing', 'chasing', 'moored'}
# Dominating set length: 69
# Maximal independent set: ['foal-like', 'across', 'rippling', 'beach', 'sanderling', 'plain', 'face', 'ringing', 'slowed', 'cooling', 'chasing', 'cawing', 'still', 'shredded', 'one', 'came', 'small', 'soft', 'stick', 'as', 'coast', 'wood', 'sharp', 'bill', 'surface', 'thick', 'splinter', 'fell', 'stagnant', 'ebbed', 'north', 'dusty', 'whistling', 'uneasily', 'settled', 'ringer', 'spray', 'gull', 'stood', 'five', 'sank', 'tiring', 'patient', 'heat-haze', 'could', 'smaller', 'whirling', 'gritty', 'salvo', 'pied', 'rising', 'perched', 'column', 'ripped', 'cry', 'high', 'different', 'closing', 'reflection', 'peregrine', 'skylark', 'circled', 'wing', 'shield', 'marsh', 'sleeping', 'knot', 'shining', 'stopped', 'far', 'though']
# Maximal independent set length: 71
# [(12, 'wing'), (10, 'long'), (9, 'hawk')]
# Loss: -199
# Diameter: 13
# Center nodes: ['orchard']
# Average clustering: 0.004715219421101774
# Dominating set: {'rain', 'goldfinch', 'hawk', 'rain-smoked', 'separate', 'sank', 'grass', 'fluttering', 'soil', 'wafting', 'as', 'vertical', 'earth', 'expected', 'hover', 'hovered', 'low', 'thick', 'ebbed', 'north', 'tree', 'blended', 'small', 'sandpiper', 'foot', 'red-brown', 'killed', 'six', 'bending', 'lyrical', 'owl', 'eye', 'swooped', 'turning', 'distant', 'threaded', 'sun', 'stretching', 'jerked', 'strong', 'hovering', 'deepening', 'magpie', 'waterlogged', 'clumsy', 'edge', 'hook-shaped', 'spinning', 'chiming', 'circled', 'woven', 'hug', 'straw', 'rise', 'seed', 'followed', 'touching', 'plangent', 'shining', 'steep', 'black', 'motionless', 'desolate', 'chiaroscuro', 'frog-like', 'east', 'rose', 'suddenly', 'curved', 'golden', 'dark', 'crouched', 'waiting', 'gesture', 'dim', 'tail', 'level', 'smaller', 'rising', 'staccato', 'silently', 'church', 'hiding', 'round', 'ten', 'wooded', 'grey', 'muddy', 'must', 'horizon', 'fifty', 'patch', 'river', 'calling', 'echoing', 'bugling', 'drifting', 'red-legged', 'later', 'three', 'corner', 'floated', 'day', 'slight', 'swinging', 'lowering', 'climbed', 'cross', 'sometimes', 'threshing', 'sitting', 'bent', 'web'}
# Dominating set length: 113
# Maximal independent set: ['spider', 'folded', 'bathing', 'wafting', 'nothing', 'thorny', 'time', 'crouched', 'edge', 'stubble', 'strong', 'goldfinch', 'woven', 'turning', 'yet', 'ebbed', 'chatter', 'seed', 'bound', 'plover', 'tail', 'church', 'skyline', 'spun', 'dropped', 'higher', 'dim', 'waterlogged', 'hook-shaped', 'veered', 'hovering', 'jerked', 'grey-black', 'ended', 'ten', 'thick', 'beside', 'uncurled', 'bending', 'eye', 'floated', 'green', 'hopped', 'plaintive', 'rain-cloud', 'field', 'bare', 'separate', 'straw', 'climbed', 'river', 'spinning', 'leg', 'grey', 'left', 'drifting', 'motionless', 'suddenly', 'coming', 'change', 'bent', 'owl', 'looked', 'back', 'curved', 'wooded', 'gate', 'level', 'dwindled', 'large', 'cloud', 'echoing', 'heavily', 'drenching', 'rising', 'almost', 'sun', 'ease', 'circled', 'dive', 'merely', 'fluttering', 'small', 'disturbed', 'furthest', 'clumsy', 'hear', 'grass', 'chiaroscuro', 'settled', 'half', 'came', 'desolate', 'bulky', 'must', 'bugling', 'grey-brown', 'western', 'smaller', 'stretching', 'continue', 'fifty', 'cross', 'disdainful', 'dark', 'hover', 'silently', 'north', 'threshing', 'shining', 'sank', 'sometimes', 'down-bent', 'distant', 'hug', 'pricked', 'red-legged', 'day', 'hiding', 'soil']
# Maximal independent set length: 120
# [(14, 'wing'), (8, 'peregrine'), (6, 'tail')]
# Loss: -264
# Diameter: 18
# Center nodes: ['foot', 'two', 'hundred', 'passing', 'twice', 'as', 'a', 'great', 'gave', 'touch', 'long', 'face', 'surface', 'catch', 'heron', 'day', 'hour', 'dropped', 'spiralled', 'water', 'slicing']
# Average clustering: 0.01613566781477229
# Dominating set: {'separate', 'swept', 'oddly', 'overhead', 'as', 'skylark', 'potter', 'hovered', 'breadth', 'describe', 'freed', 'tree', 'rippling', 'life', 'lawn', 'solid', 'way', 'picked', 'small', 'stoat', 'observed', 'moving', 'brook', 'teeth', 'outline', 'securely', 'flash', 'length', 'longer', 'drooping', 'beside', 'water', 'sun', 'fur', 'swiftly', 'blue', 'sear', 'keep', 'trail', 'seen', 'edge', 'smoulder', 'leg', 'hunched', 'seed', 'aimed', 'towards', 'width', 'felted', 'delicate', 'cedar', 'five', 'tree-top', 'died', 'hedge', 'gliding', 'profile', 'getting', 'thousand', 'dropped', 'live', 'hunting', 'dead', 'waiting', 'shallow', 'clear', 'neck', 'would', 'side', 'leaving', 'long-tailed', 'four', 'northern', 'grew', 'slightly', 'equal', 'forward', 'opaque', 'feeding', 'wood', 'night', 'roach', 'fox', 'furrowed', 'face', 'air', 'joined', 'behind', 'hand', 'carried', 'upward', 'hour', 'night-seeing', 'ford', 'come', 'gulp', 'blunter', 'unaware', 'second', 'slender', 'kestrel', 'later', 'whining', 'hundred', 'short', 'moss', 'day', 'breath', 'wide', 'mandible', 'kill', 'flame', 'green', 'came', 'crown', 'seem', 'helix', 'great', 'mauve', 'different', 'stopped', 'galaxy'}
# Dominating set length: 122
# Maximal independent set: ['fox', 'always', 'beneath', 'empty', 'blunter', 'missed', 'crown', 'death', 'stopped', 'gulp', 'ripple', 'brook', 'potter', 'head', 'solid', 'gliding', 'mauve', 'fur', 'a', 'rakish', 'hovered', 'kill', 'burn', 'breath', 'together', 'come', 'unfolding', 'could', 'second', 'forward', 'came', 'stood', 'stooped', 'skylark', 'felted', 'floated', 'small', 'sear', 'mandible', 'spiralled', 'flatter', 'shallow', 'ford', 'ridge', 'holding', 'minute', 'drooping', 'short', 'hundred', 'air', 'overhead', 'breadth', 'galaxy', 'face', 'green', 'nibbling', 're-appeared', 'feeding', 'flicked', 'facing', 'profile', 'seemed', 'grew', 'seem', 'never', 'long-tailed', 'often', 'leg', 'day', 'hunting', 'sign', 'live', 'stubble', 'body', 'kestrel', 'gull', 'observed', 'tree', 'le', 'beating', 'bill', 'evanescent', 'trail', 'delicate', 'slicing', 'width', 'upward', 'secondary', 'life', 'separate', 'four', 'freed', 'gone', 'hit', 'night-seeing', 'unaware', 'waiting', 'lawn', 'shone', 'swiftly', 'heavy-headed', 'hour', 'edge', 'equal', 'securely', 'flash', 'behind', 'longer', 'night', 'moss', 'died', 'thousand', 'northern', 'effect', 'front', 'rippling', 'ahead', 'tree-top', 'river', 'acorn', 'opaque']
# Maximal independent set length: 121
# [(15, 'wader'), (12, 'like'), (9, 'inland')]
# Loss: 10
# Diameter: 15
# Center nodes: ['flew', 'like', 'wader', 'small', 'facing']
# Average clustering: 0.020095473002449748
# Dominating set: {'alert', 'hawk', 'stayed', 'harmless', 'many', 'brown', 'tide', 'overhead', 'poured', 'a', 'low', 'furrow', 'gleamed', 'tree', 'pheasant', 'uneasy', 'peering', 'small', 'salting', 'foot', 'turning', 'curlew', 'water', 'sun', 'front', 'dangerous', 'nearer', 'put', 'least', 'oclock', 'snow', 'dry', 'map', 'looking', 'walked', 'towards', 'bumping', 'long', 'tilted', 'estuary', 'inching', 'crossbow', 'sea-wall', 'thousand', 'east', 'walk', 'curved', 'dead', 'battle', 'jostling', 'grew', 'indifferent', 'long-billed', 'beneath', 'peregrine', 'exist', 'grey', 'wild', 'horizon', 'behind', 'fed', 'calling', 'toy', 'soared', 'nothing', 'knot', 'chiefly', 'rained', 'hoping', 'crouching', 'asleep', 'crown', 'fog', 'facing', 'watch', 'godwit', 'horde'}
# Dominating set length: 77
# Maximal independent set: ['smarted', 'like', 'frieze', 'walked', 'grey', 'salting', 'drowsy', 'spurted', 'flapping', 'inching', 'nothing', 'circling', 'lifted', 'gleamed', 'bumping', 'greenshank', 'five', 'formed', 'listen', 'soared', 'brown', 'foot', 'crawled', 'long-billed', 'tree', 'move', 'called', 'stubble', 'three', 'poured', 'curved', 'wind', 'towards', 'hoping', 'still', 'restless', 'grew', 'two', 'asleep', 'looked', 'hawk', 'as', 'looking', 'indifferent', 'calling', 'walk', 'glided', 'high', 'lower', 'low', 'stood', 'rained', 'may', 'funnel', 'dangerous', 'tilted', 'crown', 'cut', 'making', 'many', 'glassy', 'hardened', 'chiefly', 'nearer', 'rest', 'uneasy', 'turning', 'jostling', 'dead', 'facing', 'stopped', 'chitin', 'skirling', 'falcon', 'snow', 'crossbow', 'ridge']
# Maximal independent set length: 77
# [(8, 'sun'), (8, 'like'), (6, 'jay')]
# Loss: 38
# Diameter: 17
# Center nodes: ['hid', 'shining', 'martin', 'flew', 'hawk']
# Average clustering: 0.0
# Dominating set: {'meat', 'hawk', 'stayed', 'dwindling', 'brown', 'pike', 'shook', 'a', 'smelt', 'poured', 'eleven', 'quickly', 'skylark', 'week', 'poplar', 'fumbling', 'fetid', 'north', 'drift', 'bush', 'small', 'foot', 'eye', 'distant', 'jurassic', 'larger', 'flamed', 'blue', 'curving', 'gold', 'bill', 'abound', 'bar', 'death', 'stay', 'whirled', 'edge', 'looking', 'beating', 'mobbed', 'stiffly', 'burned', 'finger', 'sunlight', 'shining', 'jet', 'frail', 'morning', 'left', 'road', 'glisten', 'steamy', 'across', 'season', 'tail', 'corona', 'bird', 'rising', 'head', 'heavy', 'partridge', 'insipid', 'hid', 'passed', 'late', 'circling', 'folly', 'found', 'martin', 'bronzed', 'cold', 'coast', 'fast', 'came', 'swamp', 'ever', 'plough'}
# Dominating set length: 77
# Maximal independent set: ['stayed', 'heat', 'week', 'inert', 'beating', 'exploit', 'bush', 'lombardy', 'sang', 'sun', 'mist-cloud', 'hawk', 'circle', 'jay', 'hid', 'death', 'passed', 'great', 'dark', 'went', 'first', 'like', 'sunlight', 'right', 'as', 'flamed', 'brown', 'circling', 'spread', 'shook', 'forward', 'coil', 'head', 'finger', 'drift', 'insipid', 'metallic', 'covey', 'looking', 'cold', 'stiffly', 'good', 'numerous', 'alternately', 'river', 'lapwing', 'flashed', 'shredded', 'red-legged', 'heavy', 'reed', 'saurian', 'afternoon', 'came', 'morning', 'downstream', 'land', 'sudden', 'poured', 'rising', 'strip', 'died', 'martin', 'thermal', 'small', 'flying', 'clenched', 'splendid', 'bill', 'burned', 'darted', 'smoke', 'corona', 'ten', 'perhaps', 'eleven']
# Maximal independent set length: 76
# [(22, 'hawk'), (16, 'crow'), (12, 'like')]
# Loss: -384
# Diameter: 15
# Center nodes: ['away', 'peregrine', 'come', 'inland', 'estuary', 'hawk', 'rose', 'circled', 'higher', 'wing', 'back', 'small', 'black', 'stone', 'fighting', 'slowly']
# Average clustering: 0.005778617595337852
# Dominating set: {'beat', 'brown', 'tide', 'rest', 'gnarled', 'as', 'eleven', 'turned', 'quickly', 'stiff', 'expected', 'low', 'easily', 'grow', 'around', 'ebbed', 'north', 'sang', 'gull', 'small', 'bee', 'laboured', 'outline', 'bleached', 'bending', 'chased', 'swooped', 'eye', 'fretted', 'becomes', 'shoal', 'valley', 'tormented', 'underside', 'feathered', 'higher', 'dunlin', 'blue', 'throughout', 'hide', 'shimmered', 'flashed', 'sleeping', 'susurrus', 'gold', 'skimming', 'southern', 'drop', 'clumsy', 'dusty', 'reached', 'beating', 'plume', 'easier', 'insect', 'towards', 'damp', 'wither', 'distance', 'look', 'finger', 'always', 'five', 'fled', 'fighting', 'breathes', 'r', 'stab', 'rush', 'thousand', 'cry', 'east', 'chase', 'suddenly', 'shiny', 'coloured', 'tangent', 'across', 'called', 'crowded', 'shallow', 'crescent', 'sending', 'height', 'stone', 'squeezed', 'midday', 'whirlwind', 'bare', 'round', 'learn', 'abundant', 'anything', 'hill', 'see', 'grew', 'inward', 'sleep', 'simply', 'big', 'partridge', 'slowed', 'deliberate', 'deeply', 'high-pitched', 'afternoon', 'stood', 'catch', 'oak', 'effect', 'surface', 'circle', 'come', 'snipey', 'chasing', 'much', 'autumn', 'violence', 'feather', 'passed', 'glided', 'prey', 'back', 'away', 'circling', 'bounce', 'barred', 'outspread', 'plover', 'bathe', 'afterwards', 'beautiful', 'gone', 'slap', 'tangling', 'wind', 'two', 'threshing', 'gave', 'sight'}
# Dominating set length: 140
# Maximal independent set: ['till', 'soaring', 'look', 'beat', 'small', 'valley', 'brown', 'expected', 'pulse', 'sleeping', 'hundred', 'gliding', 'eye', 'cry', 'insect', 'carried', 'becomes', 'tide', 'man', 'shimmered', 'back', 'susurrus', 'glittered', 'brook', 'as', 'bigger', 'glaring', 'sleep', 'big', 'eleven', 'passed', 'hill', 'two', 'dunlin', 'abundant', 'catch', 'dusty', 'inward', 'overshot', 'course', 'focus', 'horizon', 'beautiful', 'r', 'bare', 'gripped', 'learn', 'shoal', 'outline', 'distance', 'heavily', 'coloured', 'high-pitched', 'height', 'let', 'bending', 'outspread', 'dead', 'fading', 'covey', 'fast', 'violence', 'hypnotic', 'volleyed', 'skimming', 'plunging', 'sending', 'baffling', 'circled', 'stone', 'called', 'luminous', 'haze', 'eat', 'shining', 'branch', 'fog', 'hard', 'slewing', 'sinuously', 'chase', 'afterwards', 'ebbed', 'crowded', 'bathe', 'drop', 'three', 'rhythmically', 'air', 'flashed', 'stiff', 'salt', 'stab', 'sun', 'chased', 'time', 'chasing', 'simply', 'circling', 'island', 'shiny', 'glided', 'came', 'blew', 'gnarled', 'scorched', 'green', 'much', 'easily', 'plodded', 'sat', 'one', 'thousand', 'flushed', 'crescent', 'bee', 'slap', 'drifted', 'sunburnt', 'lark', 'wither', 'fish', 'funnel', 'swooped', 'tangling', 'turned', 'gave', 'feather', 'swooping', 'autumn', 'rush', 'gull', 'bleached', 'half-way', 'grew', 'fled', 'feathered', 'towards', 'come', 'snipey', 'grow']
# Maximal independent set length: 141
# [(14, 'water'), (8, 'peregrine'), (8, 'godwit')]
# Loss: 112
# Diameter: 20
# Center nodes: ['white', 'glinting', 'water', 'grey', 'plover', 'seldom', 'waggle', 'flourish', 'rococo', 'flight', 'surging']
# Average clustering: 0.007088122605363985
# Dominating set: {'seldom', 'sadness', 'zostera', 'dwindling', 'sneezing', 'tide', 'lifting', 'a', 'snuffling', 'mouthing', 'shoulder', 'flourish', 'panting', 'arched', 'grazing', 'glinting', 'eye', 'body', 'thin', 'distant', 'curlew', 'line', 'clutching', 'flight', 'blue', 'dunlin', 'gold', 'bill', 'tumbling', 'wing', 'southern', 'burning', 'greenshank', 'drowned', 'wave', 'redshank', 'finger', 'long', 'shining', 'screaming', 'silent', 'darting', 'wader-teeming', 'loud-calling', 'calm', 'land', 'shield', 'across', 'flickering', 'dark', 'widening', 'crumbling', 'still', 'round', 'head', 'call', 'pecking', 'mild', 'corkscrewing', 'diving', 'bar-tailed', 'autumn', 'smooth', 'falling', 'smoke', 'vehement', 'wigeon', 'gone', 'blazing', 'dock', 'dyke', 'one', 'elm', 'spitting', 'snipe', 'lanky', 'shape', 'following', 'sheep', 'moored'}
# Dominating set length: 80
# Maximal independent set: ['insistent', 'shuttle', 'shining', 'cropping', 'eccentric', 'surging', 'healing', 'bar-tailed', 'shrill', 'sheep', 'widening', 'spitting', 'arched', 'wing', 'curlew', 'moored', 'falling', 'cloud', 'snipe', 'gone', 'never', 'shape', 'long', 'oak', 'round', 'ricocheting', 'whole', 'glinting', 'loud-calling', 'land', 'sneezing', 'turning', 'bill', 'upon', 'dwindling', 'nettled', 'lifting', 'green', 'crumbling', 'darting', 'swooping', 'patch', 'southern', 'twenty', 'stubble', 'calm', 'wader-teeming', 'three', 'let', 'grazing', 'rare', 'heron', 'blazing', 'as', 'touch', 'flourish', 'gold', 'pecking', 'going', 'beaten', 'arm', 'seldom', 'dyke', 'turnstone', 'dark', 'blue', 'welling', 'shield', 'diving', 'thin', 'screaming', 'soft', 'sunlight', 'head', 'corkscrewing', 'drowned', 'stone', 'call', 'grey', 'tumbling']
# Maximal independent set length: 80
# [(10, 'peregrine'), (10, 'flew'), (10, 'falcon')]
# Loss: -62
# Diameter: 18
# Center nodes: ['peregrine', 'tiercel', 'falcon', 'quicker', 'plumage']
# Average clustering: 0.00895528083028083
# Dominating set: {'hawk', 'many', 'brown', 'roost', 'a', 'gather', 'quickly', 'veering', 'around', 'part', 'plumage', 'down-chopping', 'soon', 'danger', 'constantly', 'brook', 'increased', 'breast', 'foot', 'chased', 'turning', 'arrived', 'scold', 'sun', 'obviously', 'quicker', 'wingbeats', 'hovering', 'magpie', 'deep', 'wing', 'declining', 'bar', 'lapwing', 'seen', 'broomstick', 'mile', 'circled', 'dusk', 'completely', 'distance', 'towards', 'ringing', 'standing', 'laterally', 'silent', 'left', 'scattered', 'within', 'discus', 'display', 'random', 'sunset', 'rose', 'catapulting', 'hunting', 'waiting', 'angle', 'height', 'round', 'four', 'see', 'aside', 'near', 'first', 'partridge', 'sky', 'slowed', 'vanishing', 'fly', 'hawthorn', 'watched', 'tinted', 'bullfinch', 'moulting', 'hour', 'second', 'patient', 'avoided', 'eastern', 'move', 'circling', 'swooping', 'trying', 'dragging', 'came', 'turn', 'sexual', 'two', 'high', 'fog'}
# Dominating set length: 91
# Maximal independent set: ['circled', 'gave', 'hour', 'foot', 'vanishing', 'rush', 'made', 'stopped', 'waiting', 'faster', 'still', 'moustachial', 'covey', 'adult', 'began', 'round', 'sun', 'river', 'gradually', 'around', 'fog', 'area', 'high', 'wide', 'one', 'came', 'swallow', 'prominent', 'laterally', 'circling', 'sparrow', 'first', 'declining', 'trying', 'arrived', 'called', 'back', 'heron', 'flurry', 'bill', 'waited', 'display', 'slightly', 'blend', 'hunting', 'rising', 'sagging', 'near', 'fast', 'higher', 'well-thrown', 'slowed', 'gain', 'wing', 'probably', 'seemed', 'almost', 'catapulting', 'run', 'upper', 'hawthorn', 'deep', 'danger', 'close', 'chased', 'breast', 'jackdaw', 'silent', 'difficult', 'hedge', 'swooped', 'quarter', 'baggy', 'twenty', 'western', 'sexual', 'mallard', 'sometimes', 'reach', 'speed', 'winter', 'skyline', 'two', 'obviously', 'abrupt-angled', 'roost', 'without', 'sky', 'four', 'towards', 'quicker', 'tinted']
# Maximal independent set length: 92
# [(10, 'spray'), (8, 'water'), (8, 'sky')]
# Loss: -19
# Diameter: 17
# Center nodes: ['spray', 'leapt', 'wave', 'along', 'shingle', 'ridge', 'faced', 'wind', 'sun', 'lash', 'high', 'smoke', 'jetted', 'away', 'sky', 'strength', 'passed', 'north']
# Average clustering: 0.0026455026455026454
# Dominating set: {'slashed', 'hawk', 'splayed', 'grass', 'brown', 'diminishing', 'thudded', 'glittering', 'underpart', 'polished', 'roaring', 'lash', 'furrow', 'shoulder', 'arrowhead', 'low', 'rejoicing', 'gleamed', 'north', 'gull', 'small', 'plucked', 'grip', 'orange', 'straight', 'eye', 'gunner', 'sun', 'ringed', 'shimmered', 'brilliant', 'saw', 'wing', 'pain', 'dusk', 'jetted', 'lay', 'shingle', 'estuary', 'widened', 'burnt', 'hissed', 'gliding', 'sea-wall', 'white', 'faced', 'shadow', 'shudder-up', 'sunset', 'dust', 'suddenly', 'lined', 'dying', 'rising', 'side', 'streaming', 'fierce', 'northern', 'lobe', 'secondary', 'drove', 'outpouring', 'watched', 'air', 'triangle', 'tiercel', 'glided', 'knot', 'gasp', 'primary', 'cheek', 'flame', 'clouded', 'flickered', 'climbed', 'violently', 'leapt', 'heat', 'stare', 'great', 'bent', 'looked', 'human'}
# Dominating set length: 83
# Maximal independent set: ['sword', 'blowing', 'hawk', 'air', 'shape', 'ochreous', 'knew', 'grass', 'wader', 'earth', 'flinging', 'widened', 'polished', 'northern', 'colour', 'seemed', 'estuary', 'lobe', 'splayed', 'pebble', 'knot', 'calm', 'flown', 'heat', 'thudded', 'primary', 'shudder-up', 'mail', 'furrow', 'southerly', 'lay', 'tide', 'wave', 'arrowhead', 'aside', 'watched', 'gleamed', 'outpouring', 'hundred', 'waiting', 'glowed', 'rejoicing', 'secondary', 'side', 'blemish', 'clustered', 'triangle', 'plucked', 'beast', 'cheek', 'straight', 'high', 'flicking', 'strength', 'sunset', 'floating', 'small', 'dusk', 'glided', 'gasp', 'looked', 'lined', 'clouded', 'fierce', 'ringed', 'shoulder', 'darkening', 'northward', 'salt', 'hostile', 'shingle', 'field', 'stained', 'passed', 'bent', 'gliding', 'faced', 'climbed', 'dying', 'burnt', 'grip', 'away', 'marsh', 'brilliant']
# Maximal independent set length: 84
# [(15, 'flew'), (14, 'rain'), (14, 'crow')]
# Loss: -375
# Diameter: 16
# Center nodes: ['minute']
# Average clustering: 0.004533104864230692
# Dominating set: {'rain', 'slow', 'swept', 'perch', 'squeaky', 'echo', 'intent', 'overhead', 'apparently', 'as', 'puff', 'retreated', 'turned', 'quickly', 'voice', 'sleepy', 'opening', 'bush', 'soon', 'fieldfare', 'moving', 'plucked', 'dragged', 'foot', 'breast', 'challenging', 'chased', 'rushed', 'distant', 'valley', 'hurtled', 'nearer', 'pointed', 'west', 'something', 'enemy', 'cocoon', 'oclock', 'rank-spreading', 'elaborating', 'remains', 'mile', 'though', 'crackling', 'pause', 'hunched', 'followed', 'intricate', 'fifteen', 'distance', 'towards', 'downward', 'motion', 'always', 'long', 'rope', 'five', 'carefully', 'wet', 'within', 'clenching', 'eat', 'random', 'thousand', 'cry', 'water-pump', 'posture', 'dropped', 'suddenly', 'stubble', 'faint', 'dead', 'dark', 'began', 'food', 'bird', 'neck', 'breathing', 'sat', 'blackbird', 'screeching', 'four', 'grew', 'misty', 'spasmodic', 'flesh', 'forward', 'becoming', 'clearly', 'cable', 'scolding', 'far', 'knew', 'desultory', 'recognised', 'watched', 'stood', 'sidled', 'bone', 'terror', 'stubbled', 'upward', 'hour', 'net', 'mouse', 'relaxed', 'alertness', 'rasping', 'probed', 'mountain', 'steadily', 'second', 'like', 'shelter', 'three', 'alone', 'thought', 'together', 'beaky', 'keerk', 'swooping', 'quiet', 'ditch', 'rain-sodden', 'kill', 'plover', 'lowering', 'rackety', 'centre', 'tawny', 'often', 'spread', 'know', 'sick', 'berry', 'right', 'soft'}
# Dominating set length: 137
# Maximal independent set: ['faint', 'though', 'shifting', 'ring', 'till', 'crow', 'bulky', 'oak', 'five', 'know', 'rank-spreading', 'food', 'flight', 'damp', 'turned', 'air', 'stopped', 'puff', 'jackdaw', 'seek', 'jerking', 'recognised', 'cover', 'thousand', 'wide', 'monotonous', 'away', 'six', 'something', 'notched', 'bill', 'desultory', 'rasping', 'leapt', 'weir', 'heavily', 'became', 'feebler', 'knew', 'like', 'gentle', 'fifteen', 'elm', 'began', 'one', 'distance', 'mouse', 'water-pump', 'moorhen', 'followed', 'spreading', 'probed', 'sidled', 'give', 'quickly', 'bush', 'dropped', 'inclined', 'perch', 'pursuit', 'maze', 'oddity', 'apparently', 'blinding', 'long', 'plover', 'hurtled', 'place', 'rain-sodden', 'brown', 'grew', 'threatening', 'pause', 'alone', 'together', 'regularly', 'prey', 'spread', 'upon', 'die', 'moving', 'screeching', 'watching', 'sick', 'large', 'bubbly', 'cliff', 'random', 'dangling', 'harsh', 'came', 'grass', 'moved', 'released', 'front', 'side', 'carrying', 'watchful', 'kill', 'move', 'dark', 'across', 'three', 'wind', 'upward', 'plucked', 'west', 'mist', 'swooping', 'right', 'mile', 'wandered', 'serrated', 'hawthorn', 'berry', 'sold', 'cold', 'skewered', 'wire', 'thought', 'still', 'realised', 'timbre', 'drifted', 'pylon', 'safety', 'later', 'lowering', 'intent', 'stubble', 'sorted', 'crescendo']
# Maximal independent set length: 132
# [(14, 'like'), (10, 'wing'), (8, 'river')]
# Loss: -185
# Diameter: 16
# Center nodes: ['circled', 'foot', 'like', 'drifted']
# Average clustering: 0.012390670553935858
# Dominating set: {'hawk', 'anchor', 'swept', 'kale', 'brown', 'a', 'silvery', 'point', 'breaking', 'hovered', 'fish', 'veering', 'low', 'shoulder', 'north', 'tree', 'movement', 'towered', 'silhouette', 'small', 'relief', 'brook', 'moving', 'foot', 'struck', 'warm', 'killed', 'chestnut', 'breast', 'body', 'freshness', 'joint', 'water', 'sun', 'brightness', 'front', 'underside', 'higher', 'roan', 'curving', 'pointed', 'puffed', 'glinted', 'oclock', 'dashed', 'scattering', 'deep', 'wider', 'coil', 'idle', 'without', 'ripe', 'revolving', 'poised', 'long', 'south', 'sunlight', 'onto', 'five', 'merest', 'gliding', 'swung', 'yellow-rippling', 'close', 'rested', 'meadow', 'began', 'pursuit', 'thinned', 'rocked', 'iron', 'side', 'leaving', 'loosely', 'rook', 'see', 'woodpigeons', 'stoop', 'missed', 'first', 'scale', 'sky', 'flock', 'eluded', 'falcon', 'pattern', 'beyond', 'air', 'talon', 'corkscrewing', 'landed', 'net', 'size', 'mettlesome', 'cloud', 'tiercel', 'autumn', 'soared', 'later', 'shaded', 'feather', 'glided', 'never', 'spiral', 'plover', 'clay', 'leapt', 'tawny', 'facing', 'project', 'following'}
# Dominating set length: 111
# Maximal independent set: ['inwards', 'lapwing', 'flashing', 'without', 'tree', 'ray', 'wheat', 'shaded', 'hundred', 'falling', 'south', 'scale', 'put', 'neck', 'river', 'ruffling', 'tigerish', 'following', 'water', 'breast', 'mettlesome', 'began', 'iron', 'freshness', 'speckled', 'blackish', 'tumbled', 'puffed', 'blow', 'two', 'clay', 'landed', 'normally', 'first', 'woodpigeons', 'joint', 'le', 'size', 'hung', 'way', 'soared', 'hill', 'leaving', 'small', 'lengthened', 'struck', 'thinned', 'yard', 'corkscrewing', 'beneath', 'fast', 'along', 'warm', 'light', 'moment', 'swaying', 'poised', 'tawny', 'project', 'coil', 'swept', 'fleece', 'shining', 'low', 'yellow-rippling', 'glide', 'movement', 'air', 'northern', 'sailed', 'silvery', 'boat', 'languidly', 'apart', 'tiercel', 'fell', 'rich', 'gliding', 'fish', 'five', 'goshawk', 'autumn', 'twisting', 'partridge', 'silhouette', 'hunched', 'facing', 'rocked', 'feint', 'east', 'relief', 'think', 'brightness', 'later', 'golden-brown', 'pursuit', 'underside', 'roan', 'never', 'forward', 'deep', 'swung', 'followed', 'drooping', 'plover', 'higher', 'brook', 'splendid', 'thousand', 'oclock', 'kale', 'reaching']
# Maximal independent set length: 112
# [(8, 'starling'), (8, 'river'), (8, 'peregrine')]
# Loss: 59
# Diameter: 13
# Center nodes: ['gull']
# Average clustering: 0.0
# Dominating set: {'neighbour', 'rarer', 'autumn', 'hawk', 'launched', 'greenshank', 'circled', 'opposite', 'many', 'migrating', 'seven', 'ridge', 'misty', 'like', 'overhead', 'a', 'three', 'long', 'producing', 'migrant', 'quickly', 'succeeded', 'sunlight', 'call', 'risen', 'part', 'north', 'circling', 'opening', 'left', 'uneasy', 'interval', 'wood', 'gull', 'small', 'fieldfare', 'inevitable', 'foot', 'mimicked', 'north-westward', 'arrive', 'steeply', 'golden', 'sun', 'deceived', 'circle', 'hour', 'endlessly', 'twentieth', 'water-meadows', 'one', 'throughout', 'clear', 'drifted', 'oclock', 'faithfully', 'blackbird', 'probably', 'wing', 'glide', 'seize', 'tiercel', 'round'}
# Dominating set length: 63
# Maximal independent set: ['emerged', 'along', 'many', 'opposite', 'believe', 'throughout', 'coast', 'back', 'flew', 'wing', 'may', 'hoping', 'woodpigeons', 'glided', 'till', 'recorded', 'fieldfare', 'arrive', 'inevitable', 'went', 'succeeded', 'twitched', 'call', 'fifty', 'hawthorn', 'three', 'rarer', 'one', 'like', 'thousand', 'perfectly', 'risen', 'hidden', 'since', 'ford', 'saw', 'as', 'rose', 'neighbour', 'bill', 'part', 'autumn', 'far', 'soared', 'seven', 'come', 'followed', 'north', 'sunset', 'travelling', 'long', 'small', 'launched', 'actually', 'clear', 'golden', 'drifted', 'much', 'also', 'twelve', 'sound', 'round', 'made', 'misty', 'mimicked', 'glide']
# Maximal independent set length: 66
# [(10, 'gull'), (9, 'river'), (6, 'went')]
# Loss: -32
# Diameter: 27
# Center nodes: ['peregrine', 'went']
# Average clustering: 0.012216694306246544
# Dominating set: {'hawk', 'copper', 'sadness', 'swept', 'brown', 'tide', 'roost', 'a', 'driving', 'lane', 'buttercup', 'turned', 'stiff', 'north', 'tree', 'confluence', 'lean', 'quite', 'well-sited', 'gull', 'small', 'plucked', 'ploughland', 'turning', 'distant', 'water', 'valley', 'cool', 'furiously', 'hysteria', 'swiftly', 'flight', 'mob', 'bill', 'saw', 'scattering', 'wing', 'le', 'reached', 'leaf', 'dusk', 'eaten', 'towards', 'reservoir', 'morning', 'felled', 'stripe', 'cover', 'two-hundred-foot', 'curved', 'shooting', 'hunting', 'serious', 'returned', 'whether', 'blackbird', 'ten', 'four', 'head', 'impossible', 'brimmed', 'beneath', 'near', 'peregrine', 'main', 'tall', 'interval', 'confused', 'underwing', 'light', 'golden-yellow', 'inland', 'mud', 'whiteness', 'protruding', 'triangle', 'formation', 'kestrel', 'nothing', 'later', 'ready', 'scooped-out', 'folded', 'quiet', 'barred', 'unusually', 'plover', 'large'}
# Dominating set length: 88
# Maximal independent set: ['place', 'turning', 'brittle', 'hysteria', 'mud', 'underwing', 'pale', 'black-headed', 'left', 'high', 'wing', 'folded', 'lean', 'shooting', 'estuary', 'drew', 'judge', 'four', 'morning', 'confused', 'triangle', 'quiet', 'flight', 'stiff', 'grey', 'beginning', 'attempt', 'perched', 'menacing', 'tall', 'distant', 'two-hundred-foot', 'since', 'clamouring', 'main', 'stooping', 'head', 'flew', 'eaten', 'wet', 'glaring', 'sunrise', 'saw', 'furiously', 'curved', 'small', 'scooped-out', 'calm', 'nothing', 'twenty', 'protruding', 'hour', 'feather', 'bill', 'close', 'blackbird', 'v', 'shone', 'brown', 'ten', 'lower', 'wood', 'brimmed', 'another', 'wholly', 'much', 'air', 'attack', 'glided', 'woodpigeons', 'low', 'beneath', 'reservoir', 'barred', 'clutch', 'interval', 'a', 'moustachial', 'foot', 'muffled', 'away', 'tiercel', 'buttercup', 'golden-yellow', 'going', 'lay', 'settled', 'hidden', 'drab']
# Maximal independent set length: 89
# [(14, 'flew'), (13, 'gull'), (10, 'like')]
# Loss: -330
# Diameter: 22
# Center nodes: ['field', 'silent', 'misty', 'peregrine', 'brown', 'earth', 'colour', 'around', 'rising', 'wing', 'greyness', 'made', 'without', 'effort', 'many', 'bird', 'stooped', 'cream']
# Average clustering: 0.011394711075222257
# Dominating set: {'slashed', 'layered', 'closed', 'slow', 'pattered', 'easy', 'many', 'hundred-foot', 'dull', 'roost', 'changed', 'jab', 'headed', 'climb', 'shook', 'sweet', 'as', 'turned', 'quickly', 'skylark', 'spray', 'earth', 'panic', 'shoulder', 'odd', 'silkily', 'tree', 'pheasant', 'five-hundred', 'enough', 'way', 'broad', 'small', 'soon', 'unable', 'chased', 'swoop', 'straight', 'thinly', 'turning', 'joint', 'form', 'rushed', 'wing-bars', 'partial', 'many-jointed', 'jumping', 'obviously', 'underside', 'higher', 'flashed', 'hit', 'gold', 'le', 'without', 'oval', 'axillaries', 'mile', 'could', 'bunting', 'followed', 'bird-calling', 'towards', 'clutched', 'mounting', 'rhythm', 'five', 'horse', 'matched', 'silent', 'wet', 'dodged', 'redwing', 'sea-wall', 'dodge', 'swung', 'black', 'shadow', 'greyness', 'cream', 'east', 'eventually', 'vigorous', 'golden', 'across', 'called', 'marking', 'dark', 'leaning', 'blackbird', 'sculling', 'clawed', 'evaded', 'got', 'jay', 'head', 'last', 'transform', 'dropping', 'hard', 'call', 'shade', 'dog', 'furtive', 'fly', 'backwards', 'afternoon', 'moved', 'behind', 'several', 'flying', 'acorn', 'carried', 'rustling', 'hour', 'repeatedly', 'mud', 'merely', 'viciously', 'chasing', 'tiercel', 'drifting', 'glided', 'corner', 'surged', 'never', 'jackdaw', 'jinking', 'found', 'hidden', 'quiet', 'hexagon', 'cold', 'flickered', 'seeing', 'silver', 'snipe', 'shone'}
# Dominating set length: 138
# Maximal independent set: ['east', 'till', 'feeding', 'jackdaw', 'none', 'called', 'hexagon', 'rhythm', 'rising', 'method', 'flew', 'way', 'frozen', 'tried', 'wood', 'hard', 'blind', 'worrying', 'found', 'river', 'abruptly', 'primary', 'evaded', 'hind', 'pheasant', 'dodged', 'bird-calling', 'sheen', 'leaning', 'past', 'knew', 'veered', 'small', 'behind', 'movement', 'hidden', 'across', 'sculling', 'layered', 'vulnerable', 'attack', 'without', 'throat', 'ground-level', 'silkily', 'easy', 'slash', 'turn', 'spray', 'sun', 'vertical', 'spiralling', 'matched', 'quickly', 'peered', 'like', 'direction', 'many', 'greyness', 'mile-long', 'closed', 'grey', 'joint', 'seeing', 'as', 'pattered', 'hedge', 'transform', 'surged', 'open', 'long', 'island', 'minute', 'sang', 'partial', 'wing-bars', 'acorn', 'frightening', 'whistled', 'got', 'came', 'stubble', 'followed', 'shook', 'attempt', 'gold', 'hour', 'backwards', 'patch', 'surface', 'supple', 'darting', 'dropping', 'mile', 'drifting', 'cream', 'could', 'breast', 'never', 'sea-wall', 'shadow', 'armpit', 'earth', 'enough', 'repeatedly', 'eventually', 'glide', 'along', 'buzzed', 'call', 'blackbird', 'mud', 'still', 'jinking', 'two', 'golden', 'corner', 'immediately', 'lasted', 'slashed', 'last', 'flickered', 'afterwards', 'gone', 'suddenly', 'chasing', 'south', 'path', 'broad', 'underside', 'dry', 'lithe', 'either', 'obviously', 'silent', 'corn', 'merely']
# Maximal independent set length: 137
# [(10, 'like'), (10, 'hawk'), (9, 'field')]
# Loss: -371
# Diameter: 13
# Center nodes: ['inland', 'green', 'bird', 'called', 'snipe']
# Average clustering: 0.0028120087225518534
# Dominating set: {'nose', 'glare', 'splayed', 'sank', 'grass', 'hushing', 'brown', 'tide', 'rest', 'shook', 'summer', 'smelt', 'lane', 'as', 'puff', 'conveyed', 'easily', 'low', 'splashed', 'furrow', 'weaving', 'drift', 'indefinable', 'small', 'plucked', 'salting', 'warm', 'white-flecked', 'turning', 'joint', 'softly', 'hissing', 'fur', 'smouldering', 'enfolded', 'spat', 'higher', 'deepening', 'gold', 'elbow-like', 'deep', 'lowered', 'fire', 'edge', 'looking', 'though', 'could', 'leaf', 'circled', 'bird-calling', 'towards', 'elegant', 'dreary', 'smell', 'shining', 'roan-coloured', 'glitteringly', 'silent', 'left', 'wet', 'gliding', 'aroma', 'heard', 'shine', 'ducking', 'raced', 'wetness', 'thousand', 'roused', 'dropped', 'suddenly', 'brighter', 'stubble', 'across', 'called', 'crowded', 'waiting', 'midday', 'side', 'streaming', 'fierce', 'hill', 'four', 'last', 'head', 'evening', 'beer', 'pervasive', 'forward', 'sleep', 'splashing', 'near', 'hard', 'partridge', 'savagely', 'ground', 'barking', 'tiptoe', 'minute', 'dimmed', 'dart', 'sea-weed', 'blowing', 'top', 'fed', 'jewel', 'contract', 'casting', 'others', 'pure', 'limp', 'windless', 'baffled', 'menacing', 'hood', 'draught', 'hopelessly', 'swayed', 'autumn', 'drifting', 'muffled', 'among', 'sniffed', 'became', 'teal', 'yard', 'falling', 'skyline', 'outlined', 'soothed', 'roosting', 'flame', 'darkening', 'came', 'one', 'gave', 'shape', 'ebb-tide', 'heron'}
# Dominating set length: 139
# Maximal independent set: ['watch', 'sour-sweet', 'splayed', 'shining', 'shine', 'near', 'understand', 'left', 'burned', 'sea-weed', 'hill', 'silent', 'partridge', 'flew', 'roan-coloured', 'blowing', 'hunted', 'fire', 'forward', 'as', 'day', 'heron', 'splashing', 'stoop', 'sleek', 'elm', 'thousand', 'crowded', 'unchanging', 'wet', 'small', 'salt', 'hissing', 'sound', 'elbow-like', 'gorse', 'iris', 'sunlit', 'sank', 'short-eared', 'light', 'called', 'brush', 'among', 'three', 'drier', 'teal', 'towards', 'curved', 'warm', 'tiptoe', 'dusk', 'though', 'stubble', 'along', 'round', 'rocked', 'dripping', 'midday', 'could', 'circled', 'darting', 'falling', 'shape', 'darkening', 'furrow', 'nostalgic', 'float', 'drift', 'raced', 'dart', 'streaming', 'nutty', 'joint', 'softly', 'higher', 'dropped', 'lowered', 'ear', 'windless', 'drifting', 'pure', 'flickered', 'conveyed', 'hopelessly', 'looking', 'deep', 'within', 'ten', 'shadow', 'dimmed', 'barbaric', 'building', 'across', 'brown', 'hood', 'roused', 'sleep', 'mist', 'rest', 'suddenly', 'plucked', 'cheese', 'white-flecked', 'grass', 'glitteringly', 'heard', 'smelt', 'autumnal', 'warning', 'far', 'splashed', 'fed', 'elegant', 'dog', 'walked', 'stood', 'exhaled', 'head', 'fixed', 'last', 'swayed', 'ebb-tide', 'brighter', 'one', 'human', 'beating', 'contract', 'savagely', 'side', 'sparrow', 'gave', 'bill', 'slanting', 'bird-calling', 'aimlessly']
# Maximal independent set length: 136
# [(8, 'river'), (8, 'hawk'), (8, 'flew')]
# Loss: -4
# Diameter: 17
# Center nodes: ['oclock', 'sky', 'as', 'a', 'domed', 'white', 'spiralling', 'hawk', 'kill']
# Average clustering: 0.0
# Dominating set: {'hawk', 'slow', 'seldom', 'stayed', 'brown', 'fluttering', 'dull', 'overhead', 'a', 'earth', 'furrow', 'low', 'around', 'north', 'tree', 'searched', 'spend', 'gull', 'glinting', 'danger', 'eagle', 'warm', 'chased', 'bounding', 'downstream', 'volley', 'lying', 'flight', 'higher', 'wing', 'remains', 'fire', 'looking', 'circled', 'early', 'unmistakable', 'straw', 'dusk', 'completely', 'towards', 'look', 'domed', 'five', 'hedge', 'repeated', 'flicking', 'thousand', 'cover', 'steeply', 'across', 'heavily', 'clear', 'sat', 'dung-heap', 'woodpigeons', 'heavy', 'feeding', 'minute', 'must', 'darkened', 'fear', 'bone', 'sparrow', 'ignoring', 'lithe', 'three', 'away', 'together', 'shiny-solid', 'smoke', 'clod', 'almost', 'gaze', 'one', 'two', 'mobbing', 'wind', 'snake', 'strained', 'looked', 'plough'}
# Dominating set length: 81
# Maximal independent set: ['away', 'black-brown', 'wind', 'lithe', 'late', 'lying', 'domed', 'unmistakable', 'straw', 'swooped', 'looking', 'spend', 'almost', 'edge', 'volley', 'spiralling', 'warm', 'brown', 'dozen', 'clear', 'wood', 'a', 'sun', 'grey', 'game', 'skirmishing', 'dull', 'hunger', 'stayed', 'smoke', 'kill', 'snake', 'higher', 'blood', 'fear', 'rose', 'carrying', 'following', 'darkened', 'found', 'sliced', 'one', 'circled', 'ignoring', 'dusk', 'dancing', 'must', 'dare', 'three', 'along', 'fire', 'bit', 'peering', 'closer', 'strained', 'heavy', 'searched', 'bone', 'eagle', 'bathing', 'sparrow', 'overhead', 'post', 'teeth', 'common', 'mile', 'tired', 'woodpigeons', 'thousand', 'later', 'completely', 'woodland', 'feeding', 'across', 'sight', 'together', 'ten', 'ground', 'big', 'cover', 'plunged', 'chasing', 'curved', 'air']
# Maximal independent set length: 84
# [(6, 'wind'), (6, 'marsh'), (6, 'leaf')]
# Loss: 19
# Diameter: 17
# Center nodes: ['small', 'brown', 'like', 'priest', 'fell']
# Average clustering: 0.0
# Dominating set: {'rain', 'brown', 'peculiar', 'sad', 'lifting', 'pierced', 'a', 'pasture', 'roaring', 'spray', 'swan', 'north', 'tree', 'spanned', 'ploughland', 'lovely', 'swerving', 'breast', 'killed', 'broken', 'eye', 'body', 'curlew', 'flitted', 'return', 'wing', 'death', 'southern', 'dry', 'greasy', 'frozen', 'reached', 'lived', 'distance', 'flew', 'shivered', 'sunlight', 'shining', 'hedge', 'pied', 'land', 'charred', 'east', 'jagged', 'suddenly', 'lift', 'across', 'bird', 'cheerful', 'bleak', 'fallen', 'upon', 'see', 'sound', 'ended', 'headland', 'grey', 'brindled', 'drove', 'yet', 'lark', 'desolation', 'diminishes', 'top', 'change', 'wasted', 'void', 'parish', 'fan', 'gale', 'handling', 'wind-shred', 'lifted', 'autumn', 'branch', 'peace', 'passed', 'descend', 'wigeon', 'shone'}
# Dominating set length: 80
# Maximal independent set: ['silver', 'estuary', 'headland', 'heavy', 'dry', 'change', 'quiet', 'drifting', 'glittered', 'gone', 'sun', 'return', 'valley', 'swerving', 'river-shining', 'reached', 'lifted', 'wasted', 'drenching', 'wall', 'descend', 'one', 'swallow', 'rose', 'sound', 'autumn', 'curlew', 'upon', 'bleak', 'among', 'spanned', 'faint', 'went', 'black', 'neck', 'pied', 'as', 'fan', 'nothing', 'lined', 'lifting', 'seemed', 'peregrine', 'wind', 'distance', 'slope', 'till', 'bone', 'wing', 'day', 'swan', 'sky', 'damp', 'across', 'branch', 'land', 'rot', 'yet', 'bending', 'far', 'loneliness', 'frozen', 'laid', 'roaring', 'small', 'narrow', 'charred', 'coast', 'breast', 'reed', 'divine', 'wintry', 'stank', 'stubbled', 'parish', 'wind-shred', 'merlin', 'furrow']
# Maximal independent set length: 78
# [(12, 'wing'), (10, 'like'), (8, 'shone')]
# Loss: -182
# Diameter: 17
# Center nodes: ['peregrine', 'sank', 'blue', 'sky', 'circled', 'like', 'together', 'face', 'tree', 'brook', 'willing', 'alarm', 'wader', 'flung', 'polished', 'wood']
# Average clustering: 0.0009484154522322461
# Dominating set: {'rain', 'flung', 'greater', 'sank', 'horseman', 'seven', 'stayed', 'fluttering', 'tide', 'overhead', 'deep-voiced', 'as', 'rounded', 'polished', 'quickly', 'earth', 'hovered', 'warrior', 'north', 'fieldfare', 'brook', 'ploughland', 'chestnut', 'free', 'eye', 'outer', 'thin', 'rusty-red', 'sun', 'open', 'beech', 'flight', 'higher', 'spring', 'put', 'noble', 'angling', 'glinted', 'dashed', 'deep', 'le', 'bar', 'lapwing', 'edge', 'fire', 'heading', 'could', 'circled', 'opened', 'followed', 'long', 'south', 'lombardy', 'striped', 'rushing', 'freedom', 'inner', 'gliding', 'white', 'sixty', 'merged', 'squawked', 'approach', 'land', 'flocked', 'stubble', 'golden', 'ochreous', 'dead', 'shallow', 'began', 'perhaps', 'returned', 'scull', 'submerged', 'silently', 'side', 'bleak', 'upon', 'inclined', 'depth', 'gravel', 'towering', 'willow', 'sky', 'savagely', 'meet', 'leaping', 'sun-dazzle', 'falcon', 'hawthorn', 'stood', 'grained', 'swirled', 'clenched', 'pigeon', 'half-past', 'golden-yellow', 'gun', 'directly', 'cloud', 'power', 'autumn', 'hid', 'flamboyantly', 'passed', 'place', 'move', 'back', 'rim', 'lightly', 'seemed', 'outlined', 'brilliance', 'fist', 'fast', 'two'}
# Dominating set length: 117
# Maximal independent set: ['ploughland', 'chestnut', 'open', 'leaping', 'land', 'shallow', 'shooting', 'sun-dazzle', 'south', 'mud', 'rushing', 'seven', 'steady', 'pliant', 'inner', 'marsh', 'flocked', 'duck', 'polished', 'watching', 'careless', 'tree', 'bar', 'flamboyantly', 'golden-yellow', 'deep', 'squawked', 'shaded', 'gleamed', 'stained', 'horseman', 'edge', 'fore-shortened', 'far', 'firm', 'side', 'descended', 'drifted', 'spring', 'fluttering', 'hundred', 'approach', 'tawny', 'branch', 'great', 'leaf', 'bright', 'clenched', 'seemed', 'golden-red', 'carried', 'poplar', 'skin', 'tide', 'sixty', 'flight', 'submerged', 'black', 'meet', 'flew', 'move', 'lashed', 'merged', 'shower', 'followed', 'long', 'heading', 'constellation', 'fast', 'grew', 'rainbow', 'place', 'depth', 'stayed', 'lapwing', 'floated', 'bloomed', 'went', 'shining', 'warrior', 'finely', 'coast', 'scull', 'silver', 'stubble', 'wader', 'willow', 'feed', 'crash', 'snipe', 'plover', 'light', 'dipped', 'returned', 'suddenly', 'inclined', 'directly', 'white', 'hovered', 'island', 'outer', 'upon', 'glaring', 'angling', 'fist', 'willing', 'cold', 'sank', 'later', 'quickly', 'opened', 'rounded', 'smoke', 'le', 'curled', 'one', 'shedding']
# Maximal independent set length: 117
# [(7, 'hovered'), (6, 'like'), (6, 'hovering')]
# Loss: 58
# Diameter: 19
# Center nodes: ['cold', 'glare', 'distance']
# Average clustering: 0.001916376306620209
# Dominating set: {'nine', 'burning', 'glare', 'new', 'cock', 'hawk', 'patient', 'seldom', 'could', 'sank', 'stayed', 'grass', 'brown', 'rabbit', 'followed', 'head', 'scuffle', 'a', 'wind-whipped', 'closer', 'flailing', 'peregrine', 'flew', 'yard', 'every', 'safety', 'sky', 'copper-red', 'crest', 'ice', 'nap', 'velvet', 'minute', 'white', 'moving', 'plucked', 'outspread', 'foot', 'iridescence', 'bleached', 'cleaned', 'alighting', 'skin', 'talon', 'eye', 'seething', 'blown', 'foaming', 'sunset', 'dropped', 'suddenly', 'rose', 'drake', 'flying', 'water', 'snip', 'hunting', 'sun', 'hissing', 'fur', 'hour', 'strongly', 'strong', 'pursuing', 'winged', 'bottom', 'ignominious', 'leaning', 'stone', 'deep', 'church', 'side', 'steadily', 'creek', 'keep', 'crumpled'}
# Dominating set length: 76
# Maximal independent set: ['keep', 'came', 'sea-wall', 'suddenly', 'skin', 'alighting', 'brown', 'also', 'iridescence', 'stone', 'grass', 'luminous', 'heavy', 'snip', 'falcon', 'blue', 'nap', 'glory', 'dropped', 'pursuing', 'chrome', 'velvet', 'probably', 'across', 'tree', 'sea', 'shadow', 'north-west', 'leaving', 'smouldered', 'plucked', 'creek', 'drake', 'ran', 'steadily', 'flew', 'turquoise', 'fur', 'sky', 'wall', 'ditch', 'time', 'glare', 'rested', 'foot', 'outspread', 'strongly', 'as', 'hare', 'sunset', 'yard', 'moving', 'scuffle', 'mile', 'horizon', 'patient', 'talon', 'bending', 'bla-zoned', 'ignominious', 'firework', 'strong', 'deep', 'neatly', 'could', 'bleached', 'refuge', 'blown', 'minute']
# Maximal independent set length: 69
# [(21, 'like'), (10, 'sky'), (10, 'hawk')]
# Loss: -302
# Diameter: 16
# Center nodes: ['sky']
# Average clustering: 0.010648623957976477
# ...
# Maximal independent set length: 162
# [(6, 'wing'), (6, 'wind'), (5, 'sun')]
# Loss: 161
# Diameter: 19
# Center nodes: ['as', 'sun', 'sea', 'rising']
# Average clustering: 0.0
# Dominating set: {'rain', 'edge', 'branch', 'swept', 'sea', 'head', 'like', 'lobe', 'feed', 'feather', 'a', 'forward', 'incisive', 'year', 'needle', 'storm', 'south', 'scolding', 'thought', 'grey', 'first', 'big', 'chaffinch', 'trap-door', 'sky', 'north', 'sang', 'pond', 'starred', 'sandpiper', 'minute', 'foot', 'swerving', 'chased', 'feeling', 'joint', 'bird-clouds', 'wing-bars', 'upward', 'high', 'inland', 'dipping', 'underside', 'banked', 'woodpecker', 'drifted', 'angling', 'endless', 'bill', 'compact', 'bristling', 'lifted'}
# Dominating set length: 52
# Maximal independent set: ['chased', 'twisting', 'rounded', 'rising', 'day', 'scolding', 'pointing', 'called', 'vertically', 'wing-bars', 'finch', 'fast', 'pond', 'cedar', 'high', 'needle', 'wasted', 'bristling', 'lifted', 'descending', 'sandpiper', 'highest', 'began', 'thought', 'starred', 'power', 'carpal', 'inland', 'bird-clouds', 'long', 'foot', 'east', 'north', 'lobe', 'moved', 'angling', 'made', 'feather', 'chaffinch', 'feeling', 'like', 'first', 'minute', 'year', 'edge', 'seem', 'sang', 'light', 'incisive', 'a', 'drifted']
# Maximal independent set length: 51
# [(11, 'went'), (10, 'wind'), (10, 'like')]
# Loss: -213
# Diameter: 14
# Center nodes: ['came', 'across', 'back', 'dead', 'left', 'brook']
# Average clustering: 0.0
# Dominating set: {'chalk', 'sprayed', 'muscle', 'sacrifice', 'hawk', 'swept', 'sea', 'gashed', 'brown', 'climb', 'soiled', 'a', 'pulled', 'eye-level', 'quickly', 'shoulder', 'hovered', 'clockwise', 'blew', 'bronze', 'gleamed', 'tree', 'north', 'drift', 'movement', 'gull', 'small', 'eighty', 'fieldfare', 'brook', 'closely', 'foot', 'warm', 'killed', 'eye', 'drumming', 'impetus', 'fawn', 'valley', 'beech', 'feathery', 'dipping', 'blue', 'roan', 'tilting', 'southern', 'twelve', 'nostril', 'seen', 'remains', 'orchard', 'pause', 'leg', 'completely', 'towards', 'damp', 'shining', 'speck', 'matched', 'south-east', 'made', 'steep', 'gliding', 'faced', 'black', 'monotonous', 'land', 'mantle', 'immediately', 'frog-like', 'east', 'rose', 'golden', 'meadow', 'returned', 'tail', 'exultant', 'dying', 'blackbird', 'held', 'church', 'astonished', 'ten', 'gently', 'see', 'woodpigeons', 'near', 'scolding', 'far', 'flock', 'emerged', 'outstretched', 'face', 'descent', 'tinted', 'oak', 'half', 'post', 'endless', 'escape', 'alternately', 'due', 'three', 'ready', 'wall', 'field', 'till', 'perched', 'v', 'reflecting', 'one', 'pulse', 'man'}
# Dominating set length: 113
# Maximal independent set: ['back', 'dipping', 'right', 'air', 'v', 'shape', 'skyline', 'bulging', 'steep', 'church', 'fawn', 'south', 'carrying', 'narrowly', 'dropped', 'shining', 'dying', 'gliding', 'came', 'whiteness', 'well', 'bronze', 'pulse', 'gleamed', 'damp', 'face', 'leave', 'fed', 'north', 'blackbird', 'perched', 'climb', 'light', 'flock', 'kept', 'held', 'neck', 'coast', 'east', 'north-east', 'moved', 'reflection', 'hour', 'eighty', 'leaf', 'sat', 'surface', 'throat', 'three', 'nostril', 'cross', 'dead', 'woodpigeons', 'scolding', 'mist', 'speck', 'trying', 'hawk', 'land', 'yard', 'bird', 'lit', 'round', 'falling', 'made', 'sparrowhawk', 'a', 'immediately', 'hiding', 'landed', 'maze', 'inland', 'stable', 'movement', 'tilting', 'seem', 'time', 'long', 'could', 'estuary', 'tinted', 'smoke', 'drumming', 'drifting', 'across', 'gaping', 'deepest', 'muscle', 'golden', 'ten', 'feathery', 'earth', 'blew', 'astonished', 'leg', 'yet', 'faced', 'fieldfare', 'quickly', 'half', 'watched', 'sometimes', 'till', 'along', 'calm', 'twenty', 'dark', 'thin', 'monotonous', 'roan', 'secondary', 'rose', 'reached', 'black-headed']
# Maximal independent set length: 114
# [(11, 'sky'), (10, 'wind'), (8, 'like')]
# Loss: -43
# Diameter: 20
# Center nodes: ['see', 'hawk', 'higher', 'perch', 'elm', 'looked', 'greener', 'seldom']
# Average clustering: 0.007848788638262322
# Dominating set: {'rain', 'flung', 'muscle', 'slow', 'hawk', 'seldom', 'swept', 'many', 'perch', 'brown', 'pierced', 'a', 'lane', 'breaking', 'hovered', 'low', 'grow', 'tree', 'gull', 'moving', 'foot', 'owl', 'sunrise', 'turning', 'water', 'wish', 'sun', 'exaltation', 'scratched', 'return', 'tangle', 'curious', 'wing', 'arrow', 'lapwing', 'leaf', 'circled', 'dusk', 'drenched', 'closer', 'migrant', 'smell', 'five', 'made', 'shine', 'white', 'sweeping', 'land', 'silence', 'close', 'suspicious', 'east', 'learnt', 'sailed', 'rested', 'rose', 'shiny', 'hunting', 'bird', 'side', 'making', 'indifferent', 'wheatear', 'near', 'sound', 'attacked', 'vigorously', 'torrent', 'surface', 'pigeon', 'another', 'drifted', 'branch', 'day', 'field', 'away', 'slowly', 'dazzling', 'came', 'turn', 'seem', 'great', 'ring'}
# Dominating set length: 83
# Maximal independent set: ['singing', 'away', 'foot', 'reddish-gold', 'later', 'stopped', 'wing-beats', 'white', 'wake', 'flowed', 'smell', 'vigorously', 'sailed', 'way', 'branch', 'close', 'moment', 'dead', 'sudden', 'water', 'sweeping', 'higher', 'melting', 'turn', 'seem', 'thistle', 'brown', 'bleating', 'circling', 'fly', 'see', 'kept', 'another', 'dusk', 'rested', 'grow', 'circled', 'laugh', 'gained', 'wheatear', 'bite', 'perched', 'come', 'shiny', 'distant', 'deer', 'wedged', 'serenity', 'attacked', 'lower', 'learnt', 'side', 'owl', 'frozen', 'rose', 'scratched', 'gone', 'hunting', 'east', 'four', 'a', 'swept', 'lane', 'spread', 'soar', 'song', 'indifferent', 'great', 'pigeon', 'return', 'made', 'drenched', 'march', 'even', 'shared', 'bush', 'furrow', 'dazzling', 'went', 'day', 'shine', 'watched', 'land', 'seldom', 'rain', 'ascension']
# Maximal independent set length: 86
# [(14, 'flew'), (12, 'tree'), (12, 'hawk')]
# Loss: -401
# Diameter: 13
# Center nodes: ['sun', 'across']
# Average clustering: 0.008947004031749793
# Dominating set: {'nine', 'switchbacking', 'sea', 'stayed', 'many', 'perch', 'grass', 'tide', 'overhead', 'rest', 'as', 'eleven', 'turned', 'quickly', 'skylark', 'tremulously', 'trust', 'north', 'jerking', 'renewing', 'way', 'peering', 'quite', 'small', 'moving', 'salting', 'foot', 'breast', 'warm', 'bending', 'chased', 'glancing', 'flash', 'distant', 'apple', 'savage', 'larger', 'wait', 'flight', 'glowed', 'west', 'brilliant', 'sleeping', 'deepening', 'filthy', 'death', 'southern', 'arrow', 'keep', 'lapwing', 'seen', 'rise', 'bat', 'look', 'smell', 'hollowed', 'five', 'tarnished', 'left', 'hedge', 'phantom', 'random', 'neolithic', 'east', 'cover', 'swerve', 'hunting', 'golden', 'across', 'called', 'flickering', 'might', 'dark', 'moment', 'binoculars', 'clear', 'stone', 'rising', 'round', 'jay', 'running', 'indifferent', 'woodcock', 'slept', 'forward', 'ship', 'belly', 'willow', 'going', 'banging', 'flock', 'hollow', 'wood', 'falcon', 'vole', 'oak', 'wedged', 'several', 'blade', 'limp', 'echoing', 'come', 'size', 'rib', 'shake-out', 'viciously', 'much', 'branch', 'passed', 'move', 'eagerly', 'never', 'back', 'together', 'hunted', 'wide', 'perched', 'kill', 'darkening', 'gone', 'time', 'hoping', 'came', 'october', 'violently', 'order', 'crept', 'high', 'took', 'finished', 'east-west', 'great', 'watch', 'laugh'}
# Dominating set length: 134
# Maximal independent set: ['apple', 'lay', 'dazzling', 'ship', 'receding', 'twenty', 'bird', 'along', 'sunlight', 'jay', 'slept', 'breast', 'wedged', 'crept', 'finished', 'went', 'skylark', 'slowly', 'like', 'arrow', 'oak', 'distant', 'playfully', 'seemed', 'occasionally', 'soft', 'back', 'savage', 'stayed', 'east-west', 'dark', 'never', 'star', 'cleared', 'flank', 'rising', 'wing', 'round', 'moving', 'slope', 'snow', 'renewing', 'wide', 'much', 'high', 'estuary', 'knife', 'east', 'eroded', 'evening', 'together', 'desperate', 'floated', 'swing', 'hollow', 'seen', 'wind-whipped', 'smell', 'darting', 'might', 'took', 'hedge', 'foot', 'filthy', 'rise', 'quickly', 'eagerly', 'oclock', 'trust', 'bill', 'find', 'ground', 'bronze', 'shining', 'flight', 'keep', 'several', 'branch', 'may', 'forward', 'flash', 'making', 'laugh', 'incohesive', 'till', 'chased', 'indifferent', 'peering', 'flock', 'october', 'left', 'carried', 'going', 'phantom', 'viciously', 'clangour', 'calling', 'death', 'hunting', 'north', 'fat', 'slash', 'limp', 'perched', 'masthead', 'willow', 'quite', 'featureless', 'glimmered', 'nine', 'west', 'running', 'gone', 'noctule', 'owl', 'blossom', 'shudder-up', 'golden', 'swerve', 'darkening', 'wood', 'fugitive', 'hoping', 'elm', 'binoculars', 'fluttered', 'hunted', 'stopped', 'stroke', 'cover', 'size']
# Maximal independent set length: 131
# [(12, 'hawk'), (10, 'sky'), (10, 'flew')]
# Loss: [-485 -485 -485 -485 -485]
# Diameter: 21
# Center nodes: ['huge', 'scooped-out']
# Average clustering: 0.009925474254742547
# Dominating set: {'cart', 'viking', 'swept', 'seven', 'perch', 'dull', 'tide', 'barn', 'overhead', 'poured', 'smelt', 'as', 'eleven', 'earth', 'frost', 'bronze', 'blurred', 'north', 'tree', 'drizzle', 'way', 'apart', 'pond', 'billhook', 'quite', 'small', 'fieldfare', 'closely', 'plucked', 'brook', 'bounding', 'gloomed', 'kingfisher', 'beside', 'fawn', 'hissing', 'glowed', 'eighth', 'spring', 'gold', 'dashed', 'le', 'southern', 'trail', 'keep', 'seen', 'lapwing', 'though', 'could', 'reached', 'lived', 'circled', 'followed', 'walked', 'blur', 'black-headed', 'south', 'blackthorn', 'tractor', 'sunlight', 'pupil', 'twenty', 'however', 'steep', 'sea-wall', 'heard', 'monotonous', 'cutting', 'breeze', 'mantle', 'silence', 'frog-like', 'hunting', 'view', 'called', 'might', 'dead', 'shallow', 'began', 'winged', 'burnished', 'blackbird', 'midday', 'throat', 'side', 'jay', 'ten', 'arm', 'hill', 'head', 'stooped', 'slept', 'woodpigeons', 'scolding', 'near', 'slate-grey', 'gradually', 'falcon', 'column', 'air', 'top', 'softened', 'surface', 'landed', 'calling', 'half', 'limp', 'pass', 'come', 'mud', 'cloudless', 'steadily', 'along', 'second', 'branch', 'say', 'thirty', 'scooped-out', 'together', 'end', 'hidden', 'almost', 'sharp', 'brilliance', 'flame', 'plover', 'dripping', 'spar', 'follow', 'time', 'gloomy', 'pair', 'two', 'high', 'tawny', 'seem', 'mimicking', 'amber', 'swath', 'cut', 'detail', 'looked', 'lee', 'web', 'moored'}
# Dominating set length: 145
# Maximal independent set: ['column', 'something', 'falcon', 'successive', 'together', 'broken', 'hissing', 'highest', 'however', 'dry', 'yard', 'tawny', 'evening', 'round', 'raft', 'emptiness', 'short-eared', 'light', 'thousand', 'asleep', 'overhead', 'flame', 'cut', 'silence', 'tree-fringed', 'feather', 'forced', 'pierced', 'brook', 'frog-like', 'elm', 'pliant', 'glide', 'stretched', 'sunlight', 'passed', 'seemed', 'skimmed', 'killed', 'keep', 'gradually', 'say', 'frost', 'swath', 'pair', 'cover', 'looked', 'dusk', 'day', 'dull', 'hunting', 'every', 'eaten', 'quite', 'called', 'dark', 'mantle', 'hissed', 'water', 'cast', 'seven', 'le', 'billhook', 'a', 'tiercel', 'circled', 'tractor', 'breeze', 'minute', 'heard', 'blackthorn', 'dead', 'huge', 'flickering', 'gold', 'flying', 'sagging', 'hawk', 'follow', 'crown', 'blackbird', 'walked', 'plover', 'southern', 'aching', 'swept', 'gloomed', 'came', 'warrior', 'hoping', 'time', 'steadily', 'closely', 'tree', 'grey', 'turned', 'followed', 'speck', 'farm', 'first', 'feeding', 'softened', 'twenty', 'dashed', 'scolding', 'fast', 'lower', 'blue', 'smelt', 'winged', 'series', 'drizzle', 'sing', 'ride', 'poured', 'silly', 'wood', 'neck', 'fieldfare', 'apart', 'briefly', 'lee', 'natural', 'mimicking', 'obstruction', 'till', 'trail', 'reached', 'lived', 'shining', 'folded', 'pupil', 'watched', 'throat', 'along', 'faint', 'north', 'valley', 'see', 'black-headed', 'shaking']
# Maximal independent set length: 141
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-89c1dd7080b4> in <module>()
#       1 gdtm = make_graph_dtm(text_folder,normalize=True)
#       2 gdtm_meta=df_meta.merge(gdtm,on='fn')
# ----> 3 gdtm_meta = gdtm_meta[dtm_meta.author !="gpt-2"]
#       4 gdtm_meta
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2965         # check_bool_indexer will throw exception if Series key cannot
#    2966         # be reindexed to match DataFrame rows
# -> 2967         key = check_bool_indexer(self.index, key)
#    2968         indexer = key.nonzero()[0]
#    2969         return self._take(indexer, axis=0)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in check_bool_indexer(ax, key)
#    2481     result = key
#    2482     if isinstance(key, ABCSeries) and not key.index.equals(ax):
# -> 2483         result = result.reindex(ax)
#    2484         mask = isna(result._values)
#    2485         if mask.any():
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    3736     @Appender(generic.NDFrame.reindex.__doc__)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#    3740     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4372             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    4373                                              fill_value=fill_value,
# -> 4374                                              copy=copy, allow_dups=False)
#    4375
#    4376         return obj
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1222         # some axes don't allow reindexing with dups
#    1223         if not allow_dups:
# -> 1224             self.axes[axis]._can_reindex(indexer)
#    1225
#    1226         if axis >= self.ndim:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3085         # trying to reindex on an axis with duplicates
#    3086         if not self.is_unique and len(indexer):
# -> 3087             raise ValueError("cannot reindex from a duplicate axis")
#    3088
#    3089     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
draw_graph3(_g)
# Out:
#         <iframe
#             width="100%"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
draw_graph3(g)
# Out:
#         <iframe
#             width="100%"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
def concordance(text_folder,filename,word,width=100,lines=1000):
    # Get the path
    text_path = os.path.join(text_folder, filename)
    print(text_path)

    # Open the file
    with open(text_path) as file:
        text_txt=file.read()

    # make nltk version of the text (useful for concordance)
    import nltk
    text_words = nltk.word_tokenize(text_txt)
    text_nltk = nltk.text.Text(text_words)

    # get concordance
    text_nltk.concordance(word,width=width,lines=lines)

# %%
concordance(text_folder,'_'+checkfile+".txt","like")
concordance(text_folder,checkfile+".txt","like")
# Out:
# ../corpora/peregrine/_52_jan-9.txt
# Displaying 1 of 1 matches:
# hundred woodpigeons clattered up from the mud , like damp squibs . None moved when I walked towards
# ../corpora/peregrine/52_jan-9.txt
# Displaying 1 of 1 matches:
# awks . Their eyes see maps of black and white , like a crackle of silent film . The moving black is
