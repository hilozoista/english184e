# %% [markdown]
# # Most distinctive words
#
# Following on [the previous notebook](6A_document_term_matrices.ipynb)...
#
# How can we find the words directly which distinguish Republican and Democrat States of the Union? Or between pre- and post-war America?
#
#
# ## Preliminaries

# %%
# import some things
import os
import pandas as pd
from textblob import TextBlob
pd.set_option("display.max_rows", 20)

# %%
# Set text folder and metadata path
# (If you don't have this corpus, please download it here): https://www.dropbox.com/sh/xd854hgyvbysqlm/AAAhbS6r7MFe4SVg1BFuuMTCa?dl=1

text_folder = '../corpora/sotu_1900-2018/texts'
path_to_metadata='../corpora/sotu_1900-2018/metadata.xls'

# %% [markdown]
# ### Functions from last time

# %%
# Loop over each of the filenames

def make_dtm(text_folder,n_top_words=1000,normalize=False):
    # get stopwords
    from nltk.corpus import stopwords
    stopwords=set(stopwords.words('english'))

    # make an empty results list
    all_results = []

    # make a count for all words
    from collections import Counter
    all_counts = Counter()

    # for each filename
    filenames=sorted(os.listdir(text_folder))
    for i,fn in enumerate(filenames):
        if not i%10: print('>> looping through #',i,'of',len(filenames),'files:',fn)
        # make sure is a text file
        if not fn.endswith('.txt'): continue
        
        # full path
        full_path = os.path.join(text_folder,fn)

        # open the file
        with open(full_path) as file:
            txt=file.read()

        # make a blob
        blob = TextBlob(txt.lower())

        # make a result dictionary
        text_result = {}

        # set the filename
        text_result['fn']=fn

        # loop over the word counts
        num_words = len(blob.words)

        # for each word,count pair in the blob.word_counts dictionary...
        for word,count in blob.word_counts.items():
            # is the word in the stopwords?
            if word in stopwords: continue  

            # is the word a punctuation?
            if not word[0].isalpha(): continue
            
            # set the normalized version
            if normalize:
                # get the term frequency (count divided by number of words)
                tf = count / num_words

                # set the term frequency result to the key 'word' in the text_result dictionary
                text_result[word] = tf
            else:
                # set the count as a result
                text_result[word] = count

            # add the count to the dictionary of counts for all words
            all_counts[word]+=count

        # add results
        all_results.append(text_result)
    
    # Get the most frequent words
    most_common_words_plus_counts = all_counts.most_common(n_top_words)
    
    # Get only the words
    word_columns = []
    for word,count in most_common_words_plus_counts:
        word_columns.append(word)
    
    # Get columns
    columns=[]
    columns.append('fn')
    columns.extend(word_columns)
    
    # Make dataframe
    df = pd.DataFrame(all_results, columns=columns).set_index('fn').fillna(0)
    
    # return dataframe
    return df

# %%
# Make the document term matrix
dtm = make_dtm(text_folder,normalize=True)
# Out:
# >> looping through # 0 of 118 files: 1900.McKinley.txt
# >> looping through # 10 of 118 files: 1910.Taft.txt
# >> looping through # 20 of 118 files: 1920.Wilson.txt
# >> looping through # 30 of 118 files: 1930.Hoover.txt
# >> looping through # 40 of 118 files: 1941.Roosevelt.txt
# >> looping through # 50 of 118 files: 1951.Truman.txt
# >> looping through # 60 of 118 files: 1961.Eisenhower.txt
# >> looping through # 70 of 118 files: 1971.Nixon.txt
# >> looping through # 80 of 118 files: 1981.Carter.txt
# >> looping through # 90 of 118 files: 1991.Bush.txt
# >> looping through # 100 of 118 files: 2001.Bush.txt
# >> looping through # 110 of 118 files: 2011.Obama.txt

# %%
# Get the metadata for this corpus
df_meta = pd.read_excel(path_to_metadata).set_index('fn')
df_meta
# Out:
#                     President  Year       Party
# fn
# 1900.McKinley.txt    McKinley  1900  Republican
# 1901.Roosevelt.txt  Roosevelt  1901  Republican
# 1902.Roosevelt.txt  Roosevelt  1902  Republican
# 1903.Roosevelt.txt  Roosevelt  1903  Republican
# 1904.Roosevelt.txt  Roosevelt  1904  Republican
# 1905.Roosevelt.txt  Roosevelt  1905  Republican
# 1906.Roosevelt.txt  Roosevelt  1906  Republican
# 1907.Roosevelt.txt  Roosevelt  1907  Republican
# 1908.Roosevelt.txt  Roosevelt  1908  Republican
# 1909.Taft.txt            Taft  1909  Republican
# ...                       ...   ...         ...
# 2009.Obama.txt          Obama  2009    Democrat
# 2010.Obama.txt          Obama  2010    Democrat
# 2011.Obama.txt          Obama  2011    Democrat
# 2012.Obama.txt          Obama  2012    Democrat
# 2013.Obama.txt          Obama  2013    Democrat
# 2014.Obama.txt          Obama  2014    Democrat
# 2015.Obama.txt          Obama  2015    Democrat
# 2016.Obama.txt          Obama  2016    Democrat
# 2017.Trump.txt          Trump  2017  Republican
# 2018.Trump.txt          Trump  2018  Republican
#
# [118 rows x 3 columns]

# %%
# Add the metadata
dtm_meta=df_meta.merge(dtm,on='fn')
dtm_meta
# Out:
#                     President  Year       Party  government      must  \
# fn
# 1900.McKinley.txt    McKinley  1900  Republican    0.005690  0.000783
# 1901.Roosevelt.txt  Roosevelt  1901  Republican    0.002597  0.002546
# 1902.Roosevelt.txt  Roosevelt  1902  Republican    0.001637  0.002661
# 1903.Roosevelt.txt  Roosevelt  1903  Republican    0.004013  0.000602
# 1904.Roosevelt.txt  Roosevelt  1904  Republican    0.003270  0.002410
# 1905.Roosevelt.txt  Roosevelt  1905  Republican    0.003505  0.002270
# 1906.Roosevelt.txt  Roosevelt  1906  Republican    0.003513  0.002116
# 1907.Roosevelt.txt  Roosevelt  1907  Republican    0.003393  0.002408
# 1908.Roosevelt.txt  Roosevelt  1908  Republican    0.002882  0.001750
# 1909.Taft.txt            Taft  1909  Republican    0.005755  0.000432
# ...                       ...   ...         ...         ...       ...
# 2009.Obama.txt          Obama  2009    Democrat    0.001170  0.002508
# 2010.Obama.txt          Obama  2010    Democrat    0.001804  0.001110
# 2011.Obama.txt          Obama  2011    Democrat    0.002547  0.001273
# 2012.Obama.txt          Obama  2012    Democrat    0.001119  0.000280
# 2013.Obama.txt          Obama  2013    Democrat    0.001376  0.002751
# 2014.Obama.txt          Obama  2014    Democrat    0.000432  0.000576
# 2015.Obama.txt          Obama  2015    Democrat    0.000725  0.000000
# 2016.Obama.txt          Obama  2016    Democrat    0.000715  0.000358
# 2017.Trump.txt          Trump  2017  Republican    0.001579  0.003947
# 2018.Trump.txt          Trump  2018  Republican    0.000774  0.001161
#
#                       people  congress     world       new      year  \
# fn
# 1900.McKinley.txt   0.002193  0.002871  0.000522  0.001096  0.002454
# 1901.Roosevelt.txt  0.002444  0.001629  0.001477  0.000662  0.000407
# 1902.Roosevelt.txt  0.002252  0.003582  0.001330  0.000819  0.000716
# 1903.Roosevelt.txt  0.001739  0.003076  0.001070  0.001605  0.002608
# 1904.Roosevelt.txt  0.002180  0.002180  0.000631  0.000344  0.000631
# 1905.Roosevelt.txt  0.002031  0.002111  0.000677  0.000438  0.000797
# 1906.Roosevelt.txt  0.002582  0.001143  0.000381  0.000720  0.000423
# 1907.Roosevelt.txt  0.001569  0.001824  0.000584  0.000584  0.000912
# 1908.Roosevelt.txt  0.002831  0.001441  0.000721  0.000978  0.000618
# 1909.Taft.txt       0.000504  0.002590  0.000791  0.001079  0.001655
# ...                      ...       ...       ...       ...       ...
# 2009.Obama.txt      0.003344  0.001672  0.001839  0.003344  0.001338
# 2010.Obama.txt      0.004580  0.001388  0.000833  0.002776  0.003747
# 2011.Obama.txt      0.004669  0.001415  0.002547  0.005093  0.002122
# 2012.Obama.txt      0.003217  0.002098  0.002657  0.003776  0.002657
# 2013.Obama.txt      0.003057  0.002598  0.001223  0.003515  0.002598
# 2014.Obama.txt      0.003459  0.002882  0.002018  0.004179  0.002594
# 2015.Obama.txt      0.003333  0.001884  0.003043  0.005941  0.002174
# 2016.Obama.txt      0.003755  0.000894  0.004470  0.002861  0.003040
# 2017.Trump.txt      0.002960  0.001579  0.003355  0.003750  0.001776
# 2018.Trump.txt      0.005031  0.002515  0.001935  0.004063  0.003096
#
#                        ...       september  authorized    postal  materials  \
# fn                     ...
# 1900.McKinley.txt      ...        0.000313    0.000209  0.000261   0.000104
# 1901.Roosevelt.txt     ...        0.000102    0.000051  0.000305   0.000000
# 1902.Roosevelt.txt     ...        0.000000    0.000000  0.000205   0.000000
# 1903.Roosevelt.txt     ...        0.000201    0.000201  0.000201   0.000000
# 1904.Roosevelt.txt     ...        0.000000    0.000057  0.000057   0.000000
# 1905.Roosevelt.txt     ...        0.000040    0.000159  0.000000   0.000040
# 1906.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000000
# 1907.Roosevelt.txt     ...        0.000182    0.000073  0.000146   0.000000
# 1908.Roosevelt.txt     ...        0.000103    0.000206  0.000257   0.000000
# 1909.Taft.txt          ...        0.000288    0.000144  0.000575   0.000072
# ...                    ...             ...         ...       ...        ...
# 2009.Obama.txt         ...        0.000000    0.000000  0.000000   0.000000
# 2010.Obama.txt         ...        0.000000    0.000000  0.000000   0.000139
# 2011.Obama.txt         ...        0.000141    0.000000  0.000000   0.000141
# 2012.Obama.txt         ...        0.000000    0.000000  0.000000   0.000140
# 2013.Obama.txt         ...        0.000000    0.000000  0.000000   0.000153
# 2014.Obama.txt         ...        0.000000    0.000000  0.000000   0.000144
# 2015.Obama.txt         ...        0.000000    0.000000  0.000000   0.000000
# 2016.Obama.txt         ...        0.000000    0.000000  0.000000   0.000000
# 2017.Trump.txt         ...        0.000000    0.000000  0.000000   0.000000
# 2018.Trump.txt         ...        0.000193    0.000000  0.000000   0.000000
#
#                     understand     facts      fall     offer  partnership  \
# fn
# 1900.McKinley.txt     0.000052  0.000052  0.000000  0.000000     0.000000
# 1901.Roosevelt.txt    0.000051  0.000102  0.000153  0.000204     0.000000
# 1902.Roosevelt.txt    0.000000  0.000102  0.000409  0.000000     0.000000
# 1903.Roosevelt.txt    0.000000  0.000268  0.000067  0.000134     0.000000
# 1904.Roosevelt.txt    0.000115  0.000230  0.000115  0.000057     0.000000
# 1905.Roosevelt.txt    0.000080  0.000159  0.000040  0.000159     0.000000
# 1906.Roosevelt.txt    0.000042  0.000127  0.000169  0.000000     0.000000
# 1907.Roosevelt.txt    0.000036  0.000255  0.000073  0.000036     0.000000
# 1908.Roosevelt.txt    0.000103  0.000154  0.000051  0.000000     0.000000
# 1909.Taft.txt         0.000000  0.000288  0.000072  0.000144     0.000000
# ...                        ...       ...       ...       ...          ...
# 2009.Obama.txt        0.000502  0.000167  0.000167  0.000000     0.000000
# 2010.Obama.txt        0.000278  0.000000  0.000139  0.000000     0.000000
# 2011.Obama.txt        0.000000  0.000000  0.000141  0.000141     0.000283
# 2012.Obama.txt        0.000280  0.000140  0.000140  0.000280     0.000420
# 2013.Obama.txt        0.000153  0.000000  0.000153  0.000306     0.000459
# 2014.Obama.txt        0.000144  0.000000  0.000144  0.000576     0.000144
# 2015.Obama.txt        0.000580  0.000145  0.000000  0.000145     0.000000
# 2016.Obama.txt        0.000358  0.000179  0.000536  0.000000     0.000179
# 2017.Trump.txt        0.000000  0.000000  0.000000  0.000000     0.000197
# 2018.Trump.txt        0.000387  0.000000  0.000000  0.000000     0.000000
#
#                     afghanistan
# fn
# 1900.McKinley.txt      0.000000
# 1901.Roosevelt.txt     0.000000
# 1902.Roosevelt.txt     0.000000
# 1903.Roosevelt.txt     0.000000
# 1904.Roosevelt.txt     0.000000
# 1905.Roosevelt.txt     0.000000
# 1906.Roosevelt.txt     0.000000
# 1907.Roosevelt.txt     0.000000
# 1908.Roosevelt.txt     0.000000
# 1909.Taft.txt          0.000000
# ...                         ...
# 2009.Obama.txt         0.000334
# 2010.Obama.txt         0.000416
# 2011.Obama.txt         0.000141
# 2012.Obama.txt         0.000420
# 2013.Obama.txt         0.000611
# 2014.Obama.txt         0.000865
# 2015.Obama.txt         0.000435
# 2016.Obama.txt         0.000179
# 2017.Trump.txt         0.000000
# 2018.Trump.txt         0.000193
#
# [118 rows x 1003 columns]

# %% [markdown]
# ## Finding the most distinctive words

# %% [markdown]
# ### (1) Difference of means

# %%
dtm_meta.groupby('Party').mean()
# Out:
#                    Year  government      must    people  congress     world  \
# Party
# Democrat    1962.785714    0.002461  0.003902  0.003470  0.002721  0.003521
# Republican  1956.000000    0.003588  0.003182  0.003103  0.002896  0.002671
#
#                  new      year  american    states     ...       september  \
# Party                                                  ...
# Democrat    0.002770  0.002445  0.002031  0.001475     ...        0.000034
# Republican  0.002453  0.002132  0.002349  0.001973     ...        0.000122
#
#             authorized    postal  materials  understand     facts      fall  \
# Party
# Democrat      0.000071  0.000015   0.000153    0.000138  0.000122  0.000106
# Republican    0.000099  0.000106   0.000087    0.000111  0.000085  0.000119
#
#                offer  partnership  afghanistan
# Party
# Democrat    0.000102     0.000134     0.000112
# Republican  0.000117     0.000121     0.000150
#
# [2 rows x 1001 columns]

# %%
dtm_meta.groupby('Party').mean().T
# Out:
# Party           Democrat   Republican
# Year         1962.785714  1956.000000
# government      0.002461     0.003588
# must            0.003902     0.003182
# people          0.003470     0.003103
# congress        0.002721     0.002896
# world           0.003521     0.002671
# new             0.002770     0.002453
# year            0.002445     0.002132
# american        0.002031     0.002349
# states          0.001475     0.001973
# ...                  ...          ...
# september       0.000034     0.000122
# authorized      0.000071     0.000099
# postal          0.000015     0.000106
# materials       0.000153     0.000087
# understand      0.000138     0.000111
# facts           0.000122     0.000085
# fall            0.000106     0.000119
# offer           0.000102     0.000117
# partnership     0.000134     0.000121
# afghanistan     0.000112     0.000150
#
# [1001 rows x 2 columns]

# %%
round(dtm_meta.groupby('Party').mean().T * 1000,2)
# Out:
# Party          Democrat  Republican
# Year         1962785.71  1956000.00
# government         2.46        3.59
# must               3.90        3.18
# people             3.47        3.10
# congress           2.72        2.90
# world              3.52        2.67
# new                2.77        2.45
# year               2.44        2.13
# american           2.03        2.35
# states             1.47        1.97
# ...                 ...         ...
# september          0.03        0.12
# authorized         0.07        0.10
# postal             0.01        0.11
# materials          0.15        0.09
# understand         0.14        0.11
# facts              0.12        0.09
# fall               0.11        0.12
# offer              0.10        0.12
# partnership        0.13        0.12
# afghanistan        0.11        0.15
#
# [1001 rows x 2 columns]

# %%
dtm_meta_T = dtm_meta.groupby('Party').mean().T * 1000
dtm_meta_T
# Out:
# Party            Democrat    Republican
# Year         1.962786e+06  1.956000e+06
# government   2.461048e+00  3.588064e+00
# must         3.901520e+00  3.181923e+00
# people       3.470494e+00  3.102993e+00
# congress     2.720751e+00  2.896402e+00
# world        3.521217e+00  2.670673e+00
# new          2.770091e+00  2.452986e+00
# year         2.444723e+00  2.131966e+00
# american     2.030995e+00  2.349020e+00
# states       1.474577e+00  1.972770e+00
# ...                   ...           ...
# september    3.418065e-02  1.224638e-01
# authorized   7.057241e-02  9.866924e-02
# postal       1.498145e-02  1.062402e-01
# materials    1.527434e-01  8.669086e-02
# understand   1.384083e-01  1.105063e-01
# facts        1.222187e-01  8.506759e-02
# fall         1.057216e-01  1.194746e-01
# offer        1.019811e-01  1.167446e-01
# partnership  1.338939e-01  1.213275e-01
# afghanistan  1.116003e-01  1.502044e-01
#
# [1001 rows x 2 columns]

# %%
dtm_meta_T['D-R']=dtm_meta_T['Democrat'] - dtm_meta_T['Republican']
round(dtm_meta_T,2)
# Out:
# Party          Democrat  Republican      D-R
# Year         1962785.71  1956000.00  6785.71
# government         2.46        3.59    -1.13
# must               3.90        3.18     0.72
# people             3.47        3.10     0.37
# congress           2.72        2.90    -0.18
# world              3.52        2.67     0.85
# new                2.77        2.45     0.32
# year               2.44        2.13     0.31
# american           2.03        2.35    -0.32
# states             1.47        1.97    -0.50
# ...                 ...         ...      ...
# september          0.03        0.12    -0.09
# authorized         0.07        0.10    -0.03
# postal             0.01        0.11    -0.09
# materials          0.15        0.09     0.07
# understand         0.14        0.11     0.03
# facts              0.12        0.09     0.04
# fall               0.11        0.12    -0.01
# offer              0.10        0.12    -0.01
# partnership        0.13        0.12     0.01
# afghanistan        0.11        0.15    -0.04
#
# [1001 rows x 3 columns]

# %%
round(dtm_meta_T.sort_values('D-R'),2)
# Out:
# Party         Democrat  Republican      D-R
# government        2.46        3.59    -1.13
# federal           0.85        1.83    -0.98
# america           2.00        2.72    -0.72
# states            1.47        1.97    -0.50
# law               0.66        1.09    -0.43
# department        0.18        0.60    -0.42
# system            0.75        1.17    -0.42
# state             0.66        1.08    -0.42
# made              1.06        1.46    -0.41
# freedom           0.76        1.16    -0.41
# ...                ...         ...      ...
# us                2.79        2.34     0.45
# jobs              0.95        0.48     0.47
# know              1.20        0.69     0.50
# every             2.00        1.41     0.59
# nations           1.73        1.12     0.61
# n't               1.03        0.34     0.69
# must              3.90        3.18     0.72
# world             3.52        2.67     0.85
# war               2.24        1.17     1.07
# Year        1962785.71  1956000.00  6785.71
#
# [1001 rows x 3 columns]

# %%
dtm_meta.boxplot('government',by='Party',figsize=(8,5))

# %%
dtm_meta.boxplot('war',by='Party',figsize=(8,5))

# %%
dtm_meta.sort_values('war',ascending=False)
# Out:
#                     President  Year       Party  government      must  \
# fn
# 1944.Roosevelt.txt  Roosevelt  1944    Democrat    0.002618  0.002095
# 1943.Roosevelt.txt  Roosevelt  1943    Democrat    0.000870  0.002829
# 1945.Roosevelt.txt  Roosevelt  1945    Democrat    0.000972  0.005102
# 1942.Roosevelt.txt  Roosevelt  1942    Democrat    0.000569  0.005117
# 1917.Wilson.txt        Wilson  1917    Democrat    0.001530  0.007141
# 1946.Truman.txt        Truman  1946    Democrat    0.004567  0.002625
# 1953.Truman.txt        Truman  1953    Democrat    0.001440  0.002469
# 1941.Roosevelt.txt  Roosevelt  1941    Democrat    0.001203  0.004209
# 1918.Wilson.txt        Wilson  1918    Democrat    0.002191  0.002191
# 1920.Wilson.txt        Wilson  1920    Democrat    0.007364  0.001473
# ...                       ...   ...         ...         ...       ...
# 1930.Hoover.txt        Hoover  1930  Republican    0.004182  0.000440
# 1938.Roosevelt.txt  Roosevelt  1938    Democrat    0.008692  0.002120
# 1983.Reagan.txt        Reagan  1983  Republican    0.003174  0.006172
# 1913.Wilson.txt        Wilson  1913    Democrat    0.003940  0.003659
# 1935.Roosevelt.txt  Roosevelt  1935    Democrat    0.004809  0.001697
# 1949.Truman.txt        Truman  1949    Democrat    0.006444  0.006737
# 1990.Bush.txt            Bush  1990  Republican    0.001037  0.004406
# 1934.Roosevelt.txt  Roosevelt  1934    Democrat    0.003138  0.001345
# 1982.Reagan.txt        Reagan  1982  Republican    0.005481  0.002268
# 1993.Clinton.txt      Clinton  1993    Democrat    0.003528  0.004939
#
#                       people  congress     world       new      year  \
# fn
# 1944.Roosevelt.txt  0.003404  0.003404  0.001833  0.001309  0.000786
# 1943.Roosevelt.txt  0.003046  0.001088  0.004569  0.000653  0.003916
# 1945.Roosevelt.txt  0.001944  0.001701  0.002187  0.002551  0.002065
# 1942.Roosevelt.txt  0.004548  0.000569  0.004832  0.000284  0.003127
# 1917.Wilson.txt     0.005101  0.002040  0.004846  0.000000  0.000000
# 1946.Truman.txt     0.001726  0.002661  0.001978  0.001618  0.006652
# 1953.Truman.txt     0.003807  0.000926  0.009878  0.002778  0.000823
# 1941.Roosevelt.txt  0.001503  0.003007  0.006013  0.003307  0.000301
# 1918.Wilson.txt     0.000730  0.001643  0.001825  0.000913  0.000730
# 1920.Wilson.txt     0.002209  0.005155  0.003682  0.000368  0.002946
# ...                      ...       ...       ...       ...       ...
# 1930.Hoover.txt     0.000660  0.004622  0.001101  0.001321  0.004843
# 1938.Roosevelt.txt  0.003816  0.002756  0.001696  0.001060  0.001696
# 1983.Reagan.txt     0.003350  0.001411  0.002469  0.001411  0.003350
# 1913.Wilson.txt     0.003940  0.002533  0.001689  0.000281  0.000000
# 1935.Roosevelt.txt  0.004809  0.002263  0.001980  0.003678  0.001697
# 1949.Truman.txt     0.004394  0.004979  0.004101  0.002050  0.000586
# 1990.Bush.txt       0.002592  0.001037  0.006221  0.004406  0.004147
# 1934.Roosevelt.txt  0.005379  0.002689  0.001793  0.001345  0.000000
# 1982.Reagan.txt     0.003213  0.002457  0.001701  0.002835  0.002457
# 1993.Clinton.txt    0.006209  0.001552  0.002399  0.004093  0.002964
#
#                        ...       september  authorized    postal  materials  \
# fn                     ...
# 1944.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000262
# 1943.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000218
# 1945.Roosevelt.txt     ...        0.000121    0.000000  0.000000   0.000364
# 1942.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000284
# 1917.Wilson.txt        ...        0.000000    0.000000  0.000000   0.000255
# 1946.Truman.txt        ...        0.000827    0.000431  0.000144   0.000360
# 1953.Truman.txt        ...        0.000000    0.000000  0.000000   0.000000
# 1941.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000601
# 1918.Wilson.txt        ...        0.000365    0.000000  0.000000   0.000913
# 1920.Wilson.txt        ...        0.000000    0.000368  0.000000   0.000000
# ...                    ...             ...         ...       ...        ...
# 1930.Hoover.txt        ...        0.000000    0.000880  0.000660   0.000440
# 1938.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000212
# 1983.Reagan.txt        ...        0.000176    0.000000  0.000000   0.000000
# 1913.Wilson.txt        ...        0.000000    0.000281  0.000000   0.000000
# 1935.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000000
# 1949.Truman.txt        ...        0.000000    0.000000  0.000000   0.001465
# 1990.Bush.txt          ...        0.000000    0.000000  0.000000   0.000000
# 1934.Roosevelt.txt     ...        0.000000    0.000000  0.000000   0.000000
# 1982.Reagan.txt        ...        0.000000    0.000000  0.000000   0.000000
# 1993.Clinton.txt       ...        0.000000    0.000000  0.000000   0.000000
#
#                     understand     facts      fall     offer  partnership  \
# fn
# 1944.Roosevelt.txt    0.000000  0.000262  0.000000  0.000000     0.000000
# 1943.Roosevelt.txt    0.000218  0.000218  0.000000  0.000000     0.000000
# 1945.Roosevelt.txt    0.000121  0.000000  0.000000  0.000243     0.000000
# 1942.Roosevelt.txt    0.000284  0.000000  0.000000  0.000000     0.000000
# 1917.Wilson.txt       0.000255  0.000255  0.000255  0.000000     0.001020
# 1946.Truman.txt       0.000072  0.000036  0.000180  0.000180     0.000000
# 1953.Truman.txt       0.000412  0.000000  0.000309  0.000000     0.000000
# 1941.Roosevelt.txt    0.000000  0.000000  0.000000  0.000000     0.000000
# 1918.Wilson.txt       0.000000  0.000183  0.000183  0.000183     0.000000
# 1920.Wilson.txt       0.000368  0.000000  0.000000  0.000000     0.000000
# ...                        ...       ...       ...       ...          ...
# 1930.Hoover.txt       0.000000  0.000000  0.000220  0.000220     0.000000
# 1938.Roosevelt.txt    0.000000  0.000848  0.000424  0.000000     0.000000
# 1983.Reagan.txt       0.000353  0.000000  0.000000  0.000176     0.000705
# 1913.Wilson.txt       0.000000  0.000000  0.000000  0.000000     0.000000
# 1935.Roosevelt.txt    0.000000  0.000283  0.000000  0.000000     0.000000
# 1949.Truman.txt       0.000000  0.000000  0.000000  0.000000     0.000000
# 1990.Bush.txt         0.000259  0.000000  0.000518  0.000778     0.000000
# 1934.Roosevelt.txt    0.000000  0.000000  0.000000  0.000000     0.000000
# 1982.Reagan.txt       0.000378  0.000000  0.000189  0.000000     0.000567
# 1993.Clinton.txt      0.000141  0.000282  0.000141  0.000564     0.000282
#
#                     afghanistan
# fn
# 1944.Roosevelt.txt     0.000000
# 1943.Roosevelt.txt     0.000000
# 1945.Roosevelt.txt     0.000000
# 1942.Roosevelt.txt     0.000000
# 1917.Wilson.txt        0.000000
# 1946.Truman.txt        0.000000
# 1953.Truman.txt        0.000000
# 1941.Roosevelt.txt     0.000000
# 1918.Wilson.txt        0.000000
# 1920.Wilson.txt        0.000000
# ...                         ...
# 1930.Hoover.txt        0.000000
# 1938.Roosevelt.txt     0.000000
# 1983.Reagan.txt        0.000000
# 1913.Wilson.txt        0.000000
# 1935.Roosevelt.txt     0.000000
# 1949.Truman.txt        0.000000
# 1990.Bush.txt          0.000000
# 1934.Roosevelt.txt     0.000000
# 1982.Reagan.txt        0.000189
# 1993.Clinton.txt       0.000000
#
# [118 rows x 1003 columns]

# %%
# Sort by government
dtm_meta.sort_values('government',ascending=False)

# %%
# Why is Nixon using government so much?
nixon_path = os.path.join(text_folder, '1971.Nixon.txt')
print(nixon_path)

# Open the file
with open(nixon_path) as file:
    nixon_txt=file.read()
    
# make nltk version of the text (useful for concordance)
import nltk
nixon_words = nltk.word_tokenize(nixon_txt)
nixon_nltk = nltk.text.Text(nixon_words)

# get concordance
nixon_nltk.concordance('government',width=100,lines=1000)

# %%
def concordance(text_folder,filename,word,width=100,lines=1000):
    # Get the path
    text_path = os.path.join(text_folder, filename)
    print(text_path)

    # Open the file
    with open(text_path) as file:
        text_txt=file.read()

    # make nltk version of the text (useful for concordance)
    import nltk
    text_words = nltk.word_tokenize(text_txt)
    text_nltk = nltk.text.Text(text_words)

    # get concordance
    text_nltk.concordance(word,width=width,lines=lines)

# %%
concordance(text_folder,'1938.Roosevelt.txt','government')

# %%
dtm_meta.boxplot('war',by='Party',figsize=(8,5))

# %% [markdown]
# ### (2) TF-IDF
#
# #### TF: Term Frequency
#
# <center><img src="https://latex.codecogs.com/png.latex?TF = \frac{n_w}{n_d}"></center>
#
# Where:
# * *Nw* is the number of times a given word *w* appears in a document.
# * *Nd* is the number of words in that document.

# %%
# set a given word?
given_word='jobs'

# %%
# We already have that calculated here:
tf_series = dtm[given_word]
tf_series.sort_values(ascending=False)

# %% [markdown]
# #### IDF: Inverse Document Frequency
#
# <center><img src="https://latex.codecogs.com/png.latex?IDF = \log \left( \frac{c_d}{i_d} \right)"></center>
#
# Where:
# * <img src="https://latex.codecogs.com/png.latex?{c_d}"> is the count of documents in the corpus.
# * <img src="https://latex.codecogs.com/png.latex?{i_d}"> = is the number of documents in which that word appears.

# %%
# Get the number of documents
num_docs = len(dtm)
num_docs

# %%
# Get the number of documents a given word appears
dtm[dtm[given_word]>0][given_word]

# %%
num_docs_with_word=len(dtm[dtm[given_word]>0])

# %%
import numpy as np
idf = np.log(num_docs/num_docs_with_word)
idf

# %%
tfidf_series = tf_series * idf
tfidf_series.sort_values(ascending=False)

# %%
pd.DataFrame({'tfidf':tfidf_series, 'tf':tf_series}).plot(x='tf',y='tfidf',kind='scatter')

# %%
# make
def to_tfidf(dtm):
    # list of dictionaries
    dtm_tfidf = pd.DataFrame()
    
    for word in dtm.columns:
        # tf
        tf_series = dtm[word]
        
        # idf
        num_docs = len(dtm)
        num_docs_with_word=len(dtm[dtm[word]>0])
        idf=np.log(num_docs/num_docs_with_word)
        
        # tfidf
        tfidf_series = tf_series * idf
        dtm_tfidf[word]=tfidf_series
    
    return dtm_tfidf

# %%
dtm_tfidf=to_tfidf(dtm)
dtm_tfidf

# %%
word='america'
dtm[word].nlargest(10)

# %%
dtm_tfidf[word].nlargest(10)

# %%
pd.DataFrame({'tf':dtm[word], 'tfidf':dtm_tfidf[word]}).plot(x='tf',y='tfidf')

# %%
fn='2002.Bush.txt'
dtm_tfidf.loc[fn].nlargest(10)

# %%
dtm.loc[fn].nlargest(10)

# %%
fn='2017.Trump.txt'
dtm_tfidf.loc[fn].nlargest(10)

# %%
n_words = 10
for index in reversed(dtm_tfidf.index):
    # get row for this index
    row=dtm_tfidf.loc[index]
    
    # get the lagest words
    top_words_series=row.nlargest(n_words)
    top_words_list=list(top_words_series.index)
    top_words_str=', '.join(top_words_list)
    
    # print
    print('##',index.upper())
    print(top_words_str)
    print()

# %% [markdown]
# ### (3) Fisher's exact test

# %%
# For this we need a document-term matrix *of raw counts*
dtm_counts = make_dtm(text_folder,normalize=False)

# %%
dtm_counts_meta = df_meta.merge(dtm_counts,on='fn')
dtm_counts_meta

# %%
Rs=dtm_counts[df_meta.Party == 'Republican']
Ds=dtm_counts[df_meta.Party == 'Democrat']
Rs

# %%
word='immigration'
sum_word_Rs = Rs[word].sum()
sum_word_Ds = Ds[word].sum()

print(sum_word_Rs,sum_word_Ds)

# %%
Rs.sum()

# %%
sum_allword_Rs=Rs.sum().sum()
sum_allword_Rs

# %%
sum_allword_Ds=Ds.sum().sum()
sum_allword_Ds

# %%
sum_notword_Rs = sum_allword_Rs - sum_word_Rs
sum_notword_Rs

# %%
sum_notword_Ds = sum_allword_Ds - sum_word_Ds
sum_notword_Ds

# %%
contingency_table = [
    [sum_word_Rs, sum_notword_Rs],
    [sum_word_Ds, sum_notword_Ds]
]

# %%
contingency_table

# %%
from scipy.stats import fisher_exact

oddsratio, pvalue = fisher_exact(contingency_table)
oddsratio, pvalue

# %% [markdown]
# #### "Stacking" a DTM

# %%
dtm_counts.stack()

# %%
dtm_stacked = dtm_counts.stack().reset_index()
dtm_stacked

# %%
dtm_stacked.columns = ['fn','word','count']
dtm_stacked

# %%
# Pivot table back to unstacked original form
dtm_stacked.pivot(index='fn',columns='word',values='count')

# %%
# Merge stacked DTM with meta
dtm_stacked_meta = df_meta.merge(dtm_stacked,on='fn')
dtm_stacked_meta

# %%
num_word_Rs=dtm_stacked_meta.query('word == "government" & Party == "Republican"')['count'].sum()
num_word_notRs=dtm_stacked_meta.query('word == "government" & Party != "Republican"')['count'].sum()
num_notword_Rs=dtm_stacked_meta.query('word != "government" & Party == "Republican"')['count'].sum()
num_notword_notRs=dtm_stacked_meta.query('word != "government" & Party != "Republican"')['count'].sum()

# %%
contingency_table = [
    [num_word_Rs, num_word_notRs],
    [num_notword_Rs, num_notword_notRs]
]
fisher_exact(contingency_table)

# %%
# Try every word!
result_list=[]

party='Republican'
for word in dtm_stacked_meta['word'].unique():
    num_word_Rs=dtm_stacked_meta.query('word == "'+word+'" & Party == "'+party+'"')['count'].sum()
    num_word_notRs=dtm_stacked_meta.query('word == "'+word+'" & Party != "'+party+'"')['count'].sum()
    num_notword_Rs=dtm_stacked_meta.query('word != "'+word+'" & Party == "'+party+'"')['count'].sum()
    num_notword_notRs=dtm_stacked_meta.query('word != "'+word+'" & Party != "'+party+'"')['count'].sum()
    contingency_table = [
        [num_word_Rs, num_word_notRs],
        [num_notword_Rs, num_notword_notRs]
    ]
    oddsratio,pvalue=fisher_exact(contingency_table)
    if oddsratio>2 and pvalue<0.05:
        print('{oddsratio} to 1 = the odds of "{word}" appearing in {party} (vs. non-{party}) texts'.format(
            word=word,party=party,oddsratio=round(oddsratio,2)))

    result_dict={}
    result_dict['word']=word
    result_dict['oddsratio']=oddsratio
    result_dict['pvalue']=pvalue
    result_dict['group']=party
    result_list.append(result_dict)

df_mdw = pd.DataFrame(result_list)
# Out:
# 2.34 to 1 = the odds of "carried" appearing in Republican (vs. non-Republican) texts
# 2.46 to 1 = the odds of "farmer" appearing in Republican (vs. non-Republican) texts
# 2.46 to 1 = the odds of "corporation" appearing in Republican (vs. non-Republican) texts
# 2.02 to 1 = the odds of "terrorists" appearing in Republican (vs. non-Republican) texts
# 4.21 to 1 = the odds of "territory" appearing in Republican (vs. non-Republican) texts
# 2.2 to 1 = the odds of "conduct" appearing in Republican (vs. non-Republican) texts
# 2.09 to 1 = the odds of "mexico" appearing in Republican (vs. non-Republican) texts
# 3.0 to 1 = the odds of "dealing" appearing in Republican (vs. non-Republican) texts
# 2.07 to 1 = the odds of "railroads" appearing in Republican (vs. non-Republican) texts
# 2.14 to 1 = the odds of "persons" appearing in Republican (vs. non-Republican) texts
# 3.83 to 1 = the odds of "chief" appearing in Republican (vs. non-Republican) texts
# 2.12 to 1 = the odds of "practice" appearing in Republican (vs. non-Republican) texts
# 6.96 to 1 = the odds of "statute" appearing in Republican (vs. non-Republican) texts
# 8.79 to 1 = the odds of "investigation" appearing in Republican (vs. non-Republican) texts
# 3.04 to 1 = the odds of "earnestly" appearing in Republican (vs. non-Republican) texts
# 3.66 to 1 = the odds of "committee" appearing in Republican (vs. non-Republican) texts
# 3.16 to 1 = the odds of "evil" appearing in Republican (vs. non-Republican) texts
# 2.35 to 1 = the odds of "submitted" appearing in Republican (vs. non-Republican) texts
# 2.45 to 1 = the odds of "organized" appearing in Republican (vs. non-Republican) texts
# 2.45 to 1 = the odds of "received" appearing in Republican (vs. non-Republican) texts
# 2.6 to 1 = the odds of "expenditure" appearing in Republican (vs. non-Republican) texts
# 23.44 to 1 = the odds of "supervision" appearing in Republican (vs. non-Republican) texts
# 4.84 to 1 = the odds of "governmental" appearing in Republican (vs. non-Republican) texts
# 2.69 to 1 = the odds of "river" appearing in Republican (vs. non-Republican) texts
# 9.52 to 1 = the odds of "claims" appearing in Republican (vs. non-Republican) texts
# 2.53 to 1 = the odds of "amendment" appearing in Republican (vs. non-Republican) texts
# 7.16 to 1 = the odds of "arbitration" appearing in Republican (vs. non-Republican) texts
# 4.0 to 1 = the odds of "careful" appearing in Republican (vs. non-Republican) texts
# 3.01 to 1 = the odds of "recommendation" appearing in Republican (vs. non-Republican) texts
# 4.34 to 1 = the odds of "desirable" appearing in Republican (vs. non-Republican) texts
# 4.68 to 1 = the odds of "degree" appearing in Republican (vs. non-Republican) texts
# 5.07 to 1 = the odds of "appointed" appearing in Republican (vs. non-Republican) texts
# 2.05 to 1 = the odds of "except" appearing in Republican (vs. non-Republican) texts
# 9.1 to 1 = the odds of "satisfactory" appearing in Republican (vs. non-Republican) texts
# 6.92 to 1 = the odds of "forest" appearing in Republican (vs. non-Republican) texts
# 2.02 to 1 = the odds of "honest" appearing in Republican (vs. non-Republican) texts
# 4.18 to 1 = the odds of "moreover" appearing in Republican (vs. non-Republican) texts
# 3.05 to 1 = the odds of "directed" appearing in Republican (vs. non-Republican) texts
# 2.85 to 1 = the odds of "republics" appearing in Republican (vs. non-Republican) texts
# 2.48 to 1 = the odds of "pending" appearing in Republican (vs. non-Republican) texts
# 2.33 to 1 = the odds of "joint" appearing in Republican (vs. non-Republican) texts
# 7.69 to 1 = the odds of "postal" appearing in Republican (vs. non-Republican) texts

# %%
df_mdw[df_mdw.group=='Democrat'].sort_values('oddsratio',ascending=False).head(20)
# Out:
# Empty DataFrame
# Columns: [group, oddsratio, pvalue, word]
# Index: []

# %%
df_mdw[df_mdw.group=='Republican'].sort_values('oddsratio',ascending=False).head(20)
# Out:
#           group  oddsratio        pvalue           word
# 297  Republican  29.814889  1.269588e-49          court
# 907  Republican  23.439326  1.901514e-19    supervision
# 508  Republican  20.029269  1.842075e-31           cent
# 716  Republican  14.651442  1.066697e-21         bureau
# 410  Republican  13.997990  1.429226e-33         tariff
# 536  Republican  10.191117  1.458381e-24         courts
# 918  Republican   9.521590  8.666267e-15         claims
# 972  Republican   9.102826  6.863674e-14   satisfactory
# 871  Republican   8.789364  4.646844e-15  investigation
# 992  Republican   7.690104  1.390131e-12         postal
# 451  Republican   7.284211  1.882482e-23          canal
# 931  Republican   7.161276  1.169184e-12    arbitration
# 509  Republican   7.051924  3.570370e-21          board
# 861  Republican   6.958081  2.072143e-13        statute
# 974  Republican   6.917009  5.675679e-12         forest
# 438  Republican   6.633157  9.472719e-23     commercial
# 637  Republican   6.153359  2.660581e-16         panama
# 243  Republican   6.077255  1.029565e-31       officers
# 320  Republican   5.645659  6.271053e-25        islands
# 403  Republican   5.495535  2.051971e-21       property

# %%
# Forest?
dtm['forest'].nlargest(10)
# Out:
# fn
# 1904.Roosevelt.txt     0.001377
# 1901.Roosevelt.txt     0.000815
# 1903.Roosevelt.txt     0.000468
# 1905.Roosevelt.txt     0.000438
# 1908.Roosevelt.txt     0.000412
# 1949.Truman.txt        0.000293
# 1913.Wilson.txt        0.000281
# 1990.Bush.txt          0.000259
# 1928.Coolidge.txt      0.000248
# 1957.Eisenhower.txt    0.000240
# Name: forest, dtype: float64

# %% [markdown]
# #### (4) Mann-Whitney U test

# %%
# See: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html
from scipy.stats import mannwhitneyu

# %%
Rs=dtm[df_meta.Party=='Republican']
Ds=dtm[df_meta.Party=='Democrat']

# %%
word='forest'
x=Rs[word]
y=Ds[word]
mannwhitneyu(x,y)
# Out:
# MannwhitneyuResult(statistic=1517.0, pvalue=0.035799315826459614)

# %%
#dtm_stacked_meta.query('Party == "Republican" and word=="forest"')

# %%
def compute_mannwhitney(group1,group2,words=None):
    if not words:
        words = set(group1.columns) & set(group2.columns)
    
    result_list=[]
    for word in words:
        x=group1[word]
        y=group2[word]
        
        mwU, pvalue = mannwhitneyu(x,y)
    
        result_dict={}
        result_dict['word']=word
        result_dict['mannwhitney_U']=mwU
        result_dict['mannwhitney_pvalue']=pvalue
        result_list.append(result_dict)
        
    return pd.DataFrame(result_list)

# %%
df_mannwhitney=compute_mannwhitney(Rs,Ds)

# %%
# Top 20 Republicans
df_mannwhitney.sort_values('mannwhitney_U',ascending=True).head(20)

# %%
# Top 20 Democrats
df_mannwhitney.sort_values('mannwhitney_U',ascending=False).head(20)

# %%
df_mannwhitney[df_mannwhitney.word=="iraq"]

# %%
df_mdw[df_mdw.word=="iraq"]

# %%
dtm_meta_T.loc['iraq']

# %%
df_mdw.merge(df_mannwhitney,on='word').plot(x='oddsratio',logx=True,y='mannwhitney_U',kind='scatter',figsize=(8,8))
